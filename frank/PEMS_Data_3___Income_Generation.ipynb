# %%
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib.axes as axe
import pandas as pd
import datetime as dt
import gurobipy as gp
from gurobipy import GRB
import cvxpy as cp
import yaml
import copy

import random
from itertools import chain, combinations, tee
import time

import os

# %% [markdown]
# # Functions

# %%
str_1 = "027___403206_Redwood_City___off"
"Redwood_City" in str_1
# Out:
# True

# %%
def station_to_city(station_name):
    if "East_Palo_Alto" in station_name:
        city_name = "East Palo Alto"
    elif "Palo_Alto" in station_name:
        city_name = "Palo Alto"
    elif "Menlo_Park" in station_name:
        city_name = "Menlo Park"
    elif "Redwood_City" in station_name:
        city_name = "Redwood City"
    elif "Belmont" in station_name:
        city_name = "Belmont"
    elif "San_Mateo" in station_name:
        city_name = "San Mateo"
    elif "Burlingame" in station_name:
        city_name = "Burlingame"
    elif "Millbrae" in station_name:
        city_name = "Millbrae"
    else:
        assert 1 == 0, "There should be no other case."
    return city_name

def income_range_avg(income_range_str):
    
    if income_range_str == "< $10,000":
        mean_income = 10000/2

    elif income_range_str == "$10,000 to $14,999":
        mean_income = (10000 + 15000)/2

    elif income_range_str == "$15,000 to $24,999":
        mean_income = (15000 + 25000)/2

    elif income_range_str == "$25,000 to $34,999":
        mean_income = (25000 + 35000)/2
        
    elif income_range_str == "$35,000 to $49,999":
        mean_income = (35000 + 50000)/2
        
    elif income_range_str == "$50,000 to $74,999":
        mean_income = (50000 + 75000)/2
        
    elif income_range_str == "$75,000 to $99,999":
        mean_income = (75000 + 100000)/2

    elif income_range_str == "$100,000 to $149,999":
        mean_income = (100000 + 150000)/2
    
    elif income_range_str == "$150,000 to $199,999":
        mean_income = (150000 + 200000)/2
    
    else:
        assert 1 == 0, "This case should not occur."
    
    return mean_income

# %% [markdown]
# # Import O-D Flow Data + Income Data:

# %%
directory_path = '../data/pems_flow___101_N_Sep_to_Nov_2024/'
df_od_flow_data = pd.read_csv(directory_path + 'data_od.csv')

dict_df_od_flow_data = {}

for column_name_full in list(df_od_flow_data.columns):
    if column_name_full == "Data Category":
        categories_list = df_od_flow_data[column_name_full].tolist()
    else:
        dict_df_od_flow_data[int(column_name_full)] = {}
        for category_index, category in enumerate(categories_list):
            if category == "Start Index" or category == "End Index":
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = int(df_od_flow_data[column_name_full].tolist()[category_index])
            elif category == "O-D Flow (Initialization)" or category == "O-D Flow (Max Entropy)":
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = float(df_od_flow_data[column_name_full].tolist()[category_index])
            else:
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = df_od_flow_data[column_name_full].tolist()[category_index]
        
        dict_df_od_flow_data[int(column_name_full)]["Start City"] \
            = station_to_city(dict_df_od_flow_data[int(column_name_full)]["Start Station"])
        dict_df_od_flow_data[int(column_name_full)]["End City"] \
            = station_to_city(dict_df_od_flow_data[int(column_name_full)]["End Station"])
        
dict_df_od_flow_data
# dict_df_od_flow_data[0]["O-D Flow (Initialization)"]
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.539616936298,
#   'O-D Flow (Max Entropy)': 612.539616936298,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto'},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.02842969746226,
#   'O-D Flow (Max Entropy)': 80.19045260172992,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.21104560854025,
#   'O-D Flow (Max Entropy)': 413.6495858413996,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217997502863,
#   'O-D Flow (Max Entropy)': 517.2177492843396,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.44612634033228,
#   'O-D Flow (Max Entropy)': 209.30114967791195,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.39336877576807,
#   'O-D Flow (Max Entropy)': 348.2467008641436,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.01367510128861,
#   'O-D Flow (Max Entropy)': 37.860514534190564,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.63571900479022,
#   'O-D Flow (Max Entropy)': 229.8646608025822,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.78201958831744,
#   'O-D Flow (Max Entropy)': 156.99625166997893,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436350256,
#   'O-D Flow (Max Entropy)': 20.52905029219567,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974006398,
#   'O-D Flow (Max Entropy)': 198.37149432605494,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.00842462083335,
#   'O-D Flow (Max Entropy)': 152.67891882581497,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.71158987155542,
#   'O-D Flow (Max Entropy)': 99.72718407391667,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375188904,
#   'O-D Flow (Max Entropy)': 142.25775753230835,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.72922631760076,
#   'O-D Flow (Max Entropy)': 857.7160571545749,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490165905821027,
#   'O-D Flow (Max Entropy)': 17.844467261638155,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897818557937,
#   'O-D Flow (Max Entropy)': 92.04654838648104,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.20053599754033,
#   'O-D Flow (Max Entropy)': 115.09418514350136,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.813417511788266,
#   'O-D Flow (Max Entropy)': 46.57526081630505,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624204764,
#   'O-D Flow (Max Entropy)': 77.49149049917995,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571269596,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489042881028074,
#   'O-D Flow (Max Entropy)': 51.14923184657617,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.738893898300925e-05,
#   'O-D Flow (Max Entropy)': 34.93550462429403,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0043795064128136,
#   'O-D Flow (Max Entropy)': 4.566207664736659,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.741895858479324,
#   'O-D Flow (Max Entropy)': 44.14323906987277,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.221691887554826,
#   'O-D Flow (Max Entropy)': 33.974821450749424,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122126079,
#   'O-D Flow (Max Entropy)': 22.192000339235506,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.116586547656297,
#   'O-D Flow (Max Entropy)': 31.65589811766146,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.4762189636408,
#   'O-D Flow (Max Entropy)': 190.86374328265674,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581043829,
#   'O-D Flow (Max Entropy)': 31.42046242741641,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.882852733289326,
#   'O-D Flow (Max Entropy)': 39.28808280167192,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823076939408,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011146195222578345,
#   'O-D Flow (Max Entropy)': 26.451979741660878,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.8750509114018827,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0002637732790534185,
#   'O-D Flow (Max Entropy)': 17.459738652877096,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.925127314864811,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0012777350014209995,
#   'O-D Flow (Max Entropy)': 1.5581574227592943,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.068203959225531,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123544749855,
#   'O-D Flow (Max Entropy)': 11.597200229945047,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.771041909144758,
#   'O-D Flow (Max Entropy)': 7.575108690332761,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.311510645634552,
#   'O-D Flow (Max Entropy)': 10.805636142115725,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.80398130682082,
#   'O-D Flow (Max Entropy)': 65.15065614753317,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277858517939,
#   'O-D Flow (Max Entropy)': 54.916421020820955,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.01693277464443,
#   'O-D Flow (Max Entropy)': 68.66669331850726,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.786880754177904,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011717563116433972,
#   'O-D Flow (Max Entropy)': 46.23226244080016,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.0255805897047585,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0003209100698846976,
#   'O-D Flow (Max Entropy)': 30.516086525290536,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243038725,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0014863361082006613,
#   'O-D Flow (Max Entropy)': 2.724047399123207,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449282449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.2645858237607364,
#   'O-D Flow (Max Entropy)': 20.26950370115961,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.805615892154279,
#   'O-D Flow (Max Entropy)': 13.239865933338049,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384262711,
#   'O-D Flow (Max Entropy)': 18.88601804571517,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.64406248440758,
#   'O-D Flow (Max Entropy)': 113.87033808551647,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.0008902776788274977,
#   'O-D Flow (Max Entropy)': 28.39019172812698,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363558756599,
#   'O-D Flow (Max Entropy)': 35.49904629530624,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.364943848148798,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203423669012125,
#   'O-D Flow (Max Entropy)': 23.900868897153714,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.5976517193859276,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0013525774258009015,
#   'O-D Flow (Max Entropy)': 15.775857999295344,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  61: {'Start Index': 10,
#   'End Index': 41,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.775041902292813,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  62: {'Start Index': 10,
#   'End Index': 44,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0028260612912363128,
#   'O-D Flow (Max Entropy)': 1.407803184625391,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  63: {'Start Index': 10,
#   'End Index': 48,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 13.614973874797407,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  64: {'Start Index': 10,
#   'End Index': 55,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.675449695299628,
#   'O-D Flow (Max Entropy)': 10.478738375164713,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  65: {'Start Index': 10,
#   'End Index': 59,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 12.429368059694482,
#   'O-D Flow (Max Entropy)': 6.844509524495882,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  66: {'Start Index': 10,
#   'End Index': 61,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 12.96983679618438,
#   'O-D Flow (Max Entropy)': 9.763506317809803,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  67: {'Start Index': 10,
#   'End Index': 62,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 170.4623074573709,
#   'O-D Flow (Max Entropy)': 58.86755804990479,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  68: {'Start Index': 15,
#   'End Index': 23,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 145.30097933241564,
#   'O-D Flow (Max Entropy)': 80.93831702052893,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  69: {'Start Index': 15,
#   'End Index': 28,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 201.35654360137846,
#   'O-D Flow (Max Entropy)': 134.66678898781961,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  70: {'Start Index': 15,
#   'End Index': 36,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.639505369145454,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  71: {'Start Index': 15,
#   'End Index': 38,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.44077343556827,
#   'O-D Flow (Max Entropy)': 88.887964919763,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  72: {'Start Index': 15,
#   'End Index': 41,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 75.50701144783005,
#   'O-D Flow (Max Entropy)': 60.71162037315181,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  73: {'Start Index': 15,
#   'End Index': 44,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032014571240124275,
#   'O-D Flow (Max Entropy)': 7.935526161187877,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  74: {'Start Index': 15,
#   'End Index': 48,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 88.84960774411076,
#   'O-D Flow (Max Entropy)': 76.71286040897309,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  75: {'Start Index': 15,
#   'End Index': 55,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 25.792163092030695,
#   'O-D Flow (Max Entropy)': 59.0422066484566,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  76: {'Start Index': 15,
#   'End Index': 59,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 19.242379890974775,
#   'O-D Flow (Max Entropy)': 38.56617712224913,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  77: {'Start Index': 15,
#   'End Index': 61,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.369809489346785,
#   'O-D Flow (Max Entropy)': 55.012841926091816,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  78: {'Start Index': 15,
#   'End Index': 62,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 248.94876198417762,
#   'O-D Flow (Max Entropy)': 331.6930843243241,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  79: {'Start Index': 17,
#   'End Index': 23,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.00516902420500707,
#   'O-D Flow (Max Entropy)': 4.868485418378846,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  80: {'Start Index': 17,
#   'End Index': 28,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.007681158488132835,
#   'O-D Flow (Max Entropy)': 8.100388099725038,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  81: {'Start Index': 17,
#   'End Index': 36,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 0.880036359617237,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  82: {'Start Index': 17,
#   'End Index': 38,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.006830133362902665,
#   'O-D Flow (Max Entropy)': 5.346710542578309,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  83: {'Start Index': 17,
#   'End Index': 41,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00441850440081367,
#   'O-D Flow (Max Entropy)': 3.651722210127523,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  84: {'Start Index': 17,
#   'End Index': 44,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.008210239662192432,
#   'O-D Flow (Max Entropy)': 0.47726943213837064,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  85: {'Start Index': 17,
#   'End Index': 48,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.004688281720991468,
#   'O-D Flow (Max Entropy)': 4.614312976281366,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  86: {'Start Index': 17,
#   'End Index': 55,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005032937390121489,
#   'O-D Flow (Max Entropy)': 3.5512911504518674,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  87: {'Start Index': 17,
#   'End Index': 59,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005396482850941245,
#   'O-D Flow (Max Entropy)': 2.3193805597423256,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  88: {'Start Index': 17,
#   'End Index': 61,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005799984026906839,
#   'O-D Flow (Max Entropy)': 3.308855916554572,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  89: {'Start Index': 17,
#   'End Index': 62,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 57.02601787432584,
#   'O-D Flow (Max Entropy)': 19.956437788338075,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  90: {'Start Index': 19,
#   'End Index': 23,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0014474192547626562,
#   'O-D Flow (Max Entropy)': 14.984432416953295,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  91: {'Start Index': 19,
#   'End Index': 28,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 12.251958842638135,
#   'O-D Flow (Max Entropy)': 24.931639644855945,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  92: {'Start Index': 19,
#   'End Index': 36,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.7097580849570684,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  93: {'Start Index': 19,
#   'End Index': 38,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003108710237822861,
#   'O-D Flow (Max Entropy)': 16.45620889204438,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  94: {'Start Index': 19,
#   'End Index': 41,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000697056321470949,
#   'O-D Flow (Max Entropy)': 11.23970040009346,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  95: {'Start Index': 19,
#   'End Index': 44,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004873121203427373,
#   'O-D Flow (Max Entropy)': 1.4685619716875284,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  96: {'Start Index': 19,
#   'End Index': 48,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0009671033949896796,
#   'O-D Flow (Max Entropy)': 14.20212110935518,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  97: {'Start Index': 19,
#   'End Index': 55,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0013176885527089286,
#   'O-D Flow (Max Entropy)': 10.930621962369647,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  98: {'Start Index': 19,
#   'End Index': 59,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016817222490715924,
#   'O-D Flow (Max Entropy)': 7.139725904203833,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  99: {'Start Index': 19,
#   'End Index': 61,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.002084880450214933,
#   'O-D Flow (Max Entropy)': 10.184554543457171,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  100: {'Start Index': 19,
#   'End Index': 62,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 163.40140213404794,
#   'O-D Flow (Max Entropy)': 61.405460394558204,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  101: {'Start Index': 21,
#   'End Index': 23,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 76.87666351356728,
#   'O-D Flow (Max Entropy)': 45.72305580758106,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  102: {'Start Index': 21,
#   'End Index': 28,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 132.6396184104135,
#   'O-D Flow (Max Entropy)': 76.07437041321302,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  103: {'Start Index': 21,
#   'End Index': 36,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.269844373430182,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  104: {'Start Index': 21,
#   'End Index': 38,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 55.656865628778526,
#   'O-D Flow (Max Entropy)': 50.21377267173915,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  105: {'Start Index': 21,
#   'End Index': 41,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 6.723103641040549,
#   'O-D Flow (Max Entropy)': 34.296648033459505,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  106: {'Start Index': 21,
#   'End Index': 44,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003356329166666293,
#   'O-D Flow (Max Entropy)': 4.482698714546547,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  107: {'Start Index': 21,
#   'End Index': 48,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 20.06569993732254,
#   'O-D Flow (Max Entropy)': 43.33630933969172,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  108: {'Start Index': 21,
#   'End Index': 55,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.58240625449437,
#   'O-D Flow (Max Entropy)': 33.35353515467314,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  109: {'Start Index': 21,
#   'End Index': 59,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.622834780791564,
#   'O-D Flow (Max Entropy)': 21.786222070927916,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  110: {'Start Index': 21,
#   'End Index': 61,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 9.590880272381593,
#   'O-D Flow (Max Entropy)': 31.077026956858685,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  111: {'Start Index': 21,
#   'End Index': 62,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 215.24488308938712,
#   'O-D Flow (Max Entropy)': 187.3739502515164,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  112: {'Start Index': 24,
#   'End Index': 28,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 130.6453891483295,
#   'O-D Flow (Max Entropy)': 65.8275887993488,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  113: {'Start Index': 24,
#   'End Index': 36,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 7.15592210915664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  114: {'Start Index': 24,
#   'End Index': 38,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.51188423666123,
#   'O-D Flow (Max Entropy)': 43.450299249009106,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  115: {'Start Index': 24,
#   'End Index': 41,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 4.57812224892381,
#   'O-D Flow (Max Entropy)': 29.67696219061442,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  116: {'Start Index': 24,
#   'End Index': 44,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.878867544640723,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  117: {'Start Index': 24,
#   'End Index': 48,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 17.920718545205727,
#   'O-D Flow (Max Entropy)': 37.498793406889824,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  118: {'Start Index': 24,
#   'End Index': 55,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 28.86088574402395,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  119: {'Start Index': 24,
#   'End Index': 59,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 2.547068614951268,
#   'O-D Flow (Max Entropy)': 18.85166076178689,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  120: {'Start Index': 24,
#   'End Index': 61,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 2.0859745817154804,
#   'O-D Flow (Max Entropy)': 26.891003996396748,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  121: {'Start Index': 24,
#   'End Index': 62,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 212.94565397284782,
#   'O-D Flow (Max Entropy)': 162.13530879526462,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  122: {'Start Index': 26,
#   'End Index': 28,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 52.89757833352109,
#   'O-D Flow (Max Entropy)': 35.151834865004986,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  123: {'Start Index': 26,
#   'End Index': 36,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.8208848501938064,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  124: {'Start Index': 26,
#   'End Index': 38,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 23.202140197774664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  125: {'Start Index': 26,
#   'End Index': 41,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.847162795361594,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  126: {'Start Index': 26,
#   'End Index': 44,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.070942281529095,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  127: {'Start Index': 26,
#   'End Index': 48,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.024021418085,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  128: {'Start Index': 26,
#   'End Index': 55,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.411397934188646,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  129: {'Start Index': 26,
#   'End Index': 59,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.066574076325914,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  130: {'Start Index': 26,
#   'End Index': 61,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.359504296168554,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  131: {'Start Index': 26,
#   'End Index': 62,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 173.6789019001655,
#   'O-D Flow (Max Entropy)': 86.57833994676545,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  132: {'Start Index': 30,
#   'End Index': 36,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.179981052718745,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  133: {'Start Index': 30,
#   'End Index': 38,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 89.7982635911554,
#   'O-D Flow (Max Entropy)': 49.668109146577706,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  134: {'Start Index': 30,
#   'End Index': 41,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 40.826886582914454,
#   'O-D Flow (Max Entropy)': 33.92392928695852,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  135: {'Start Index': 30,
#   'End Index': 44,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0017600088180856205,
#   'O-D Flow (Max Entropy)': 4.433993221773312,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  136: {'Start Index': 30,
#   'End Index': 48,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 54.169482879196146,
#   'O-D Flow (Max Entropy)': 42.86504918501271,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  137: {'Start Index': 30,
#   'End Index': 55,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 32.991067791027845,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  138: {'Start Index': 30,
#   'End Index': 59,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 21.549476103995875,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  139: {'Start Index': 30,
#   'End Index': 61,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 30.739320062109986,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  140: {'Start Index': 30,
#   'End Index': 62,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 224.90688556541292,
#   'O-D Flow (Max Entropy)': 185.33775718681446,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  141: {'Start Index': 32,
#   'End Index': 36,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 17.565529828455453,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  142: {'Start Index': 32,
#   'End Index': 38,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 169.00945122429835,
#   'O-D Flow (Max Entropy)': 106.65349252959406,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  143: {'Start Index': 32,
#   'End Index': 41,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 120.0756892365596,
#   'O-D Flow (Max Entropy)': 72.84552442733366,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  144: {'Start Index': 32,
#   'End Index': 44,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0027075759340147083,
#   'O-D Flow (Max Entropy)': 9.521692036228606,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  145: {'Start Index': 32,
#   'End Index': 48,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 133.4182855328422,
#   'O-D Flow (Max Entropy)': 92.04486516666124,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  146: {'Start Index': 32,
#   'End Index': 55,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 70.36084088076063,
#   'O-D Flow (Max Entropy)': 70.84238143964212,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  147: {'Start Index': 32,
#   'End Index': 59,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 41.00911841313085,
#   'O-D Flow (Max Entropy)': 46.274396796401234,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  148: {'Start Index': 32,
#   'End Index': 61,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 42.86374542291191,
#   'O-D Flow (Max Entropy)': 66.00709439701639,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  149: {'Start Index': 32,
#   'End Index': 62,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 303.0116318932985,
#   'O-D Flow (Max Entropy)': 397.98158933608806,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  150: {'Start Index': 34,
#   'End Index': 36,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.891408995502232,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  151: {'Start Index': 34,
#   'End Index': 38,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 9.209414382474513,
#   'O-D Flow (Max Entropy)': 23.630281830482005,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  152: {'Start Index': 34,
#   'End Index': 41,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 16.13957553947632,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  153: {'Start Index': 34,
#   'End Index': 44,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002552516375068164,
#   'O-D Flow (Max Entropy)': 2.1091760323877153,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  154: {'Start Index': 34,
#   'End Index': 48,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.39350775268446,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  155: {'Start Index': 34,
#   'End Index': 55,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.69577144719794,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  156: {'Start Index': 34,
#   'End Index': 59,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.252333105150312,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  157: {'Start Index': 34,
#   'End Index': 61,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.624467769935757,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  158: {'Start Index': 34,
#   'End Index': 62,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 185.74258913871716,
#   'O-D Flow (Max Entropy)': 88.17610831888322,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  159: {'Start Index': 39,
#   'End Index': 41,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.21315794821089,
#   'O-D Flow (Max Entropy)': 32.892418220407336,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  160: {'Start Index': 39,
#   'End Index': 44,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004291525526194608,
#   'O-D Flow (Max Entropy)': 4.299156372181855,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  161: {'Start Index': 39,
#   'End Index': 48,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 66.1765063988034,
#   'O-D Flow (Max Entropy)': 41.561657960501115,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  162: {'Start Index': 39,
#   'End Index': 55,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.066154822650771,
#   'O-D Flow (Max Entropy)': 31.987917947057372,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  163: {'Start Index': 39,
#   'End Index': 59,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0012759304473504136,
#   'O-D Flow (Max Entropy)': 20.89422090151865,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  164: {'Start Index': 39,
#   'End Index': 61,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016780165039376102,
#   'O-D Flow (Max Entropy)': 29.80463689397558,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  165: {'Start Index': 39,
#   'End Index': 62,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 218.6791408483991,
#   'O-D Flow (Max Entropy)': 179.7021971948997,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  166: {'Start Index': 42,
#   'End Index': 44,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032912531410064566,
#   'O-D Flow (Max Entropy)': 6.131364060854139,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  167: {'Start Index': 42,
#   'End Index': 48,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 110.62977327490029,
#   'O-D Flow (Max Entropy)': 59.273100012715915,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  168: {'Start Index': 42,
#   'End Index': 55,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 47.48616521173347,
#   'O-D Flow (Max Entropy)': 45.620078851740445,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  169: {'Start Index': 42,
#   'End Index': 59,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0006695751803973039,
#   'O-D Flow (Max Entropy)': 29.7985770769594,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  170: {'Start Index': 42,
#   'End Index': 61,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.989069753884777,
#   'O-D Flow (Max Entropy)': 42.506108449898065,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  171: {'Start Index': 42,
#   'End Index': 62,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 261.5057143953829,
#   'O-D Flow (Max Entropy)': 256.2854550120548,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773964618167794,
#   'O-D Flow (Max Entropy)': 12.3355181881873,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.01412552337074811,
#   'O-D Flow (Max Entropy)': 9.49400834632596,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406029354183,
#   'O-D Flow (Max Entropy)': 6.201257219343068,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909370534536233,
#   'O-D Flow (Max Entropy)': 8.845980374770239,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534587726388,
#   'O-D Flow (Max Entropy)': 53.33588101319014,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.10789210160277,
#   'O-D Flow (Max Entropy)': 74.20246282234035,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037465853,
#   'O-D Flow (Max Entropy)': 48.46926736758839,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151396612,
#   'O-D Flow (Max Entropy)': 69.13785987139363,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934661554519,
#   'O-D Flow (Max Entropy)': 416.85793008435695,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278065052,
#   'O-D Flow (Max Entropy)': 55.98621571035147,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377376889,
#   'O-D Flow (Max Entropy)': 36.57007664264351,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.166731545050844,
#   'O-D Flow (Max Entropy)': 52.165054861799376,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.68337618655505,
#   'O-D Flow (Max Entropy)': 314.52376767483895,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.28398568530136,
#   'O-D Flow (Max Entropy)': 72.76486228168181,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.9536872820199,
#   'O-D Flow (Max Entropy)': 47.53017262697266,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745096037,
#   'O-D Flow (Max Entropy)': 67.79837653213843,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.07701209245874,
#   'O-D Flow (Max Entropy)': 408.78164106994745,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031221727018,
#   'O-D Flow (Max Entropy)': 57.61476844332287,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.49027099930663,
#   'O-D Flow (Max Entropy)': 82.1825203892005,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.8840620069468,
#   'O-D Flow (Max Entropy)': 495.50735639100026,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'}}

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_income_data = pd.read_csv(directory_path + 'data_income_raw___year_2023.csv')

dict_df_income_data = {}

for column_name_full in list(df_income_data.columns):
    if column_name_full == "Income":
        categories_list = df_income_data[column_name_full].tolist()
    else:
        dict_df_income_data[column_name_full] = {}
        for category_index, category in enumerate(categories_list):
            dict_df_income_data[column_name_full][category] \
                = float(df_income_data[column_name_full].tolist()[category_index])
                
dict_df_income_data
# Out:
# {'Palo Alto': {'< $10,000': 4.7,
#   '$10,000 to $14,999': 3.1,
#   '$15,000 to $24,999': 2.0,
#   '$25,000 to $34,999': 2.5,
#   '$35,000 to $49,999': 3.5,
#   '$50,000 to $74,999': 7.8,
#   '$75,000 to $99,999': 7.5,
#   '$100,000 to $149,999': 13.2,
#   '$150,000 to $199,999': 8.8,
#   '>= $200,000': 46.9,
#   'Median': 184068.0,
#   'Mean': 264292.0},
#  'East Palo Alto': {'< $10,000': 3.6,
#   '$10,000 to $14,999': 2.3,
#   '$15,000 to $24,999': 3.9,
#   '$25,000 to $34,999': 4.9,
#   '$35,000 to $49,999': 8.8,
#   '$50,000 to $74,999': 14.9,
#   '$75,000 to $99,999': 9.5,
#   '$100,000 to $149,999': 19.3,
#   '$150,000 to $199,999': 9.7,
#   '>= $200,000': 23.1,
#   'Median': 104832.0,
#   'Mean': 138379.0},
#  'Menlo Park': {'< $10,000': 1.9,
#   '$10,000 to $14,999': 0.3,
#   '$15,000 to $24,999': 2.2,
#   '$25,000 to $34,999': 2.7,
#   '$35,000 to $49,999': 5.0,
#   '$50,000 to $74,999': 6.2,
#   '$75,000 to $99,999': 5.6,
#   '$100,000 to $149,999': 13.4,
#   '$150,000 to $199,999': 9.0,
#   '>= $200,000': 53.6,
#   'Median': 206588.0,
#   'Mean': 339415.0},
#  'Redwood City': {'< $10,000': 3.6,
#   '$10,000 to $14,999': 1.6,
#   '$15,000 to $24,999': 1.9,
#   '$25,000 to $34,999': 4.4,
#   '$35,000 to $49,999': 5.1,
#   '$50,000 to $74,999': 9.8,
#   '$75,000 to $99,999': 6.3,
#   '$100,000 to $149,999': 16.7,
#   '$150,000 to $199,999': 8.8,
#   '>= $200,000': 41.8,
#   'Median': 151234.0,
#   'Mean': 226931.0},
#  'Belmont': {'< $10,000': 2.8,
#   '$10,000 to $14,999': 1.9,
#   '$15,000 to $24,999': 4.7,
#   '$25,000 to $34,999': 2.3,
#   '$35,000 to $49,999': 3.4,
#   '$50,000 to $74,999': 6.2,
#   '$75,000 to $99,999': 4.8,
#   '$100,000 to $149,999': 12.2,
#   '$150,000 to $199,999': 10.1,
#   '>= $200,000': 51.5,
#   'Median': 207609.0,
#   'Mean': 258184.0},
#  'San Mateo': {'< $10,000': 3.1,
#   '$10,000 to $14,999': 1.9,
#   '$15,000 to $24,999': 3.4,
#   '$25,000 to $34,999': 2.8,
#   '$35,000 to $49,999': 6.1,
#   '$50,000 to $74,999': 8.8,
#   '$75,000 to $99,999': 7.9,
#   '$100,000 to $149,999': 15.5,
#   '$150,000 to $199,999': 12.3,
#   '>= $200,000': 38.3,
#   'Median': 151485.0,
#   'Mean': 219670.0},
#  'Burlingame': {'< $10,000': 3.5,
#   '$10,000 to $14,999': 1.5,
#   '$15,000 to $24,999': 1.7,
#   '$25,000 to $34,999': 2.7,
#   '$35,000 to $49,999': 5.2,
#   '$50,000 to $74,999': 8.0,
#   '$75,000 to $99,999': 8.7,
#   '$100,000 to $149,999': 14.8,
#   '$150,000 to $199,999': 13.0,
#   '>= $200,000': 40.9,
#   'Median': 168832.0,
#   'Mean': 237106.0},
#  'Millbrae': {'< $10,000': 2.3,
#   '$10,000 to $14,999': 2.3,
#   '$15,000 to $24,999': 4.6,
#   '$25,000 to $34,999': 2.4,
#   '$35,000 to $49,999': 5.8,
#   '$50,000 to $74,999': 7.8,
#   '$75,000 to $99,999': 7.8,
#   '$100,000 to $149,999': 14.4,
#   '$150,000 to $199,999': 13.5,
#   '>= $200,000': 39.0,
#   'Median': 157567.0,
#   'Mean': 210044.0}}

# %% [markdown]
# # Mean Incomes, VoTs, Population Percentages

# %% [markdown]
# ## Case 1: (2 eligible groups, 3 ineligible groups)

# %%
cities_list = list(dict_df_income_data.keys())

dict_income_groups_1 = {}
income_range_list_1 = ["< $15,000", "$15,000 to $35,000", "$35,000 to $100,000", \
                       "$100,000 to $200,000", ">= $200,000"]

for city_name in cities_list:
    dict_income_groups_1[city_name] = {}
    
    for income_range in income_range_list_1:
        
        if income_range == "< $15,000":
            percent_of_population = dict_df_income_data[city_name]["< $10,000"] \
                + dict_df_income_data[city_name]["$10,000 to $14,999"]
            mean_income = (income_range_avg("< $10,000") * dict_df_income_data[city_name]["< $10,000"] \
                + income_range_avg("$10,000 to $14,999") * dict_df_income_data[city_name]["$10,000 to $14,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$15,000 to $35,000":
            percent_of_population = dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + dict_df_income_data[city_name]["$25,000 to $34,999"]
            mean_income = (income_range_avg("$15,000 to $24,999") * dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + income_range_avg("$25,000 to $34,999") * dict_df_income_data[city_name]["$25,000 to $34,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$35,000 to $100,000":
            percent_of_population = dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + dict_df_income_data[city_name]["$75,000 to $99,999"]
            mean_income = (income_range_avg("$35,000 to $49,999") * dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + income_range_avg("$50,000 to $74,999") * dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + income_range_avg("$75,000 to $99,999") * dict_df_income_data[city_name]["$75,000 to $99,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$100,000 to $200,000":
            percent_of_population = dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + dict_df_income_data[city_name]["$150,000 to $199,999"]
            mean_income = (income_range_avg("$100,000 to $149,999") * dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + income_range_avg("$150,000 to $199,999") * dict_df_income_data[city_name]["$150,000 to $199,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == ">= $200,000":
            percent_of_population = dict_df_income_data[city_name][">= $200,000"]          
            dict_income_groups_1[city_name][income_range] = [0, percent_of_population, 0]
        
        else:
            assert 1 == 0, "This case should not occur."
    
    if income_range == ">= $200,000":
        sum_of_income_mean_percent_products \
            = sum([dict_income_groups_1[city_name][income_range][0] * dict_income_groups_1[city_name][income_range][1] \
                   for income_range in income_range_list_1 if income_range != ">= 200,000"])
        mean_income = (dict_df_income_data[city_name]["Mean"] * 100 - sum_of_income_mean_percent_products) \
            / dict_income_groups_1[city_name][">= $200,000"][1]
        dict_income_groups_1[city_name][income_range][0] = mean_income

dict_income_groups_1
# Out:
# {'Palo Alto': {'< $15,000': [7980.7692307692305, 7.800000000000001],
#   '$15,000 to $35,000': [25555.555555555555, 4.5],
#   '$35,000 to $100,000': [68750.0, 18.8],
#   '$100,000 to $200,000': [145000.0, 22.0],
#   '>= $200,000': [464167.3773987207, 46.9, 0]},
#  'East Palo Alto': {'< $15,000': [7923.728813559322, 5.9],
#   '$15,000 to $35,000': [25568.181818181816, 8.8],
#   '$35,000 to $100,000': [64352.409638554214, 33.2],
#   '$100,000 to $200,000': [141724.1379310345, 29.0],
#   '>= $200,000': [316867.96536796534, 23.1, 0]},
#  'Menlo Park': {'< $15,000': [6022.727272727274, 2.1999999999999997],
#   '$15,000 to $35,000': [25510.20408163265, 4.9],
#   '$35,000 to $100,000': [64880.95238095239, 16.799999999999997],
#   '$100,000 to $200,000': [145089.2857142857, 22.4],
#   '>= $200,000': [549687.5, 53.6, 0]},
#  'Redwood City': {'< $15,000': [7307.692307692308, 5.2],
#   '$15,000 to $35,000': [26984.126984126982, 6.300000000000001],
#   '$35,000 to $100,000': [65117.92452830189, 21.2],
#   '$100,000 to $200,000': [142254.9019607843, 25.5],
#   '>= $200,000': [418112.4401913876, 41.8, 0]},
#  'Belmont': {'< $15,000': [8031.914893617022, 4.699999999999999],
#   '$15,000 to $35,000': [23285.714285714286, 7.0],
#   '$35,000 to $100,000': [66111.11111111112, 14.399999999999999],
#   '$100,000 to $200,000': [147645.73991031392, 22.299999999999997],
#   '>= $200,000': [415012.6213592233, 51.5, 0]},
#  'San Mateo': {'< $15,000': [7850.0, 5.0],
#   '$15,000 to $35,000': [24516.129032258068, 6.199999999999999],
#   '$35,000 to $100,000': [65811.40350877192, 22.8],
#   '$100,000 to $200,000': [147122.30215827338, 27.8],
#   '>= $200,000': [422591.38381201046, 38.3, 0]},
#  'Burlingame': {'< $15,000': [7250.0, 5.0],
#   '$15,000 to $35,000': [26136.363636363636, 4.4],
#   '$35,000 to $100,000': [67682.64840182649, 21.9],
#   '$100,000 to $200,000': [148381.29496402878, 27.8],
#   '>= $200,000': [438926.65036674816, 40.9, 0]},
#  'Millbrae': {'< $15,000': [8750.0, 4.6],
#   '$15,000 to $35,000': [23428.571428571428, 7.0],
#   '$35,000 to $100,000': [66191.58878504673, 21.4],
#   '$100,000 to $200,000': [149193.5483870968, 27.9],
#   '>= $200,000': [390285.89743589744, 39.0, 0]}}

# %%
dict_mean_income_estimate_1 = {}
dict_population_percentage_1 = {}
dict_VoT_1 = {}

dict_mean_income_estimate_1["Income Range"] = income_range_list_1
dict_population_percentage_1["Income Range"] = income_range_list_1
dict_VoT_1["Income Range"] = income_range_list_1

for city_name in cities_list:
    dict_mean_income_estimate_1[city_name] = []
    dict_population_percentage_1[city_name] = []
    dict_VoT_1[city_name] = []
    
    for income_range in income_range_list_1:
        dict_mean_income_estimate_1[city_name] += [dict_income_groups_1[city_name][income_range][0]]
        dict_population_percentage_1[city_name] += [dict_income_groups_1[city_name][income_range][1]]
        dict_VoT_1[city_name] += [dict_income_groups_1[city_name][income_range][0] / (40*52*60*2)]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_mean_income_estimate_1 = pd.DataFrame(dict_mean_income_estimate_1)
df_mean_income_estimate_1.to_csv(directory_path + 'data_mean_income_estimate_1.csv', index = False)

df_population_percentage_1 = pd.DataFrame(dict_population_percentage_1)
df_population_percentage_1.to_csv(directory_path + 'data_population_percentage_1.csv', index = False)

df_VoT_1 = pd.DataFrame(dict_VoT_1)
df_VoT_1.to_csv(directory_path + 'data_VoT_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
cities_list = list(dict_df_income_data.keys())

dict_income_groups_2 = {}
income_range_list_2 = ["< $35,000", "$35,000 to $200,000", ">= $200,000"]

for city_name in cities_list:
    dict_income_groups_2[city_name] = {}
    
    for income_range in income_range_list_2:
        dict_income_groups_2[city_name][income_range] = np.zeros(2)
        
        if income_range == "< $35,000":
            percent_of_population = dict_df_income_data[city_name]["< $10,000"] \
                + dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + dict_df_income_data[city_name]["$25,000 to $34,999"]
            mean_income = (income_range_avg("< $10,000") * dict_df_income_data[city_name]["< $10,000"] \
                + income_range_avg("$10,000 to $14,999") * dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + income_range_avg("$15,000 to $24,999") * dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + income_range_avg("$25,000 to $34,999") * dict_df_income_data[city_name]["$25,000 to $34,999"]) \
                / percent_of_population
            dict_income_groups_2[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$35,000 to $200,000":
            percent_of_population = dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + dict_df_income_data[city_name]["$75,000 to $99,999"] \
                + dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + dict_df_income_data[city_name]["$150,000 to $199,999"]
            mean_income = (income_range_avg("$35,000 to $49,999") * dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + income_range_avg("$50,000 to $74,999") * dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + income_range_avg("$75,000 to $99,999") * dict_df_income_data[city_name]["$75,000 to $99,999"] \
                + income_range_avg("$100,000 to $149,999") * dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + income_range_avg("$150,000 to $199,999") * dict_df_income_data[city_name]["$150,000 to $199,999"]) \
                / percent_of_population
            dict_income_groups_2[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == ">= $200,000":
            percent_of_population = dict_df_income_data[city_name][">= $200,000"]          
            dict_income_groups_2[city_name][income_range] = [0, percent_of_population]
        
        else:
            assert 1 == 0, "This case should not occur."
    
    if income_range == ">= $200,000":
        sum_of_income_mean_percent_products \
            = sum([dict_income_groups_2[city_name][income_range][0] * dict_income_groups_2[city_name][income_range][1] \
                   for income_range in income_range_list_2 if income_range != ">= 200,000"])
        mean_income = (dict_df_income_data[city_name]["Mean"] * 100 - sum_of_income_mean_percent_products) \
            / dict_income_groups_2[city_name][">= $200,000"][1]
        dict_income_groups_2[city_name][income_range][0] = mean_income

dict_income_groups_2
# Out:
# {'Palo Alto': {'< $35,000': [14410.569105691056, 12.3],
#   '$35,000 to $200,000': [109865.19607843139, 40.8],
#   '>= $200,000': [464167.3773987207, 46.9]},
#  'East Palo Alto': {'< $35,000': [18486.39455782313, 14.700000000000001],
#   '$35,000 to $200,000': [100426.04501607717, 62.2],
#   '>= $200,000': [316867.96536796534, 23.1]},
#  'Menlo Park': {'< $35,000': [19471.83098591549, 7.1000000000000005],
#   '$35,000 to $200,000': [110714.28571428572, 39.199999999999996],
#   '>= $200,000': [549687.5, 53.6]},
#  'Redwood City': {'< $35,000': [18086.956521739132, 11.5],
#   '$35,000 to $200,000': [107237.68736616701, 46.7],
#   '>= $200,000': [418112.4401913876, 41.8]},
#  'Belmont': {'< $35,000': [17158.11965811966, 11.7],
#   '$35,000 to $200,000': [115653.95095367849, 36.699999999999996],
#   '>= $200,000': [415012.6213592233, 51.5]},
#  'San Mateo': {'< $35,000': [17075.89285714286, 11.2],
#   '$35,000 to $200,000': [110484.18972332017, 50.599999999999994],
#   '>= $200,000': [422591.38381201046, 38.3]},
#  'Burlingame': {'< $35,000': [16090.425531914892, 9.4],
#   '$35,000 to $200,000': [112821.93158953721, 49.7],
#   '>= $200,000': [438926.65036674816, 40.9]},
#  'Millbrae': {'< $35,000': [17607.758620689656, 11.6],
#   '$35,000 to $200,000': [113164.30020283976, 49.3],
#   '>= $200,000': [390285.89743589744, 39.0]}}

# %%
dict_mean_income_estimate_2 = {}
dict_population_percentage_2 = {}
dict_VoT_2 = {}

dict_mean_income_estimate_2["Income Range"] = income_range_list_2
dict_population_percentage_2["Income Range"] = income_range_list_2
dict_VoT_2["Income Range"] = income_range_list_2

for city_name in cities_list:
    dict_mean_income_estimate_2[city_name] = []
    dict_population_percentage_2[city_name] = []
    dict_VoT_2[city_name] = []
    
    for income_range in income_range_list_2:
        dict_mean_income_estimate_2[city_name] += [dict_income_groups_2[city_name][income_range][0]]
        dict_population_percentage_2[city_name] += [dict_income_groups_2[city_name][income_range][1]]
        dict_VoT_2[city_name] += [dict_income_groups_2[city_name][income_range][0] / (40*52*60*2)]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_mean_income_estimate_2 = pd.DataFrame(dict_mean_income_estimate_2)
df_mean_income_estimate_2.to_csv(directory_path + 'data_mean_income_estimate_2.csv', index = False)

df_population_percentage_2 = pd.DataFrame(dict_population_percentage_2)
df_population_percentage_2.to_csv(directory_path + 'data_population_percentage_2.csv', index = False)

df_VoT_2 = pd.DataFrame(dict_VoT_2)
df_VoT_2.to_csv(directory_path + 'data_VoT_2.csv', index = False)

# %% [markdown]
# # Demands

# %% [markdown]
# ## Case 1: (2 eligible groups, 3 ineligible groups)

# %%
# dict_df_od_flow_data

# %%
dict_df_od_flow_data_augmented_1 = copy.deepcopy(dict_df_od_flow_data)

# %%
for od_index in list(dict_df_od_flow_data.keys()):
    start_city_name = dict_df_od_flow_data[od_index]["Start City"]
    demand_total_od = dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]
    
    dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][0] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 1)"] = dict_VoT_1[start_city_name][0]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][1] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 2)"] = dict_VoT_1[start_city_name][1]
    
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][2] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 1)"] = dict_VoT_1[start_city_name][2]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][3] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 2)"] = dict_VoT_1[start_city_name][3]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][4] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 3)"] = dict_VoT_1[start_city_name][4]


dict_df_od_flow_data_augmented_1
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.539616936298,
#   'O-D Flow (Max Entropy)': 612.539616936298,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto',
#   'Demand (eligible group, 1)': 47.77809012103125,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 27.564282762133406,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 115.15744798402402,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 134.75871572598555,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 287.28108034312373,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.02842969746226,
#   'O-D Flow (Max Entropy)': 80.19045260172992,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 6.254855302934934,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 3.608570367077846,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 15.075805089125224,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 17.64189957238058,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 37.60932227021133,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.21104560854025,
#   'O-D Flow (Max Entropy)': 413.6495858413996,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 32.26466769562917,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 18.61423136286298,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 77.76612213818312,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 91.0029088851079,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 194.0016557596164,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217997502863,
#   'O-D Flow (Max Entropy)': 517.2177492843396,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 40.34298444417849,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 23.274798717795278,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 97.23693686545585,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 113.78790484255471,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 242.57512441435523,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.44612634033228,
#   'O-D Flow (Max Entropy)': 209.30114967791195,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 16.325489674877133,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 9.418551735506037,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 39.34861613944745,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 46.04625292914063,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 98.1622391989407,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.39336877576807,
#   'O-D Flow (Max Entropy)': 348.2467008641436,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 27.1632426674032,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 15.67110153888646,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 65.470379762459,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 76.61427419011159,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 163.32770270528334,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.01367510128861,
#   'O-D Flow (Max Entropy)': 37.860514534190564,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.953120133666864,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 1.7037231540385753,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 7.117776732427826,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 8.329313197521923,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 17.756581316535375,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.63571900479022,
#   'O-D Flow (Max Entropy)': 229.8646608025822,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 17.929443542601415,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 10.343909736116197,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 43.21455623088546,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 50.57022537656809,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 107.80652591641105,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.78201958831744,
#   'O-D Flow (Max Entropy)': 156.99625166997893,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 12.245707630258357,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 7.0648313251490515,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 29.515295313956038,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 34.539175367395366,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 73.63124203322012,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436350256,
#   'O-D Flow (Max Entropy)': 20.52905029219567,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.6012659227912625,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 0.9238072631488052,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 3.859461454932786,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 4.516391064283047,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 9.62812458703977,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974006398,
#   'O-D Flow (Max Entropy)': 198.37149432605494,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 15.472976557432286,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 8.926717244672473,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 37.29384093329833,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 43.64172875173209,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 93.03623083891976,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.00842462083335,
#   'O-D Flow (Max Entropy)': 152.67891882581497,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 11.908955668413569,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 6.8705513471616735,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 28.703636739253216,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 33.589362141679295,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 71.60641292930723,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.71158987155542,
#   'O-D Flow (Max Entropy)': 99.72718407391667,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 7.778720357765501,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 4.48772328332625,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 18.748710605896335,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 21.93998049626167,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 46.772049330666924,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375188904,
#   'O-D Flow (Max Entropy)': 142.25775753230835,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 11.096105087520051,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 6.401599088953876,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 26.74445841607397,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 31.296706657107833,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 66.71888828265261,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.72922631760076,
#   'O-D Flow (Max Entropy)': 857.7160571545749,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 66.90185245805685,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 38.59722257195587,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 161.25061874506008,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 188.69753257400646,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 402.2688308054956,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490165905821027,
#   'O-D Flow (Max Entropy)': 17.844467261638155,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 1.3918684464077762,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 0.803001026773717,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 3.354759845187973,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 3.925782797560394,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 8.369055145708295,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897818557937,
#   'O-D Flow (Max Entropy)': 92.04654838648104,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 7.179630774145521,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 4.142094677391647,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 17.304751096658435,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 20.25024064502583,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 43.169831193259604,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.20053599754033,
#   'O-D Flow (Max Entropy)': 115.09418514350136,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 8.977346441193108,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 5.179238331457562,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 21.637706806978258,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 25.3207207315703,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 53.97917283230214,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.813417511788266,
#   'O-D Flow (Max Entropy)': 46.57526081630505,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 3.6328703436717937,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 2.095886736733727,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 8.756149033465348,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 10.246557379587111,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 21.843797322847067,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624204764,
#   'O-D Flow (Max Entropy)': 77.49149049917995,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 6.0443362589360365,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 3.4871170724630973,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 14.56840021384583,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 17.048127909819588,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 36.34350904411539,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571269596,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.6570633865590285,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 0.37907503070713183,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 1.5836912393986842,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 1.8532557056793113,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 3.9508042089254407,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489042881028074,
#   'O-D Flow (Max Entropy)': 51.14923184657617,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.9896400840329416,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 2.3017154330959277,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 9.61605558715632,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 11.252831006246758,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 23.98898973604422,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.738893898300925e-05,
#   'O-D Flow (Max Entropy)': 34.93550462429403,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.7249693606949346,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 1.5720977080932315,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 6.567874869367278,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 7.685811017344687,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 16.3847516687939,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0043795064128136,
#   'O-D Flow (Max Entropy)': 4.566207664736659,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.3561641978494594,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 0.20547934491314965,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 0.8584470409704918,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 1.0045656862420649,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 2.141551394761493,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.741895858479324,
#   'O-D Flow (Max Entropy)': 44.14323906987277,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 3.443172647450077,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 1.9864457581442747,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 8.298928945136081,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 9.71151259537201,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 20.70317912377033,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.221691887554826,
#   'O-D Flow (Max Entropy)': 33.974821450749424,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.6500360731584554,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 1.528866965283724,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 6.3872664327408915,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 7.474460719164873,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 15.934191260401478,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122126079,
#   'O-D Flow (Max Entropy)': 22.192000339235506,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.7309760264603695,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 0.9986400152655978,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 4.172096063776275,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 4.882240074631811,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 10.408048159101451,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.116586547656297,
#   'O-D Flow (Max Entropy)': 31.65589811766146,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.4691600531775943,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 1.4245154152947657,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 5.951308846120355,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 6.964297585885522,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 14.846616217183225,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.4762189636408,
#   'O-D Flow (Max Entropy)': 190.86374328265674,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 14.887371976047227,
#   'VoT (eligible group, 1)': 0.03197423570019724,
#   'Demand (eligible group, 2)': 8.588868447719554,
#   'VoT (eligible group, 2)': 0.10238603988603988,
#   'Demand (ineligible group, 1)': 35.88238373713946,
#   'VoT (ineligible group, 1)': 0.2754407051282051,
#   'Demand (ineligible group, 2)': 41.99002352218449,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 89.51509559956601,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581043829,
#   'O-D Flow (Max Entropy)': 31.42046242741641,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 1.8538072832175683,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.7650006936126443,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 10.43159352590225,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 9.111934103950759,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 7.2581268207331915,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.882852733289326,
#   'O-D Flow (Max Entropy)': 39.28808280167192,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 2.3179968852986432,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 3.457351286547129,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 13.043643490155077,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 11.393544012484856,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 9.075547127186214,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823076939408,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 0.9379956153942508,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.3990443077066792,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 5.278212615438836,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 4.6104869231242835,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.672491307730033,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011146195222578345,
#   'O-D Flow (Max Entropy)': 26.451979741660878,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.560666804757992,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.3277742172661577,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 8.782057274231413,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 7.671074125081654,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.110407320323663,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.8750509114018827,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.1696280037727111,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.2530044802033657,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 0.9545169025854251,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 0.833764764306546,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.664136760533835,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0002637732790534185,
#   'O-D Flow (Max Entropy)': 17.459738652877096,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.0301245805197488,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.5364570014531846,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 5.7966332327551955,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 5.063324209334358,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.033199628814609,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.925127314864811,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.703582511577024,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.0494112037081036,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 3.9591422685351176,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 3.4582869213107954,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.7547044097337716,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0012777350014209995,
#   'O-D Flow (Max Entropy)': 1.5581574227592943,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.09193128794279837,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.1371178532028179,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 0.5173082643560857,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 0.45186565260019534,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.359934364657397,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.068203959225531,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 0.8890240335943064,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.3260019484118468,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 5.002643714462876,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 4.369779148175404,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.480755114581098,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123544749855,
#   'O-D Flow (Max Entropy)': 11.597200229945047,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.6842348135667577,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.0205536202351642,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 3.850270476341756,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 3.3631880666840637,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.6789532531173057,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.771041909144758,
#   'O-D Flow (Max Entropy)': 7.575108690332761,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.44693141272963294,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.666609564749283,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 2.514936085190477,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 2.1967815201965006,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 1.7498501074668678,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.311510645634552,
#   'O-D Flow (Max Entropy)': 10.805636142115725,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.6375325323848279,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.950895980506184,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 3.587471199182421,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 3.1336344812135604,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.4961019488287324,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.80398130682082,
#   'O-D Flow (Max Entropy)': 65.15065614753317,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.8438887127044574,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 5.7332577409829195,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 21.63001784098101,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 18.89369028278462,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 15.049801570080163,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277858517939,
#   'O-D Flow (Max Entropy)': 54.916421020820955,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 3.240068840228437,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 4.832645049832244,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 18.23225177891256,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 15.925762096038078,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 12.685693255809642,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.01693277464443,
#   'O-D Flow (Max Entropy)': 68.66669331850726,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 4.051334905791928,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 6.042669012028639,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 22.797342181744412,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 19.913341062367103,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 15.862006156575179,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.786880754177904,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 1.6394259644964964,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.4452455063676557,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 9.225244410387065,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 8.058195418711593,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.418769454215096,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011717563116433972,
#   'O-D Flow (Max Entropy)': 46.23226244080016,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.72770348400721,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 4.068439094790415,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 15.349111130345655,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 13.407356107832047,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 10.679652623824838,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.0255805897047585,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.2965092547925808,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.4422510918940188,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 1.66849275578198,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 1.45741837101438,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 1.1609091162217993,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0003209100698846976,
#   'O-D Flow (Max Entropy)': 30.516086525290536,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.8004491049921418,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.6854156142255676,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 10.13134072639646,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 8.849665092334256,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 7.049215987342114,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243038725,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.229715903392848,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.8341525338740783,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 6.919757286888568,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 6.044366304812303,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.814650401419455,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0014863361082006613,
#   'O-D Flow (Max Entropy)': 2.724047399123207,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.16071879654826923,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 0.23971617112284224,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 0.9043837365089048,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 0.78997374574573,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.6292549491974608,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449282449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 1.5538337050766449,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.3175824753685554,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 8.74360661161773,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 7.637487702919102,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.083653997842458,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.2645858237607364,
#   'O-D Flow (Max Entropy)': 20.26950370115961,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.1959007183684172,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.7837163257020459,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 6.729475228784992,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 5.878156073336287,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.68225535496787,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.805615892154279,
#   'O-D Flow (Max Entropy)': 13.239865933338049,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.7811520900669449,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.1651082021337484,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 4.395635489868233,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 3.8395611206680345,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.0584090306010894,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384262711,
#   'O-D Flow (Max Entropy)': 18.88601804571517,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.114275064697195,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.661969588022935,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 6.270157991177436,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 5.476945233257399,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.362670168560204,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.64406248440758,
#   'O-D Flow (Max Entropy)': 113.87033808551647,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.718349947045471,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 10.020589751525451,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 37.80495224439147,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 33.02239804479977,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 26.304048097754304,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.0008902776788274977,
#   'O-D Flow (Max Entropy)': 28.39019172812698,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 1.6750213119594917,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.4983368720751744,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 9.425543653738158,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 8.233155601156824,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.558134289197333,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363558756599,
#   'O-D Flow (Max Entropy)': 35.49904629530624,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 2.0944437314230684,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 3.12391607398695,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 11.785683370041674,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 10.29472342563881,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 8.200279694215743,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.364943848148798,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 0.8475316870407791,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 1.2641150586370944,
#   'VoT (eligible group, 2)': 0.10243662587412587,
#   'Demand (ineligible group, 1)': 4.769161357585401,
#   'VoT (ineligible group, 1)': 0.25782215400061786,
#   'Demand (ineligible group, 2)': 4.165833715963151,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.3183020289223726,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203423669012125,
#   'O-D Flow (Max Entropy)': 23.900868897153714,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.410151264932069,
#   'VoT (eligible group, 1)': 0.031745708387657535,
#   'Demand (eligible group, 2)': 2.103276462949527,
#   'VoT (eligible group, 2)': 0.10243662587412587,
# ...
#   'Demand (eligible group, 1)': 0.616775909409365,
#   'VoT (eligible group, 1)': 0.03145032051282051,
#   'Demand (eligible group, 2)': 0.7648021276676126,
#   'VoT (eligible group, 2)': 0.09822167080231597,
#   'Demand (ineligible group, 1)': 2.8124981469067047,
#   'VoT (ineligible group, 1)': 0.26366748200629775,
#   'Demand (ineligible group, 2)': 3.4292740563160695,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 4.724503466075736,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.01412552337074811,
#   'O-D Flow (Max Entropy)': 9.49400834632596,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.4747004173162981,
#   'VoT (eligible group, 1)': 0.03145032051282051,
#   'Demand (eligible group, 2)': 0.5886285174722095,
#   'VoT (eligible group, 2)': 0.09822167080231597,
#   'Demand (ineligible group, 1)': 2.1646339029623194,
#   'VoT (ineligible group, 1)': 0.26366748200629775,
#   'Demand (ineligible group, 2)': 2.6393343202786173,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 3.6362051966428424,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406029354183,
#   'O-D Flow (Max Entropy)': 6.201257219343068,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.3100628609671534,
#   'VoT (eligible group, 1)': 0.03145032051282051,
#   'Demand (eligible group, 2)': 0.38447794759927023,
#   'VoT (eligible group, 2)': 0.09822167080231597,
#   'Demand (ineligible group, 1)': 1.4138866460102195,
#   'VoT (ineligible group, 1)': 0.26366748200629775,
#   'Demand (ineligible group, 2)': 1.723949506977373,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 2.375081515008395,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909370534536233,
#   'O-D Flow (Max Entropy)': 8.845980374770239,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.4422990187385119,
#   'VoT (eligible group, 1)': 0.03145032051282051,
#   'Demand (eligible group, 2)': 0.5484507832357547,
#   'VoT (eligible group, 2)': 0.09822167080231597,
#   'Demand (ineligible group, 1)': 2.0168835254476143,
#   'VoT (ineligible group, 1)': 0.26366748200629775,
#   'Demand (ineligible group, 2)': 2.459182544186126,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 3.3880104835370015,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534587726388,
#   'O-D Flow (Max Entropy)': 53.33588101319014,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.6667940506595067,
#   'VoT (eligible group, 1)': 0.03145032051282051,
#   'Demand (eligible group, 2)': 3.306824622817788,
#   'VoT (eligible group, 2)': 0.09822167080231597,
#   'Demand (ineligible group, 1)': 12.160580871007353,
#   'VoT (ineligible group, 1)': 0.26366748200629775,
#   'Demand (ineligible group, 2)': 14.827374921666857,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 20.427642428051822,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.10789210160277,
#   'O-D Flow (Max Entropy)': 74.20246282234035,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.7101231411170175,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 3.264908364182976,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 16.250339358092535,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 20.628284664610618,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 30.348807294337202,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037465853,
#   'O-D Flow (Max Entropy)': 48.46926736758839,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.4234633683794193,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 2.1326477641738895,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 10.614769553501855,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 13.474456328189572,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 19.82393035334365,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151396612,
#   'O-D Flow (Max Entropy)': 69.13785987139363,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.4568929935696815,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 3.0420658343413196,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 15.141191311835206,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 19.220325044247428,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 28.277384687399994,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934661554519,
#   'O-D Flow (Max Entropy)': 416.85793008435695,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 20.842896504217848,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 18.341748923711705,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 91.29188668847416,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 115.88650456345124,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 170.494893404502,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278065052,
#   'O-D Flow (Max Entropy)': 55.98621571035147,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.799310785517574,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 2.463393491255465,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 12.26098124056697,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 15.56416796747771,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 22.898362225533752,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377376889,
#   'O-D Flow (Max Entropy)': 36.57007664264351,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.8285038321321752,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 1.6090833722763145,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 8.008846784738928,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 10.166481306654894,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 14.957161346841195,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.166731545050844,
#   'O-D Flow (Max Entropy)': 52.165054861799376,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.608252743089969,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 2.295262413919173,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 11.424147014734062,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 14.501885251580227,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 21.335507438475943,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.68337618655505,
#   'O-D Flow (Max Entropy)': 314.52376767483895,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 15.726188383741947,
#   'VoT (eligible group, 1)': 0.02904647435897436,
#   'Demand (eligible group, 2)': 13.839045777692915,
#   'VoT (eligible group, 2)': 0.10471299533799534,
#   'Demand (ineligible group, 1)': 68.88070512078973,
#   'VoT (ineligible group, 1)': 0.2711644567380869,
#   'Demand (ineligible group, 2)': 87.43760741360524,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 128.64022097900911,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.28398568530136,
#   'O-D Flow (Max Entropy)': 72.76486228168181,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.3471836649573636,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 5.093540359717727,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 15.571680528279908,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 20.301396576589227,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 28.378296289855907,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.9536872820199,
#   'O-D Flow (Max Entropy)': 47.53017262697266,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.186387940840742,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 3.327112083888086,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 10.171456942172147,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 13.260918162925371,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 18.53676732451934,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745096037,
#   'O-D Flow (Max Entropy)': 67.79837653213843,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.118725320478368,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 4.745886357249691,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 14.508852577877624,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 18.91574705246662,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 26.441366847533992,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.07701209245874,
#   'O-D Flow (Max Entropy)': 408.78164106994745,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 18.803955489217582,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 28.614714874896322,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 87.47927118896874,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 114.05007785851534,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 159.4248400172795,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031221727018,
#   'O-D Flow (Max Entropy)': 57.61476844332287,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.6502793483928517,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 4.033033791032601,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 12.329560446871094,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 16.07452039568708,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 22.469759692895924,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.49027099930663,
#   'O-D Flow (Max Entropy)': 82.1825203892005,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.7803959379032226,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 5.752776427244036,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 17.587059363288905,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 22.928923188586943,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 32.0511829517882,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.8840620069468,
#   'O-D Flow (Max Entropy)': 495.50735639100026,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 22.79333839398601,
#   'VoT (eligible group, 1)': 0.035056089743589744,
#   'Demand (eligible group, 2)': 34.685514947370024,
#   'VoT (eligible group, 2)': 0.09386446886446886,
#   'Demand (ineligible group, 1)': 106.03857426767405,
#   'VoT (ineligible group, 1)': 0.2651906601965013,
#   'Demand (ineligible group, 2)': 138.24655243308908,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 193.2478689924901,
#   'VoT (ineligible group, 3)': 1.563645422419461}}

# %%
# dict_df_od_flow_data

# %%
# dict_df_od_flow_data

# %%
dict_od_data_to_save_1 = {}
dict_od_data_to_save_1["Data Category"] \
    = ["Start Index", "End Index", "Start Station", "End Station", "Start City", "End City", \
       "O-D Flow (Initialization)", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for od_index in list(dict_df_od_flow_data.keys()):
    dict_od_data_to_save_1[od_index] = []
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start Index"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End Index"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start Station"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End Station"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start City"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End City"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Initialization)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 3)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 3)"]]

# %%
# dict_od_data_to_save_1

directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_data_to_save_1 = pd.DataFrame(dict_od_data_to_save_1)
df_od_data_to_save_1.to_csv(directory_path + 'data_od_VoTs_demands_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
# dict_df_od_flow_data

# %%
dict_df_od_flow_data_augmented_2 = copy.deepcopy(dict_df_od_flow_data)

# %%
for od_index in list(dict_df_od_flow_data.keys()):
    start_city_name = dict_df_od_flow_data[od_index]["Start City"]
    demand_total_od = dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]
    
    dict_df_od_flow_data_augmented_2[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][0] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (eligible group, 1)"] = dict_VoT_2[start_city_name][0]
    
    dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][1] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 1)"] = dict_VoT_2[start_city_name][1]
    dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][2] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 2)"] = dict_VoT_2[start_city_name][2]

dict_df_od_flow_data_augmented_2
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.539616936298,
#   'O-D Flow (Max Entropy)': 612.539616936298,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto',
#   'Demand (eligible group, 1)': 75.34237288316466,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 249.91616371000956,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 287.28108034312373,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.02842969746226,
#   'O-D Flow (Max Entropy)': 80.19045260172992,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 9.86342567001278,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 32.717704661505806,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 37.60932227021133,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.21104560854025,
#   'O-D Flow (Max Entropy)': 413.6495858413996,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 50.87889905849215,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 168.76903102329103,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 194.0016557596164,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217997502863,
#   'O-D Flow (Max Entropy)': 517.2177492843396,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 63.61778316197377,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 211.02484170801054,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 242.57512441435523,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.44612634033228,
#   'O-D Flow (Max Entropy)': 209.30114967791195,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 25.74404141038317,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 85.39486906858806,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 98.1622391989407,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.39336877576807,
#   'O-D Flow (Max Entropy)': 348.2467008641436,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 42.834344206289664,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 142.08465395257056,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 163.32770270528334,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.01367510128861,
#   'O-D Flow (Max Entropy)': 37.860514534190564,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 4.656843287705439,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 15.44708992994975,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 17.756581316535375,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.63571900479022,
#   'O-D Flow (Max Entropy)': 229.8646608025822,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 28.273353278717615,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 93.78478160745354,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 107.80652591641105,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.78201958831744,
#   'O-D Flow (Max Entropy)': 156.99625166997893,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 19.31053895540741,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 64.0544706813514,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 73.63124203322012,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436350256,
#   'O-D Flow (Max Entropy)': 20.52905029219567,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.5250731859400677,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 8.375852519215833,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 9.62812458703977,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974006398,
#   'O-D Flow (Max Entropy)': 198.37149432605494,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 24.399693802104757,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 80.93556968503042,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 93.03623083891976,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.00842462083335,
#   'O-D Flow (Max Entropy)': 152.67891882581497,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 18.779507015575245,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 62.29299888093251,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 71.60641292930723,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.71158987155542,
#   'O-D Flow (Max Entropy)': 99.72718407391667,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 12.266443641091751,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 40.688691102158,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 46.772049330666924,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375188904,
#   'O-D Flow (Max Entropy)': 142.25775753230835,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 17.497704176473928,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 58.0411650731818,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 66.71888828265261,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.72922631760076,
#   'O-D Flow (Max Entropy)': 857.7160571545749,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 105.49907503001272,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 349.94815131906654,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 402.2688308054956,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490165905821027,
#   'O-D Flow (Max Entropy)': 17.844467261638155,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 2.194869473181493,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 7.280542642748367,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 8.369055145708295,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897818557937,
#   'O-D Flow (Max Entropy)': 92.04654838648104,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 11.321725451537167,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 37.55499174168426,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 43.169831193259604,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.20053599754033,
#   'O-D Flow (Max Entropy)': 115.09418514350136,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 14.15658477265067,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 46.95842753854855,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 53.97917283230214,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.813417511788266,
#   'O-D Flow (Max Entropy)': 46.57526081630505,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 5.728757080405521,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 19.002706413052458,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 21.843797322847067,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624204764,
#   'O-D Flow (Max Entropy)': 77.49149049917995,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 9.531453331399135,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 31.616528123665418,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 36.34350904411539,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571269596,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.0361384172661603,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 3.4369469450779953,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 3.9508042089254407,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489042881028074,
#   'O-D Flow (Max Entropy)': 51.14923184657617,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 6.291355517128869,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 20.868886593403076,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 23.98898973604422,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.738893898300925e-05,
#   'O-D Flow (Max Entropy)': 34.93550462429403,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 4.2970670687881665,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 14.253685886711965,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 16.3847516687939,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0043795064128136,
#   'O-D Flow (Max Entropy)': 4.566207664736659,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.5616435427626091,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 1.863012727212557,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 2.141551394761493,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.741895858479324,
#   'O-D Flow (Max Entropy)': 44.14323906987277,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 5.4296184055943515,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 18.01044154050809,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 20.70317912377033,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.221691887554826,
#   'O-D Flow (Max Entropy)': 33.974821450749424,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.178903038442179,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 13.861727151905763,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 15.934191260401478,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122126079,
#   'O-D Flow (Max Entropy)': 22.192000339235506,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.729616041725967,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 9.054336138408086,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 10.408048159101451,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.116586547656297,
#   'O-D Flow (Max Entropy)': 31.65589811766146,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.89367546847236,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 12.915606432005875,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 14.846616217183225,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.4762189636408,
#   'O-D Flow (Max Entropy)': 190.86374328265674,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 23.476240423766782,
#   'VoT (eligible group, 1)': 0.05773465186574942,
#   'Demand (ineligible group, 1)': 77.87240725932395,
#   'VoT (ineligible group, 1)': 0.4401650483911514,
#   'Demand (ineligible group, 2)': 89.51509559956601,
#   'VoT (ineligible group, 2)': 1.8596449415012848},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581043829,
#   'O-D Flow (Max Entropy)': 31.42046242741641,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 4.618807976830213,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 19.54352762985301,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 7.2581268207331915,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.882852733289326,
#   'O-D Flow (Max Entropy)': 39.28808280167192,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 5.775348171845772,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 24.437187502639937,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 9.075547127186214,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823076939408,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 2.3370399231009302,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 9.888699538563118,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.672491307730033,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011146195222578345,
#   'O-D Flow (Max Entropy)': 26.451979741660878,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.8884410220241494,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 16.45313139931307,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 6.110407320323663,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.8750509114018827,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.42263248397607683,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 1.788281666891971,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 0.664136760533835,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0002637732790534185,
#   'O-D Flow (Max Entropy)': 17.459738652877096,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.5665815819729336,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 10.859957442089554,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 4.033199628814609,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.925127314864811,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.7529937152851276,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 7.417429189845913,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.7547044097337716,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0012777350014209995,
#   'O-D Flow (Max Entropy)': 1.5581574227592943,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.22904914114561628,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 0.9691739169562811,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 0.359934364657397,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.068203959225531,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 2.215025982006153,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 9.372422862638281,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.480755114581098,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123544749855,
#   'O-D Flow (Max Entropy)': 11.597200229945047,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.7047884338019221,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 7.21345854302582,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.6789532531173057,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.771041909144758,
#   'O-D Flow (Max Entropy)': 7.575108690332761,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.1135409774789158,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 4.711717605386977,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 1.7498501074668678,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.311510645634552,
#   'O-D Flow (Max Entropy)': 10.805636142115725,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.5884285128910116,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 6.721105680395981,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.4961019488287324,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.80398130682082,
#   'O-D Flow (Max Entropy)': 65.15065614753317,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 9.577146453687376,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 40.52370812376563,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 15.049801570080163,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277858517939,
#   'O-D Flow (Max Entropy)': 54.916421020820955,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 8.072713890060681,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 34.15801387495063,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 12.685693255809642,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.01693277464443,
#   'O-D Flow (Max Entropy)': 68.66669331850726,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 10.094003917820567,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 42.710683244111515,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 15.862006156575179,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.786880754177904,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 4.084671470864152,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 17.283439829098658,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 6.418769454215096,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011717563116433972,
#   'O-D Flow (Max Entropy)': 46.23226244080016,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 6.796142578797625,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 28.756467238177702,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 10.679652623824838,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.0255805897047585,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.7387603466865995,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 3.12591112679636,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 1.1609091162217993,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0003209100698846976,
#   'O-D Flow (Max Entropy)': 30.516086525290536,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 4.485864719217709,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 18.981005818730715,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 7.049215987342114,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243038725,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.0638684372669265,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 12.96412359170087,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 4.814650401419455,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0014863361082006613,
#   'O-D Flow (Max Entropy)': 2.724047399123207,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.4004349676711114,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 1.694357482254635,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 0.6292549491974608,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449282449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 3.8714161804452005,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 16.381094314536835,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 6.083653997842458,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.2645858237607364,
#   'O-D Flow (Max Entropy)': 20.26950370115961,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.979617044070463,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 12.607631302121279,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 4.68225535496787,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.805615892154279,
#   'O-D Flow (Max Entropy)': 13.239865933338049,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.9462602922006935,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 8.235196610536267,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.0584090306010894,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384262711,
#   'O-D Flow (Max Entropy)': 18.88601804571517,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.7762446527201297,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 11.747103224434836,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 4.362670168560204,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.64406248440758,
#   'O-D Flow (Max Entropy)': 113.87033808551647,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 16.73893969857092,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 70.82735028919124,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 26.304048097754304,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.0008902776788274977,
#   'O-D Flow (Max Entropy)': 28.39019172812698,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 4.173358184034666,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 17.658699254894984,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 6.558134289197333,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363558756599,
#   'O-D Flow (Max Entropy)': 35.49904629530624,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 5.218359805410018,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 22.08040679568048,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 8.200279694215743,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.364943848148798,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 2.111646745677873,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 8.934995073548553,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.3183020289223726,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203423669012125,
#   'O-D Flow (Max Entropy)': 23.900868897153714,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.513427727881596,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 14.86634045402961,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 5.521100715242508,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.5976517193859276,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.3818548027497314,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 1.615739369458047,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 0.6000575471781493,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0013525774258009015,
#   'O-D Flow (Max Entropy)': 15.775857999295344,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.3190511258964155,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 9.812583675561704,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.6442231978372246,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  61: {'Start Index': 10,
#   'End Index': 41,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.775041902292813,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.5839311596370436,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 6.702076063226129,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.48903467942964,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  62: {'Start Index': 10,
#   'End Index': 44,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0028260612912363128,
#   'O-D Flow (Max Entropy)': 1.407803184625391,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.20694706813993247,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 0.8756535808369932,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 0.32520253564846535,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  63: {'Start Index': 10,
#   'End Index': 48,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 13.614973874797407,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 2.001401159595219,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 8.468513750123988,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 3.145058965078201,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  64: {'Start Index': 10,
#   'End Index': 55,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.675449695299628,
#   'O-D Flow (Max Entropy)': 10.478738375164713,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.5403745411492131,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 6.517775269352452,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.4205885646630487,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  65: {'Start Index': 10,
#   'End Index': 59,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 12.429368059694482,
#   'O-D Flow (Max Entropy)': 6.844509524495882,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.0061429001008948,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 4.257284924236439,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 1.5810817001585489,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  66: {'Start Index': 10,
#   'End Index': 61,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 12.96983679618438,
#   'O-D Flow (Max Entropy)': 9.763506317809803,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.4352354287180413,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 6.072900929677697,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 2.2553699594140646,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  67: {'Start Index': 10,
#   'End Index': 62,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 170.4623074573709,
#   'O-D Flow (Max Entropy)': 58.86755804990479,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 8.653531033336003,
#   'VoT (eligible group, 1)': 0.07406408076050933,
#   'Demand (ineligible group, 1)': 36.61562110704078,
#   'VoT (ineligible group, 1)': 0.4023479367631297,
#   'Demand (ineligible group, 2)': 13.598405909528008,
#   'VoT (ineligible group, 2)': 1.2695030663780662},
#  68: {'Start Index': 15,
#   'End Index': 23,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 145.30097933241564,
#   'O-D Flow (Max Entropy)': 80.93831702052893,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 9.307906457360826,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 37.798194048587014,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 33.83221651458109,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  69: {'Start Index': 15,
#   'End Index': 28,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 201.35654360137846,
#   'O-D Flow (Max Entropy)': 134.66678898781961,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 15.486680733599256,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 62.88939045731176,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 56.290717796908595,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  70: {'Start Index': 15,
#   'End Index': 36,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.639505369145454,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.683543117451727,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 6.8366490073909265,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 6.119313244302799,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  71: {'Start Index': 15,
#   'End Index': 38,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.44077343556827,
#   'O-D Flow (Max Entropy)': 88.887964919763,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 10.222115965772744,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 41.51067961752932,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 37.15516933646093,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  72: {'Start Index': 15,
#   'End Index': 41,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 75.50701144783005,
#   'O-D Flow (Max Entropy)': 60.71162037315181,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 6.981836342912458,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 28.3523267142619,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 25.377457315977452,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  73: {'Start Index': 15,
#   'End Index': 44,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032014571240124275,
#   'O-D Flow (Max Entropy)': 7.935526161187877,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.9125855085366058,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 3.705890717274739,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 3.317049935376532,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  74: {'Start Index': 15,
#   'End Index': 48,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 88.84960774411076,
#   'O-D Flow (Max Entropy)': 76.71286040897309,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 8.821978947031905,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 35.82490581099044,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 32.06597565095075,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  75: {'Start Index': 15,
#   'End Index': 55,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 25.792163092030695,
#   'O-D Flow (Max Entropy)': 59.0422066484566,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.789853764572509,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 27.57271050482923,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 24.679642379054858,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  76: {'Start Index': 15,
#   'End Index': 59,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 19.242379890974775,
#   'O-D Flow (Max Entropy)': 38.56617712224913,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.43511036905865,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 18.010404716090346,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 16.120662037100136,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  77: {'Start Index': 15,
#   'End Index': 61,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.369809489346785,
#   'O-D Flow (Max Entropy)': 55.012841926091816,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.326476821500559,
#   'VoT (eligible group, 1)': 0.07246376811594203,
#   'Demand (ineligible group, 1)': 25.69099717948488,
#   'VoT (ineligible group, 1)': 0.42963817053752806,
#   'Demand (ineligible group, 2)': 22.99536792510638,
#   'VoT (ineligible group, 2)': 1.6751299687154952},
#  78: {'Start Index': 15,
#   'End Index': 62,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 248.94876198417762,
#   'O-D Flow (Max Entropy)': 331.6930843243241,
# ...
#   'Demand (ineligible group, 1)': 90.92931178061923,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 68.82594152564657,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  166: {'Start Index': 42,
#   'End Index': 44,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032912531410064566,
#   'O-D Flow (Max Entropy)': 6.131364060854139,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.6867127748156635,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 3.102470214792194,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 2.348312435307135,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  167: {'Start Index': 42,
#   'End Index': 48,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 110.62977327490029,
#   'O-D Flow (Max Entropy)': 59.273100012715915,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 6.638587201424182,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 29.99218860643425,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 22.70159730487019,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  168: {'Start Index': 42,
#   'End Index': 55,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 47.48616521173347,
#   'O-D Flow (Max Entropy)': 45.620078851740445,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 5.109448831394929,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 23.08375989898066,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 17.47249020021659,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  169: {'Start Index': 42,
#   'End Index': 59,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0006695751803973039,
#   'O-D Flow (Max Entropy)': 29.7985770769594,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.337440632619453,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 15.078080000941455,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 11.41285502047545,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  170: {'Start Index': 42,
#   'End Index': 61,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.989069753884777,
#   'O-D Flow (Max Entropy)': 42.506108449898065,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.760684146388583,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 21.508090875648417,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 16.27983953631096,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  171: {'Start Index': 42,
#   'End Index': 62,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 261.5057143953829,
#   'O-D Flow (Max Entropy)': 256.2854550120548,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 28.703970961350137,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 129.6804402360997,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 98.15732926961698,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773964618167794,
#   'O-D Flow (Max Entropy)': 12.3355181881873,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 1.3815780370769775,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 6.241772203222773,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 4.724503466075736,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.01412552337074811,
#   'O-D Flow (Max Entropy)': 9.49400834632596,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.0633289347885075,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 4.803968223240935,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 3.6362051966428424,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406029354183,
#   'O-D Flow (Max Entropy)': 6.201257219343068,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.6945408085664236,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 3.1378361529875924,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 2.375081515008395,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909370534536233,
#   'O-D Flow (Max Entropy)': 8.845980374770239,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.9907498019742667,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 4.47606606963374,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 3.3880104835370015,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534587726388,
#   'O-D Flow (Max Entropy)': 53.33588101319014,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 5.973618673477295,
#   'VoT (eligible group, 1)': 0.06841303228021979,
#   'Demand (ineligible group, 1)': 26.987955792674207,
#   'VoT (ineligible group, 1)': 0.4426449908786866,
#   'Demand (ineligible group, 2)': 20.427642428051822,
#   'VoT (ineligible group, 2)': 1.693074454375042},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.10789210160277,
#   'O-D Flow (Max Entropy)': 74.20246282234035,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.9750315052999925,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 36.87862402270316,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 30.348807294337202,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037465853,
#   'O-D Flow (Max Entropy)': 48.46926736758839,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.556111132553308,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 24.089225881691434,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 19.82393035334365,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151396612,
#   'O-D Flow (Max Entropy)': 69.13785987139363,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.498958827911001,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 34.36151635608263,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 28.277384687399994,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934661554519,
#   'O-D Flow (Max Entropy)': 416.85793008435695,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 39.18464542792955,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 207.17839125192543,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 170.494893404502,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278065052,
#   'O-D Flow (Max Entropy)': 55.98621571035147,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 5.2627042767730385,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 27.825149208044685,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 22.898362225533752,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377376889,
#   'O-D Flow (Max Entropy)': 36.57007664264351,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.43758720440849,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 18.175328091393823,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 14.957161346841195,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.166731545050844,
#   'O-D Flow (Max Entropy)': 52.165054861799376,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.903515157009141,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 25.92603226631429,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 21.335507438475943,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.68337618655505,
#   'O-D Flow (Max Entropy)': 314.52376767483895,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 29.565234161434866,
#   'VoT (eligible group, 1)': 0.06446484588106928,
#   'Demand (ineligible group, 1)': 156.31831253439498,
#   'VoT (ineligible group, 1)': 0.4520109438683382,
#   'Demand (ineligible group, 2)': 128.64022097900911,
#   'VoT (ineligible group, 2)': 1.7585202338411385},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.28398568530136,
#   'O-D Flow (Max Entropy)': 72.76486228168181,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 8.44072402467509,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 35.87307710486913,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 28.378296289855907,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.9536872820199,
#   'O-D Flow (Max Entropy)': 47.53017262697266,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 5.513500024728828,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 23.432375105097517,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 18.53676732451934,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745096037,
#   'O-D Flow (Max Entropy)': 67.79837653213843,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 7.864611677728058,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 33.42459963034425,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 26.441366847533992,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.07701209245874,
#   'O-D Flow (Max Entropy)': 408.78164106994745,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 47.41867036411391,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 201.52934904748406,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 159.4248400172795,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031221727018,
#   'O-D Flow (Max Entropy)': 57.61476844332287,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.6833131394254535,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 28.404080842558173,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 22.469759692895924,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.49027099930663,
#   'O-D Flow (Max Entropy)': 82.1825203892005,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 9.533172365147259,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 40.515982551875844,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 32.0511829517882,
#   'VoT (ineligible group, 2)': 1.563645422419461},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.8840620069468,
#   'O-D Flow (Max Entropy)': 495.50735639100026,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 57.47885334135603,
#   'VoT (eligible group, 1)': 0.07054390473032715,
#   'Demand (ineligible group, 1)': 244.2851267007631,
#   'VoT (ineligible group, 1)': 0.4533826129921465,
#   'Demand (ineligible group, 2)': 193.2478689924901,
#   'VoT (ineligible group, 2)': 1.563645422419461}}

# %%
dict_df_od_flow_data
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.539616936298,
#   'O-D Flow (Max Entropy)': 612.539616936298,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto'},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.02842969746226,
#   'O-D Flow (Max Entropy)': 80.19045260172992,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.21104560854025,
#   'O-D Flow (Max Entropy)': 413.6495858413996,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217997502863,
#   'O-D Flow (Max Entropy)': 517.2177492843396,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.44612634033228,
#   'O-D Flow (Max Entropy)': 209.30114967791195,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.39336877576807,
#   'O-D Flow (Max Entropy)': 348.2467008641436,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.01367510128861,
#   'O-D Flow (Max Entropy)': 37.860514534190564,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.63571900479022,
#   'O-D Flow (Max Entropy)': 229.8646608025822,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.78201958831744,
#   'O-D Flow (Max Entropy)': 156.99625166997893,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436350256,
#   'O-D Flow (Max Entropy)': 20.52905029219567,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974006398,
#   'O-D Flow (Max Entropy)': 198.37149432605494,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.00842462083335,
#   'O-D Flow (Max Entropy)': 152.67891882581497,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.71158987155542,
#   'O-D Flow (Max Entropy)': 99.72718407391667,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375188904,
#   'O-D Flow (Max Entropy)': 142.25775753230835,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.72922631760076,
#   'O-D Flow (Max Entropy)': 857.7160571545749,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490165905821027,
#   'O-D Flow (Max Entropy)': 17.844467261638155,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897818557937,
#   'O-D Flow (Max Entropy)': 92.04654838648104,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.20053599754033,
#   'O-D Flow (Max Entropy)': 115.09418514350136,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.813417511788266,
#   'O-D Flow (Max Entropy)': 46.57526081630505,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624204764,
#   'O-D Flow (Max Entropy)': 77.49149049917995,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571269596,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489042881028074,
#   'O-D Flow (Max Entropy)': 51.14923184657617,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.738893898300925e-05,
#   'O-D Flow (Max Entropy)': 34.93550462429403,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0043795064128136,
#   'O-D Flow (Max Entropy)': 4.566207664736659,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.741895858479324,
#   'O-D Flow (Max Entropy)': 44.14323906987277,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.221691887554826,
#   'O-D Flow (Max Entropy)': 33.974821450749424,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122126079,
#   'O-D Flow (Max Entropy)': 22.192000339235506,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.116586547656297,
#   'O-D Flow (Max Entropy)': 31.65589811766146,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.4762189636408,
#   'O-D Flow (Max Entropy)': 190.86374328265674,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581043829,
#   'O-D Flow (Max Entropy)': 31.42046242741641,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.882852733289326,
#   'O-D Flow (Max Entropy)': 39.28808280167192,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823076939408,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011146195222578345,
#   'O-D Flow (Max Entropy)': 26.451979741660878,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.8750509114018827,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0002637732790534185,
#   'O-D Flow (Max Entropy)': 17.459738652877096,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.925127314864811,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0012777350014209995,
#   'O-D Flow (Max Entropy)': 1.5581574227592943,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.068203959225531,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123544749855,
#   'O-D Flow (Max Entropy)': 11.597200229945047,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.771041909144758,
#   'O-D Flow (Max Entropy)': 7.575108690332761,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.311510645634552,
#   'O-D Flow (Max Entropy)': 10.805636142115725,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.80398130682082,
#   'O-D Flow (Max Entropy)': 65.15065614753317,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277858517939,
#   'O-D Flow (Max Entropy)': 54.916421020820955,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.01693277464443,
#   'O-D Flow (Max Entropy)': 68.66669331850726,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.786880754177904,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011717563116433972,
#   'O-D Flow (Max Entropy)': 46.23226244080016,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.0255805897047585,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0003209100698846976,
#   'O-D Flow (Max Entropy)': 30.516086525290536,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243038725,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0014863361082006613,
#   'O-D Flow (Max Entropy)': 2.724047399123207,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449282449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.2645858237607364,
#   'O-D Flow (Max Entropy)': 20.26950370115961,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.805615892154279,
#   'O-D Flow (Max Entropy)': 13.239865933338049,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384262711,
#   'O-D Flow (Max Entropy)': 18.88601804571517,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.64406248440758,
#   'O-D Flow (Max Entropy)': 113.87033808551647,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.0008902776788274977,
#   'O-D Flow (Max Entropy)': 28.39019172812698,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363558756599,
#   'O-D Flow (Max Entropy)': 35.49904629530624,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.364943848148798,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203423669012125,
#   'O-D Flow (Max Entropy)': 23.900868897153714,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.5976517193859276,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0013525774258009015,
#   'O-D Flow (Max Entropy)': 15.775857999295344,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  61: {'Start Index': 10,
#   'End Index': 41,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.775041902292813,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  62: {'Start Index': 10,
#   'End Index': 44,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0028260612912363128,
#   'O-D Flow (Max Entropy)': 1.407803184625391,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  63: {'Start Index': 10,
#   'End Index': 48,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 13.614973874797407,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  64: {'Start Index': 10,
#   'End Index': 55,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.675449695299628,
#   'O-D Flow (Max Entropy)': 10.478738375164713,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  65: {'Start Index': 10,
#   'End Index': 59,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 12.429368059694482,
#   'O-D Flow (Max Entropy)': 6.844509524495882,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  66: {'Start Index': 10,
#   'End Index': 61,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 12.96983679618438,
#   'O-D Flow (Max Entropy)': 9.763506317809803,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  67: {'Start Index': 10,
#   'End Index': 62,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 170.4623074573709,
#   'O-D Flow (Max Entropy)': 58.86755804990479,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  68: {'Start Index': 15,
#   'End Index': 23,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 145.30097933241564,
#   'O-D Flow (Max Entropy)': 80.93831702052893,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  69: {'Start Index': 15,
#   'End Index': 28,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 201.35654360137846,
#   'O-D Flow (Max Entropy)': 134.66678898781961,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  70: {'Start Index': 15,
#   'End Index': 36,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.639505369145454,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  71: {'Start Index': 15,
#   'End Index': 38,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.44077343556827,
#   'O-D Flow (Max Entropy)': 88.887964919763,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  72: {'Start Index': 15,
#   'End Index': 41,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 75.50701144783005,
#   'O-D Flow (Max Entropy)': 60.71162037315181,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  73: {'Start Index': 15,
#   'End Index': 44,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032014571240124275,
#   'O-D Flow (Max Entropy)': 7.935526161187877,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  74: {'Start Index': 15,
#   'End Index': 48,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 88.84960774411076,
#   'O-D Flow (Max Entropy)': 76.71286040897309,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  75: {'Start Index': 15,
#   'End Index': 55,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 25.792163092030695,
#   'O-D Flow (Max Entropy)': 59.0422066484566,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  76: {'Start Index': 15,
#   'End Index': 59,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 19.242379890974775,
#   'O-D Flow (Max Entropy)': 38.56617712224913,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  77: {'Start Index': 15,
#   'End Index': 61,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.369809489346785,
#   'O-D Flow (Max Entropy)': 55.012841926091816,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  78: {'Start Index': 15,
#   'End Index': 62,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 248.94876198417762,
#   'O-D Flow (Max Entropy)': 331.6930843243241,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  79: {'Start Index': 17,
#   'End Index': 23,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.00516902420500707,
#   'O-D Flow (Max Entropy)': 4.868485418378846,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  80: {'Start Index': 17,
#   'End Index': 28,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.007681158488132835,
#   'O-D Flow (Max Entropy)': 8.100388099725038,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  81: {'Start Index': 17,
#   'End Index': 36,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 0.880036359617237,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  82: {'Start Index': 17,
#   'End Index': 38,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.006830133362902665,
#   'O-D Flow (Max Entropy)': 5.346710542578309,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  83: {'Start Index': 17,
#   'End Index': 41,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00441850440081367,
#   'O-D Flow (Max Entropy)': 3.651722210127523,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  84: {'Start Index': 17,
#   'End Index': 44,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.008210239662192432,
#   'O-D Flow (Max Entropy)': 0.47726943213837064,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  85: {'Start Index': 17,
#   'End Index': 48,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.004688281720991468,
#   'O-D Flow (Max Entropy)': 4.614312976281366,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  86: {'Start Index': 17,
#   'End Index': 55,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005032937390121489,
#   'O-D Flow (Max Entropy)': 3.5512911504518674,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  87: {'Start Index': 17,
#   'End Index': 59,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005396482850941245,
#   'O-D Flow (Max Entropy)': 2.3193805597423256,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  88: {'Start Index': 17,
#   'End Index': 61,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005799984026906839,
#   'O-D Flow (Max Entropy)': 3.308855916554572,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  89: {'Start Index': 17,
#   'End Index': 62,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 57.02601787432584,
#   'O-D Flow (Max Entropy)': 19.956437788338075,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  90: {'Start Index': 19,
#   'End Index': 23,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0014474192547626562,
#   'O-D Flow (Max Entropy)': 14.984432416953295,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  91: {'Start Index': 19,
#   'End Index': 28,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 12.251958842638135,
#   'O-D Flow (Max Entropy)': 24.931639644855945,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  92: {'Start Index': 19,
#   'End Index': 36,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.7097580849570684,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  93: {'Start Index': 19,
#   'End Index': 38,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003108710237822861,
#   'O-D Flow (Max Entropy)': 16.45620889204438,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  94: {'Start Index': 19,
#   'End Index': 41,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000697056321470949,
#   'O-D Flow (Max Entropy)': 11.23970040009346,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  95: {'Start Index': 19,
#   'End Index': 44,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004873121203427373,
#   'O-D Flow (Max Entropy)': 1.4685619716875284,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  96: {'Start Index': 19,
#   'End Index': 48,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0009671033949896796,
#   'O-D Flow (Max Entropy)': 14.20212110935518,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  97: {'Start Index': 19,
#   'End Index': 55,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0013176885527089286,
#   'O-D Flow (Max Entropy)': 10.930621962369647,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  98: {'Start Index': 19,
#   'End Index': 59,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016817222490715924,
#   'O-D Flow (Max Entropy)': 7.139725904203833,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  99: {'Start Index': 19,
#   'End Index': 61,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.002084880450214933,
#   'O-D Flow (Max Entropy)': 10.184554543457171,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  100: {'Start Index': 19,
#   'End Index': 62,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 163.40140213404794,
#   'O-D Flow (Max Entropy)': 61.405460394558204,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  101: {'Start Index': 21,
#   'End Index': 23,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 76.87666351356728,
#   'O-D Flow (Max Entropy)': 45.72305580758106,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  102: {'Start Index': 21,
#   'End Index': 28,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 132.6396184104135,
#   'O-D Flow (Max Entropy)': 76.07437041321302,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  103: {'Start Index': 21,
#   'End Index': 36,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.269844373430182,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  104: {'Start Index': 21,
#   'End Index': 38,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 55.656865628778526,
#   'O-D Flow (Max Entropy)': 50.21377267173915,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  105: {'Start Index': 21,
#   'End Index': 41,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 6.723103641040549,
#   'O-D Flow (Max Entropy)': 34.296648033459505,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  106: {'Start Index': 21,
#   'End Index': 44,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003356329166666293,
#   'O-D Flow (Max Entropy)': 4.482698714546547,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  107: {'Start Index': 21,
#   'End Index': 48,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 20.06569993732254,
#   'O-D Flow (Max Entropy)': 43.33630933969172,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  108: {'Start Index': 21,
#   'End Index': 55,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.58240625449437,
#   'O-D Flow (Max Entropy)': 33.35353515467314,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  109: {'Start Index': 21,
#   'End Index': 59,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.622834780791564,
#   'O-D Flow (Max Entropy)': 21.786222070927916,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  110: {'Start Index': 21,
#   'End Index': 61,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 9.590880272381593,
#   'O-D Flow (Max Entropy)': 31.077026956858685,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  111: {'Start Index': 21,
#   'End Index': 62,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 215.24488308938712,
#   'O-D Flow (Max Entropy)': 187.3739502515164,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  112: {'Start Index': 24,
#   'End Index': 28,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 130.6453891483295,
#   'O-D Flow (Max Entropy)': 65.8275887993488,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  113: {'Start Index': 24,
#   'End Index': 36,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 7.15592210915664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  114: {'Start Index': 24,
#   'End Index': 38,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.51188423666123,
#   'O-D Flow (Max Entropy)': 43.450299249009106,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  115: {'Start Index': 24,
#   'End Index': 41,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 4.57812224892381,
#   'O-D Flow (Max Entropy)': 29.67696219061442,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  116: {'Start Index': 24,
#   'End Index': 44,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.878867544640723,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  117: {'Start Index': 24,
#   'End Index': 48,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 17.920718545205727,
#   'O-D Flow (Max Entropy)': 37.498793406889824,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  118: {'Start Index': 24,
#   'End Index': 55,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 28.86088574402395,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  119: {'Start Index': 24,
#   'End Index': 59,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 2.547068614951268,
#   'O-D Flow (Max Entropy)': 18.85166076178689,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  120: {'Start Index': 24,
#   'End Index': 61,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 2.0859745817154804,
#   'O-D Flow (Max Entropy)': 26.891003996396748,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  121: {'Start Index': 24,
#   'End Index': 62,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 212.94565397284782,
#   'O-D Flow (Max Entropy)': 162.13530879526462,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  122: {'Start Index': 26,
#   'End Index': 28,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 52.89757833352109,
#   'O-D Flow (Max Entropy)': 35.151834865004986,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  123: {'Start Index': 26,
#   'End Index': 36,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.8208848501938064,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  124: {'Start Index': 26,
#   'End Index': 38,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 23.202140197774664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  125: {'Start Index': 26,
#   'End Index': 41,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.847162795361594,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  126: {'Start Index': 26,
#   'End Index': 44,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.070942281529095,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  127: {'Start Index': 26,
#   'End Index': 48,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.024021418085,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  128: {'Start Index': 26,
#   'End Index': 55,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.411397934188646,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  129: {'Start Index': 26,
#   'End Index': 59,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.066574076325914,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  130: {'Start Index': 26,
#   'End Index': 61,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.359504296168554,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  131: {'Start Index': 26,
#   'End Index': 62,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 173.6789019001655,
#   'O-D Flow (Max Entropy)': 86.57833994676545,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  132: {'Start Index': 30,
#   'End Index': 36,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.179981052718745,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  133: {'Start Index': 30,
#   'End Index': 38,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 89.7982635911554,
#   'O-D Flow (Max Entropy)': 49.668109146577706,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  134: {'Start Index': 30,
#   'End Index': 41,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 40.826886582914454,
#   'O-D Flow (Max Entropy)': 33.92392928695852,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  135: {'Start Index': 30,
#   'End Index': 44,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0017600088180856205,
#   'O-D Flow (Max Entropy)': 4.433993221773312,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  136: {'Start Index': 30,
#   'End Index': 48,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 54.169482879196146,
#   'O-D Flow (Max Entropy)': 42.86504918501271,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  137: {'Start Index': 30,
#   'End Index': 55,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 32.991067791027845,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  138: {'Start Index': 30,
#   'End Index': 59,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 21.549476103995875,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  139: {'Start Index': 30,
#   'End Index': 61,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 30.739320062109986,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  140: {'Start Index': 30,
#   'End Index': 62,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 224.90688556541292,
#   'O-D Flow (Max Entropy)': 185.33775718681446,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  141: {'Start Index': 32,
#   'End Index': 36,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 17.565529828455453,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  142: {'Start Index': 32,
#   'End Index': 38,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 169.00945122429835,
#   'O-D Flow (Max Entropy)': 106.65349252959406,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  143: {'Start Index': 32,
#   'End Index': 41,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 120.0756892365596,
#   'O-D Flow (Max Entropy)': 72.84552442733366,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  144: {'Start Index': 32,
#   'End Index': 44,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0027075759340147083,
#   'O-D Flow (Max Entropy)': 9.521692036228606,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  145: {'Start Index': 32,
#   'End Index': 48,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 133.4182855328422,
#   'O-D Flow (Max Entropy)': 92.04486516666124,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  146: {'Start Index': 32,
#   'End Index': 55,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 70.36084088076063,
#   'O-D Flow (Max Entropy)': 70.84238143964212,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  147: {'Start Index': 32,
#   'End Index': 59,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 41.00911841313085,
#   'O-D Flow (Max Entropy)': 46.274396796401234,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  148: {'Start Index': 32,
#   'End Index': 61,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 42.86374542291191,
#   'O-D Flow (Max Entropy)': 66.00709439701639,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  149: {'Start Index': 32,
#   'End Index': 62,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 303.0116318932985,
#   'O-D Flow (Max Entropy)': 397.98158933608806,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  150: {'Start Index': 34,
#   'End Index': 36,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.891408995502232,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  151: {'Start Index': 34,
#   'End Index': 38,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 9.209414382474513,
#   'O-D Flow (Max Entropy)': 23.630281830482005,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  152: {'Start Index': 34,
#   'End Index': 41,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 16.13957553947632,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  153: {'Start Index': 34,
#   'End Index': 44,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002552516375068164,
#   'O-D Flow (Max Entropy)': 2.1091760323877153,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  154: {'Start Index': 34,
#   'End Index': 48,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.39350775268446,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  155: {'Start Index': 34,
#   'End Index': 55,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.69577144719794,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  156: {'Start Index': 34,
#   'End Index': 59,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.252333105150312,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  157: {'Start Index': 34,
#   'End Index': 61,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.624467769935757,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  158: {'Start Index': 34,
#   'End Index': 62,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 185.74258913871716,
#   'O-D Flow (Max Entropy)': 88.17610831888322,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  159: {'Start Index': 39,
#   'End Index': 41,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.21315794821089,
#   'O-D Flow (Max Entropy)': 32.892418220407336,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  160: {'Start Index': 39,
#   'End Index': 44,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004291525526194608,
#   'O-D Flow (Max Entropy)': 4.299156372181855,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  161: {'Start Index': 39,
#   'End Index': 48,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 66.1765063988034,
#   'O-D Flow (Max Entropy)': 41.561657960501115,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  162: {'Start Index': 39,
#   'End Index': 55,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.066154822650771,
#   'O-D Flow (Max Entropy)': 31.987917947057372,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  163: {'Start Index': 39,
#   'End Index': 59,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0012759304473504136,
#   'O-D Flow (Max Entropy)': 20.89422090151865,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  164: {'Start Index': 39,
#   'End Index': 61,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016780165039376102,
#   'O-D Flow (Max Entropy)': 29.80463689397558,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  165: {'Start Index': 39,
#   'End Index': 62,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 218.6791408483991,
#   'O-D Flow (Max Entropy)': 179.7021971948997,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  166: {'Start Index': 42,
#   'End Index': 44,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032912531410064566,
#   'O-D Flow (Max Entropy)': 6.131364060854139,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  167: {'Start Index': 42,
#   'End Index': 48,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 110.62977327490029,
#   'O-D Flow (Max Entropy)': 59.273100012715915,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  168: {'Start Index': 42,
#   'End Index': 55,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 47.48616521173347,
#   'O-D Flow (Max Entropy)': 45.620078851740445,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  169: {'Start Index': 42,
#   'End Index': 59,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0006695751803973039,
#   'O-D Flow (Max Entropy)': 29.7985770769594,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  170: {'Start Index': 42,
#   'End Index': 61,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.989069753884777,
#   'O-D Flow (Max Entropy)': 42.506108449898065,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  171: {'Start Index': 42,
#   'End Index': 62,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 261.5057143953829,
#   'O-D Flow (Max Entropy)': 256.2854550120548,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773964618167794,
#   'O-D Flow (Max Entropy)': 12.3355181881873,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.01412552337074811,
#   'O-D Flow (Max Entropy)': 9.49400834632596,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406029354183,
#   'O-D Flow (Max Entropy)': 6.201257219343068,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909370534536233,
#   'O-D Flow (Max Entropy)': 8.845980374770239,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534587726388,
#   'O-D Flow (Max Entropy)': 53.33588101319014,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.10789210160277,
#   'O-D Flow (Max Entropy)': 74.20246282234035,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037465853,
#   'O-D Flow (Max Entropy)': 48.46926736758839,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151396612,
#   'O-D Flow (Max Entropy)': 69.13785987139363,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934661554519,
#   'O-D Flow (Max Entropy)': 416.85793008435695,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278065052,
#   'O-D Flow (Max Entropy)': 55.98621571035147,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377376889,
#   'O-D Flow (Max Entropy)': 36.57007664264351,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.166731545050844,
#   'O-D Flow (Max Entropy)': 52.165054861799376,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.68337618655505,
#   'O-D Flow (Max Entropy)': 314.52376767483895,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.28398568530136,
#   'O-D Flow (Max Entropy)': 72.76486228168181,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.9536872820199,
#   'O-D Flow (Max Entropy)': 47.53017262697266,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745096037,
#   'O-D Flow (Max Entropy)': 67.79837653213843,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.07701209245874,
#   'O-D Flow (Max Entropy)': 408.78164106994745,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031221727018,
#   'O-D Flow (Max Entropy)': 57.61476844332287,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.49027099930663,
#   'O-D Flow (Max Entropy)': 82.1825203892005,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.8840620069468,
#   'O-D Flow (Max Entropy)': 495.50735639100026,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'}}

# %%
dict_od_data_to_save_2 = {}
dict_od_data_to_save_2["Data Category"] \
    = ["Start Index", "End Index", "Start Station", "End Station", "Start City", "End City", \
       "O-D Flow (Initialization)", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)"]

for od_index in list(dict_df_od_flow_data.keys()):
    dict_od_data_to_save_2[od_index] = []
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start Index"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End Index"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start Station"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End Station"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start City"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End City"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Initialization)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (eligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (eligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 2)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 2)"]]

# %%
# dict_od_data_to_save_2

directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_data_to_save_2 = pd.DataFrame(dict_od_data_to_save_2)
df_od_data_to_save_2.to_csv(directory_path + 'data_od_VoTs_demands_2.csv', index = False)

# %% [markdown]
# # Demands (One Edge Per City)

# %% [markdown]
# ## Case 1: (2 eligible groups, 3 ineligible groups)

# %%
# dict_df_od_flow_data

# %%
od_cities_list = []
for key, od_info in dict_df_od_flow_data.items():
    if [od_info["Start City"], od_info["End City"]] not in od_cities_list:
        od_cities_list += [[od_info["Start City"], od_info["End City"]]]

od_flow_cities_max_entr = np.zeros(len(od_cities_list))
for key, od_info in dict_df_od_flow_data.items():
    od_cities_index = od_cities_list.index([od_info["Start City"], od_info["End City"]])
    od_flow_cities_max_entr[od_cities_index] += od_info["O-D Flow (Max Entropy)"]
    

print("od_cities_list:", od_cities_list)
print()
print("od_flow_cities_max_entr:", od_flow_cities_max_entr)
# Out:
# od_cities_list: [['Palo Alto', 'Palo Alto'], ['Palo Alto', 'East Palo Alto'], ['Palo Alto', 'Redwood City'], ['Palo Alto', 'Belmont'], ['Palo Alto', 'San Mateo'], ['Palo Alto', 'Burlingame'], ['Palo Alto', 'Millbrae'], ['East Palo Alto', 'Redwood City'], ['East Palo Alto', 'Belmont'], ['East Palo Alto', 'San Mateo'], ['East Palo Alto', 'Burlingame'], ['East Palo Alto', 'Millbrae'], ['Redwood City', 'Belmont'], ['Redwood City', 'San Mateo'], ['Redwood City', 'Burlingame'], ['Redwood City', 'Millbrae'], ['Belmont', 'San Mateo'], ['Belmont', 'Burlingame'], ['Belmont', 'Millbrae'], ['San Mateo', 'San Mateo'], ['San Mateo', 'Burlingame'], ['San Mateo', 'Millbrae'], ['Burlingame', 'Millbrae'], ['Millbrae', 'Millbrae']]
#
# od_flow_cities_max_entr: [ 612.53961694   98.03491986 1138.00806866  255.87641049  970.06350237
#   242.5147334  1531.06638078  258.18089759   58.05005537  220.06789713
#    55.01934233  347.34863924  146.51429066  555.44073566  138.86560383
#   876.70137267  230.08260488   57.52281482  363.15467555  391.88563258
#   268.47369827 1694.94808304 1067.91263504 1232.17969773]

# %%
dict_df_od_flow_data
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.539616936298,
#   'O-D Flow (Max Entropy)': 612.539616936298,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto'},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.02842969746226,
#   'O-D Flow (Max Entropy)': 80.19045260172992,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.21104560854025,
#   'O-D Flow (Max Entropy)': 413.6495858413996,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217997502863,
#   'O-D Flow (Max Entropy)': 517.2177492843396,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.44612634033228,
#   'O-D Flow (Max Entropy)': 209.30114967791195,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.39336877576807,
#   'O-D Flow (Max Entropy)': 348.2467008641436,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.01367510128861,
#   'O-D Flow (Max Entropy)': 37.860514534190564,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.63571900479022,
#   'O-D Flow (Max Entropy)': 229.8646608025822,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.78201958831744,
#   'O-D Flow (Max Entropy)': 156.99625166997893,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436350256,
#   'O-D Flow (Max Entropy)': 20.52905029219567,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974006398,
#   'O-D Flow (Max Entropy)': 198.37149432605494,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.00842462083335,
#   'O-D Flow (Max Entropy)': 152.67891882581497,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.71158987155542,
#   'O-D Flow (Max Entropy)': 99.72718407391667,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375188904,
#   'O-D Flow (Max Entropy)': 142.25775753230835,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.72922631760076,
#   'O-D Flow (Max Entropy)': 857.7160571545749,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490165905821027,
#   'O-D Flow (Max Entropy)': 17.844467261638155,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897818557937,
#   'O-D Flow (Max Entropy)': 92.04654838648104,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.20053599754033,
#   'O-D Flow (Max Entropy)': 115.09418514350136,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.813417511788266,
#   'O-D Flow (Max Entropy)': 46.57526081630505,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624204764,
#   'O-D Flow (Max Entropy)': 77.49149049917995,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571269596,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489042881028074,
#   'O-D Flow (Max Entropy)': 51.14923184657617,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.738893898300925e-05,
#   'O-D Flow (Max Entropy)': 34.93550462429403,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0043795064128136,
#   'O-D Flow (Max Entropy)': 4.566207664736659,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.741895858479324,
#   'O-D Flow (Max Entropy)': 44.14323906987277,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.221691887554826,
#   'O-D Flow (Max Entropy)': 33.974821450749424,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122126079,
#   'O-D Flow (Max Entropy)': 22.192000339235506,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.116586547656297,
#   'O-D Flow (Max Entropy)': 31.65589811766146,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.4762189636408,
#   'O-D Flow (Max Entropy)': 190.86374328265674,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581043829,
#   'O-D Flow (Max Entropy)': 31.42046242741641,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.882852733289326,
#   'O-D Flow (Max Entropy)': 39.28808280167192,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823076939408,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011146195222578345,
#   'O-D Flow (Max Entropy)': 26.451979741660878,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.8750509114018827,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0002637732790534185,
#   'O-D Flow (Max Entropy)': 17.459738652877096,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.925127314864811,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0012777350014209995,
#   'O-D Flow (Max Entropy)': 1.5581574227592943,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.068203959225531,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123544749855,
#   'O-D Flow (Max Entropy)': 11.597200229945047,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.771041909144758,
#   'O-D Flow (Max Entropy)': 7.575108690332761,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.311510645634552,
#   'O-D Flow (Max Entropy)': 10.805636142115725,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.80398130682082,
#   'O-D Flow (Max Entropy)': 65.15065614753317,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277858517939,
#   'O-D Flow (Max Entropy)': 54.916421020820955,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.01693277464443,
#   'O-D Flow (Max Entropy)': 68.66669331850726,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.786880754177904,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0011717563116433972,
#   'O-D Flow (Max Entropy)': 46.23226244080016,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.0255805897047585,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0003209100698846976,
#   'O-D Flow (Max Entropy)': 30.516086525290536,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243038725,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0014863361082006613,
#   'O-D Flow (Max Entropy)': 2.724047399123207,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449282449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.2645858237607364,
#   'O-D Flow (Max Entropy)': 20.26950370115961,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.805615892154279,
#   'O-D Flow (Max Entropy)': 13.239865933338049,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384262711,
#   'O-D Flow (Max Entropy)': 18.88601804571517,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.64406248440758,
#   'O-D Flow (Max Entropy)': 113.87033808551647,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.0008902776788274977,
#   'O-D Flow (Max Entropy)': 28.39019172812698,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363558756599,
#   'O-D Flow (Max Entropy)': 35.49904629530624,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.364943848148798,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203423669012125,
#   'O-D Flow (Max Entropy)': 23.900868897153714,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.5976517193859276,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0013525774258009015,
#   'O-D Flow (Max Entropy)': 15.775857999295344,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  61: {'Start Index': 10,
#   'End Index': 41,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.775041902292813,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  62: {'Start Index': 10,
#   'End Index': 44,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0028260612912363128,
#   'O-D Flow (Max Entropy)': 1.407803184625391,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  63: {'Start Index': 10,
#   'End Index': 48,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 13.614973874797407,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  64: {'Start Index': 10,
#   'End Index': 55,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.675449695299628,
#   'O-D Flow (Max Entropy)': 10.478738375164713,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  65: {'Start Index': 10,
#   'End Index': 59,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 12.429368059694482,
#   'O-D Flow (Max Entropy)': 6.844509524495882,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  66: {'Start Index': 10,
#   'End Index': 61,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 12.96983679618438,
#   'O-D Flow (Max Entropy)': 9.763506317809803,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  67: {'Start Index': 10,
#   'End Index': 62,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 170.4623074573709,
#   'O-D Flow (Max Entropy)': 58.86755804990479,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  68: {'Start Index': 15,
#   'End Index': 23,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 145.30097933241564,
#   'O-D Flow (Max Entropy)': 80.93831702052893,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  69: {'Start Index': 15,
#   'End Index': 28,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 201.35654360137846,
#   'O-D Flow (Max Entropy)': 134.66678898781961,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  70: {'Start Index': 15,
#   'End Index': 36,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.639505369145454,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  71: {'Start Index': 15,
#   'End Index': 38,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.44077343556827,
#   'O-D Flow (Max Entropy)': 88.887964919763,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  72: {'Start Index': 15,
#   'End Index': 41,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 75.50701144783005,
#   'O-D Flow (Max Entropy)': 60.71162037315181,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  73: {'Start Index': 15,
#   'End Index': 44,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032014571240124275,
#   'O-D Flow (Max Entropy)': 7.935526161187877,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  74: {'Start Index': 15,
#   'End Index': 48,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 88.84960774411076,
#   'O-D Flow (Max Entropy)': 76.71286040897309,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  75: {'Start Index': 15,
#   'End Index': 55,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 25.792163092030695,
#   'O-D Flow (Max Entropy)': 59.0422066484566,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  76: {'Start Index': 15,
#   'End Index': 59,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 19.242379890974775,
#   'O-D Flow (Max Entropy)': 38.56617712224913,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  77: {'Start Index': 15,
#   'End Index': 61,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.369809489346785,
#   'O-D Flow (Max Entropy)': 55.012841926091816,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  78: {'Start Index': 15,
#   'End Index': 62,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 248.94876198417762,
#   'O-D Flow (Max Entropy)': 331.6930843243241,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  79: {'Start Index': 17,
#   'End Index': 23,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.00516902420500707,
#   'O-D Flow (Max Entropy)': 4.868485418378846,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  80: {'Start Index': 17,
#   'End Index': 28,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.007681158488132835,
#   'O-D Flow (Max Entropy)': 8.100388099725038,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  81: {'Start Index': 17,
#   'End Index': 36,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 0.880036359617237,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  82: {'Start Index': 17,
#   'End Index': 38,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.006830133362902665,
#   'O-D Flow (Max Entropy)': 5.346710542578309,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  83: {'Start Index': 17,
#   'End Index': 41,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00441850440081367,
#   'O-D Flow (Max Entropy)': 3.651722210127523,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  84: {'Start Index': 17,
#   'End Index': 44,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.008210239662192432,
#   'O-D Flow (Max Entropy)': 0.47726943213837064,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  85: {'Start Index': 17,
#   'End Index': 48,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.004688281720991468,
#   'O-D Flow (Max Entropy)': 4.614312976281366,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  86: {'Start Index': 17,
#   'End Index': 55,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005032937390121489,
#   'O-D Flow (Max Entropy)': 3.5512911504518674,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  87: {'Start Index': 17,
#   'End Index': 59,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005396482850941245,
#   'O-D Flow (Max Entropy)': 2.3193805597423256,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  88: {'Start Index': 17,
#   'End Index': 61,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005799984026906839,
#   'O-D Flow (Max Entropy)': 3.308855916554572,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  89: {'Start Index': 17,
#   'End Index': 62,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 57.02601787432584,
#   'O-D Flow (Max Entropy)': 19.956437788338075,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  90: {'Start Index': 19,
#   'End Index': 23,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0014474192547626562,
#   'O-D Flow (Max Entropy)': 14.984432416953295,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  91: {'Start Index': 19,
#   'End Index': 28,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 12.251958842638135,
#   'O-D Flow (Max Entropy)': 24.931639644855945,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  92: {'Start Index': 19,
#   'End Index': 36,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.7097580849570684,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  93: {'Start Index': 19,
#   'End Index': 38,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003108710237822861,
#   'O-D Flow (Max Entropy)': 16.45620889204438,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  94: {'Start Index': 19,
#   'End Index': 41,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000697056321470949,
#   'O-D Flow (Max Entropy)': 11.23970040009346,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  95: {'Start Index': 19,
#   'End Index': 44,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004873121203427373,
#   'O-D Flow (Max Entropy)': 1.4685619716875284,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  96: {'Start Index': 19,
#   'End Index': 48,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0009671033949896796,
#   'O-D Flow (Max Entropy)': 14.20212110935518,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  97: {'Start Index': 19,
#   'End Index': 55,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0013176885527089286,
#   'O-D Flow (Max Entropy)': 10.930621962369647,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  98: {'Start Index': 19,
#   'End Index': 59,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016817222490715924,
#   'O-D Flow (Max Entropy)': 7.139725904203833,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  99: {'Start Index': 19,
#   'End Index': 61,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.002084880450214933,
#   'O-D Flow (Max Entropy)': 10.184554543457171,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  100: {'Start Index': 19,
#   'End Index': 62,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 163.40140213404794,
#   'O-D Flow (Max Entropy)': 61.405460394558204,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  101: {'Start Index': 21,
#   'End Index': 23,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 76.87666351356728,
#   'O-D Flow (Max Entropy)': 45.72305580758106,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  102: {'Start Index': 21,
#   'End Index': 28,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 132.6396184104135,
#   'O-D Flow (Max Entropy)': 76.07437041321302,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  103: {'Start Index': 21,
#   'End Index': 36,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.269844373430182,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  104: {'Start Index': 21,
#   'End Index': 38,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 55.656865628778526,
#   'O-D Flow (Max Entropy)': 50.21377267173915,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  105: {'Start Index': 21,
#   'End Index': 41,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 6.723103641040549,
#   'O-D Flow (Max Entropy)': 34.296648033459505,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  106: {'Start Index': 21,
#   'End Index': 44,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003356329166666293,
#   'O-D Flow (Max Entropy)': 4.482698714546547,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  107: {'Start Index': 21,
#   'End Index': 48,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 20.06569993732254,
#   'O-D Flow (Max Entropy)': 43.33630933969172,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  108: {'Start Index': 21,
#   'End Index': 55,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.58240625449437,
#   'O-D Flow (Max Entropy)': 33.35353515467314,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  109: {'Start Index': 21,
#   'End Index': 59,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.622834780791564,
#   'O-D Flow (Max Entropy)': 21.786222070927916,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  110: {'Start Index': 21,
#   'End Index': 61,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 9.590880272381593,
#   'O-D Flow (Max Entropy)': 31.077026956858685,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  111: {'Start Index': 21,
#   'End Index': 62,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 215.24488308938712,
#   'O-D Flow (Max Entropy)': 187.3739502515164,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  112: {'Start Index': 24,
#   'End Index': 28,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 130.6453891483295,
#   'O-D Flow (Max Entropy)': 65.8275887993488,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  113: {'Start Index': 24,
#   'End Index': 36,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 7.15592210915664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  114: {'Start Index': 24,
#   'End Index': 38,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.51188423666123,
#   'O-D Flow (Max Entropy)': 43.450299249009106,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  115: {'Start Index': 24,
#   'End Index': 41,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 4.57812224892381,
#   'O-D Flow (Max Entropy)': 29.67696219061442,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  116: {'Start Index': 24,
#   'End Index': 44,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.878867544640723,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  117: {'Start Index': 24,
#   'End Index': 48,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 17.920718545205727,
#   'O-D Flow (Max Entropy)': 37.498793406889824,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  118: {'Start Index': 24,
#   'End Index': 55,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 28.86088574402395,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  119: {'Start Index': 24,
#   'End Index': 59,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 2.547068614951268,
#   'O-D Flow (Max Entropy)': 18.85166076178689,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  120: {'Start Index': 24,
#   'End Index': 61,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 2.0859745817154804,
#   'O-D Flow (Max Entropy)': 26.891003996396748,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  121: {'Start Index': 24,
#   'End Index': 62,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 212.94565397284782,
#   'O-D Flow (Max Entropy)': 162.13530879526462,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  122: {'Start Index': 26,
#   'End Index': 28,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 52.89757833352109,
#   'O-D Flow (Max Entropy)': 35.151834865004986,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  123: {'Start Index': 26,
#   'End Index': 36,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.8208848501938064,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  124: {'Start Index': 26,
#   'End Index': 38,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 23.202140197774664,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  125: {'Start Index': 26,
#   'End Index': 41,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.847162795361594,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  126: {'Start Index': 26,
#   'End Index': 44,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.070942281529095,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  127: {'Start Index': 26,
#   'End Index': 48,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.024021418085,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  128: {'Start Index': 26,
#   'End Index': 55,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.411397934188646,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  129: {'Start Index': 26,
#   'End Index': 59,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.066574076325914,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  130: {'Start Index': 26,
#   'End Index': 61,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.359504296168554,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  131: {'Start Index': 26,
#   'End Index': 62,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 173.6789019001655,
#   'O-D Flow (Max Entropy)': 86.57833994676545,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  132: {'Start Index': 30,
#   'End Index': 36,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.179981052718745,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  133: {'Start Index': 30,
#   'End Index': 38,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 89.7982635911554,
#   'O-D Flow (Max Entropy)': 49.668109146577706,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  134: {'Start Index': 30,
#   'End Index': 41,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 40.826886582914454,
#   'O-D Flow (Max Entropy)': 33.92392928695852,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  135: {'Start Index': 30,
#   'End Index': 44,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0017600088180856205,
#   'O-D Flow (Max Entropy)': 4.433993221773312,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  136: {'Start Index': 30,
#   'End Index': 48,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 54.169482879196146,
#   'O-D Flow (Max Entropy)': 42.86504918501271,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  137: {'Start Index': 30,
#   'End Index': 55,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 32.991067791027845,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  138: {'Start Index': 30,
#   'End Index': 59,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 21.549476103995875,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  139: {'Start Index': 30,
#   'End Index': 61,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 30.739320062109986,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  140: {'Start Index': 30,
#   'End Index': 62,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 224.90688556541292,
#   'O-D Flow (Max Entropy)': 185.33775718681446,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  141: {'Start Index': 32,
#   'End Index': 36,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 17.565529828455453,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  142: {'Start Index': 32,
#   'End Index': 38,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 169.00945122429835,
#   'O-D Flow (Max Entropy)': 106.65349252959406,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  143: {'Start Index': 32,
#   'End Index': 41,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 120.0756892365596,
#   'O-D Flow (Max Entropy)': 72.84552442733366,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  144: {'Start Index': 32,
#   'End Index': 44,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0027075759340147083,
#   'O-D Flow (Max Entropy)': 9.521692036228606,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  145: {'Start Index': 32,
#   'End Index': 48,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 133.4182855328422,
#   'O-D Flow (Max Entropy)': 92.04486516666124,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  146: {'Start Index': 32,
#   'End Index': 55,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 70.36084088076063,
#   'O-D Flow (Max Entropy)': 70.84238143964212,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  147: {'Start Index': 32,
#   'End Index': 59,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 41.00911841313085,
#   'O-D Flow (Max Entropy)': 46.274396796401234,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  148: {'Start Index': 32,
#   'End Index': 61,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 42.86374542291191,
#   'O-D Flow (Max Entropy)': 66.00709439701639,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  149: {'Start Index': 32,
#   'End Index': 62,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 303.0116318932985,
#   'O-D Flow (Max Entropy)': 397.98158933608806,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  150: {'Start Index': 34,
#   'End Index': 36,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.891408995502232,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  151: {'Start Index': 34,
#   'End Index': 38,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 9.209414382474513,
#   'O-D Flow (Max Entropy)': 23.630281830482005,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  152: {'Start Index': 34,
#   'End Index': 41,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 16.13957553947632,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  153: {'Start Index': 34,
#   'End Index': 44,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002552516375068164,
#   'O-D Flow (Max Entropy)': 2.1091760323877153,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  154: {'Start Index': 34,
#   'End Index': 48,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.39350775268446,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  155: {'Start Index': 34,
#   'End Index': 55,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.69577144719794,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  156: {'Start Index': 34,
#   'End Index': 59,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.252333105150312,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  157: {'Start Index': 34,
#   'End Index': 61,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.624467769935757,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  158: {'Start Index': 34,
#   'End Index': 62,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 185.74258913871716,
#   'O-D Flow (Max Entropy)': 88.17610831888322,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  159: {'Start Index': 39,
#   'End Index': 41,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.21315794821089,
#   'O-D Flow (Max Entropy)': 32.892418220407336,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  160: {'Start Index': 39,
#   'End Index': 44,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004291525526194608,
#   'O-D Flow (Max Entropy)': 4.299156372181855,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  161: {'Start Index': 39,
#   'End Index': 48,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 66.1765063988034,
#   'O-D Flow (Max Entropy)': 41.561657960501115,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  162: {'Start Index': 39,
#   'End Index': 55,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.066154822650771,
#   'O-D Flow (Max Entropy)': 31.987917947057372,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  163: {'Start Index': 39,
#   'End Index': 59,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0012759304473504136,
#   'O-D Flow (Max Entropy)': 20.89422090151865,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  164: {'Start Index': 39,
#   'End Index': 61,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0016780165039376102,
#   'O-D Flow (Max Entropy)': 29.80463689397558,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  165: {'Start Index': 39,
#   'End Index': 62,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 218.6791408483991,
#   'O-D Flow (Max Entropy)': 179.7021971948997,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  166: {'Start Index': 42,
#   'End Index': 44,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0032912531410064566,
#   'O-D Flow (Max Entropy)': 6.131364060854139,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  167: {'Start Index': 42,
#   'End Index': 48,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 110.62977327490029,
#   'O-D Flow (Max Entropy)': 59.273100012715915,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  168: {'Start Index': 42,
#   'End Index': 55,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 47.48616521173347,
#   'O-D Flow (Max Entropy)': 45.620078851740445,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  169: {'Start Index': 42,
#   'End Index': 59,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0006695751803973039,
#   'O-D Flow (Max Entropy)': 29.7985770769594,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  170: {'Start Index': 42,
#   'End Index': 61,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.989069753884777,
#   'O-D Flow (Max Entropy)': 42.506108449898065,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  171: {'Start Index': 42,
#   'End Index': 62,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 261.5057143953829,
#   'O-D Flow (Max Entropy)': 256.2854550120548,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773964618167794,
#   'O-D Flow (Max Entropy)': 12.3355181881873,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.01412552337074811,
#   'O-D Flow (Max Entropy)': 9.49400834632596,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406029354183,
#   'O-D Flow (Max Entropy)': 6.201257219343068,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909370534536233,
#   'O-D Flow (Max Entropy)': 8.845980374770239,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534587726388,
#   'O-D Flow (Max Entropy)': 53.33588101319014,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.10789210160277,
#   'O-D Flow (Max Entropy)': 74.20246282234035,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037465853,
#   'O-D Flow (Max Entropy)': 48.46926736758839,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151396612,
#   'O-D Flow (Max Entropy)': 69.13785987139363,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934661554519,
#   'O-D Flow (Max Entropy)': 416.85793008435695,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278065052,
#   'O-D Flow (Max Entropy)': 55.98621571035147,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377376889,
#   'O-D Flow (Max Entropy)': 36.57007664264351,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.166731545050844,
#   'O-D Flow (Max Entropy)': 52.165054861799376,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.68337618655505,
#   'O-D Flow (Max Entropy)': 314.52376767483895,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.28398568530136,
#   'O-D Flow (Max Entropy)': 72.76486228168181,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.9536872820199,
#   'O-D Flow (Max Entropy)': 47.53017262697266,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745096037,
#   'O-D Flow (Max Entropy)': 67.79837653213843,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.07701209245874,
#   'O-D Flow (Max Entropy)': 408.78164106994745,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031221727018,
#   'O-D Flow (Max Entropy)': 57.61476844332287,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.49027099930663,
#   'O-D Flow (Max Entropy)': 82.1825203892005,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.8840620069468,
#   'O-D Flow (Max Entropy)': 495.50735639100026,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'}}

# %%
od_cities_dict = {}

for index, od_cities in enumerate(od_cities_list):
    od_cities_dict[index] = {}
    od_cities_dict[index]["Start City Index"] = cities_list.index(od_cities[0])
    od_cities_dict[index]["End City Index"] = cities_list.index(od_cities[1])
    od_cities_dict[index]["Start City"] = od_cities_list[index][0]
    od_cities_dict[index]["End City"] = od_cities_list[index][1]
    od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"] = od_flow_cities_max_entr[index]

od_cities_dict
# Out:
# {0: {'Start City Index': 0,
#   'End City Index': 0,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto',
#   'O-D Flow (Max Entropy, Sum)': 612.539616936298},
#  1: {'Start City Index': 0,
#   'End City Index': 1,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'O-D Flow (Max Entropy, Sum)': 98.03491986336807},
#  2: {'Start City Index': 0,
#   'End City Index': 3,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'O-D Flow (Max Entropy, Sum)': 1138.0080686557217},
#  3: {'Start City Index': 0,
#   'End City Index': 4,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': 255.876410494217},
#  4: {'Start City Index': 0,
#   'End City Index': 5,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': 970.0635023691473},
#  5: {'Start City Index': 0,
#   'End City Index': 6,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': 242.51473339592772},
#  6: {'Start City Index': 0,
#   'End City Index': 7,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 1531.066380776918},
#  7: {'Start City Index': 1,
#   'End City Index': 3,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'O-D Flow (Max Entropy, Sum)': 258.18089759184977},
#  8: {'Start City Index': 1,
#   'End City Index': 4,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': 58.05005537172078},
#  9: {'Start City Index': 1,
#   'End City Index': 5,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': 220.06789713162306},
#  10: {'Start City Index': 1,
#   'End City Index': 6,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': 55.01934232684743},
#  11: {'Start City Index': 1,
#   'End City Index': 7,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 347.3486392430312},
#  12: {'Start City Index': 3,
#   'End City Index': 4,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': 146.51429066344213},
#  13: {'Start City Index': 3,
#   'End City Index': 5,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': 555.440735655281},
#  14: {'Start City Index': 3,
#   'End City Index': 6,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': 138.86560383430134},
#  15: {'Start City Index': 3,
#   'End City Index': 7,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 876.7013726747734},
#  16: {'Start City Index': 4,
#   'End City Index': 5,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': 230.0826048826338},
#  17: {'Start City Index': 4,
#   'End City Index': 6,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': 57.52281482497482},
#  18: {'Start City Index': 4,
#   'End City Index': 7,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 363.15467555092073},
#  19: {'Start City Index': 5,
#   'End City Index': 5,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': 391.88563258093166},
#  20: {'Start City Index': 5,
#   'End City Index': 6,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': 268.4736982657627},
#  21: {'Start City Index': 5,
#   'End City Index': 7,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 1694.9480830359967},
#  22: {'Start City Index': 6,
#   'End City Index': 7,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 1067.9126350353126},
#  23: {'Start City Index': 7,
#   'End City Index': 7,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': 1232.179697734264}}

# %%
od_cities_dict_augmented_1 = copy.deepcopy(od_cities_dict)

# %%
for od_index in list(od_cities_dict.keys()):
#     od_cities_dict_augmented_1[]

    start_city_name = od_cities_dict[od_index]["Start City"]
    demand_total_od = od_cities_dict[od_index]["O-D Flow (Max Entropy, Sum)"]
    
    od_cities_dict_augmented_1[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][0] / 100
    od_cities_dict_augmented_1[od_index]["VoT (eligible group, 1)"] = dict_VoT_1[start_city_name][0]
    od_cities_dict_augmented_1[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][1] / 100
    od_cities_dict_augmented_1[od_index]["VoT (eligible group, 2)"] = dict_VoT_1[start_city_name][1]
    
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][2] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 1)"] = dict_VoT_1[start_city_name][2]
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][3] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 2)"] = dict_VoT_1[start_city_name][3]
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][4] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 3)"] = dict_VoT_1[start_city_name][4]

# %%
dict_od_cities_data_to_save_1 = {}
dict_od_cities_data_to_save_1["Data Category"] \
    = ["Start City Index", "End City Index", "Start City", "End City", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for index, od_cities in enumerate(od_cities_list):
    dict_od_cities_data_to_save_1[index] = []
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["Start City Index"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["End City Index"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["Start City"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["End City"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (eligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (eligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (eligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (eligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 3)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 3)"]]

# %%
# for value in dict_od_cities_data_to_save_1.values():
#     print(len(value))

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_cities_data_to_save_1 = pd.DataFrame(dict_od_cities_data_to_save_1)
df_od_cities_data_to_save_1.to_csv(directory_path + 'data_cities_od_VoTs_demands_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
od_cities_dict_augmented_2 = copy.deepcopy(od_cities_dict)

# %%
for od_index in list(od_cities_dict.keys()):
#     od_cities_dict_augmented_2[]

    start_city_name = od_cities_dict[od_index]["Start City"]
    demand_total_od = od_cities_dict[od_index]["O-D Flow (Max Entropy, Sum)"]
    
    od_cities_dict_augmented_2[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][0] / 100
    od_cities_dict_augmented_2[od_index]["VoT (eligible group, 1)"] = dict_VoT_2[start_city_name][0]
    
    od_cities_dict_augmented_2[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][1] / 100
    od_cities_dict_augmented_2[od_index]["VoT (ineligible group, 1)"] = dict_VoT_2[start_city_name][1]
    od_cities_dict_augmented_2[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][2] / 100
    od_cities_dict_augmented_2[od_index]["VoT (ineligible group, 2)"] = dict_VoT_2[start_city_name][2]

# %%
dict_od_cities_data_to_save_2 = {}
dict_od_cities_data_to_save_2["Data Category"] \
    = ["Start City Index", "End City Index", "Start City", "End City", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)"]

for index, od_cities in enumerate(od_cities_list):
    dict_od_cities_data_to_save_2[index] = []
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["Start City Index"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["End City Index"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["Start City"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["End City"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (eligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (eligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (ineligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (ineligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (ineligible group, 2)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (ineligible group, 2)"]]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_cities_data_to_save_2 = pd.DataFrame(dict_od_cities_data_to_save_2)
df_od_cities_data_to_save_2.to_csv(directory_path + 'data_cities_od_VoTs_demands_2.csv', index = False)

# %% [markdown]
# # Scratch Work

# %%
ell = [1, 2, 3, 4, 5]
# ell[1:-1]
ell += [6]
ell
