# %%
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib.axes as axe
import pandas as pd
import datetime as dt
import gurobipy as gp
from gurobipy import GRB
import cvxpy as cp
import yaml
import copy

import random
from itertools import chain, combinations, tee
import time

import os

# %% [markdown]
# # Functions

# %%
str_1 = "027___403206_Redwood_City___off"
"Redwood_City" in str_1
# Out:
# True

# %%
def station_to_city(station_name):
    if "East_Palo_Alto" in station_name:
        city_name = "East Palo Alto"
    elif "Palo_Alto" in station_name:
        city_name = "Palo Alto"
    elif "Menlo_Park" in station_name:
        city_name = "Menlo Park"
    elif "Redwood_City" in station_name:
        city_name = "Redwood City"
    elif "Belmont" in station_name:
        city_name = "Belmont"
    elif "San_Mateo" in station_name:
        city_name = "San Mateo"
    elif "Burlingame" in station_name:
        city_name = "Burlingame"
    elif "Millbrae" in station_name:
        city_name = "Millbrae"
    else:
        assert 1 == 0, "There should be no other case."
    return city_name

def income_range_avg(income_range_str):
    
    if income_range_str == "< $10,000":
        mean_income = 10000/2

    elif income_range_str == "$10,000 to $14,999":
        mean_income = (10000 + 15000)/2

    elif income_range_str == "$15,000 to $24,999":
        mean_income = (15000 + 25000)/2

    elif income_range_str == "$25,000 to $34,999":
        mean_income = (25000 + 35000)/2
        
    elif income_range_str == "$35,000 to $49,999":
        mean_income = (35000 + 50000)/2
        
    elif income_range_str == "$50,000 to $74,999":
        mean_income = (50000 + 75000)/2
        
    elif income_range_str == "$75,000 to $99,999":
        mean_income = (75000 + 100000)/2

    elif income_range_str == "$100,000 to $149,999":
        mean_income = (100000 + 150000)/2
    
    elif income_range_str == "$150,000 to $199,999":
        mean_income = (150000 + 200000)/2
    
    else:
        assert 1 == 0, "This case should not occur."
    
    return mean_income

# %% [markdown]
# # Import O-D Flow Data + Income Data:

# %%
directory_path = '../data/pems_flow___101_N_Sep_to_Nov_2024/'
df_od_flow_data = pd.read_csv(directory_path + 'data_od.csv')

dict_df_od_flow_data = {}

for column_name_full in list(df_od_flow_data.columns):
    if column_name_full == "Data Category":
        categories_list = df_od_flow_data[column_name_full].tolist()
    else:
        dict_df_od_flow_data[int(column_name_full)] = {}
        for category_index, category in enumerate(categories_list):
            if category == "Start Index" or category == "End Index":
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = int(df_od_flow_data[column_name_full].tolist()[category_index])
            elif category == "O-D Flow (Initialization)" or category == "O-D Flow (Max Entropy)":
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = float(df_od_flow_data[column_name_full].tolist()[category_index])
            else:
                dict_df_od_flow_data[int(column_name_full)][category] \
                    = df_od_flow_data[column_name_full].tolist()[category_index]
        
        dict_df_od_flow_data[int(column_name_full)]["Start City"] \
            = station_to_city(dict_df_od_flow_data[int(column_name_full)]["Start Station"])
        dict_df_od_flow_data[int(column_name_full)]["End City"] \
            = station_to_city(dict_df_od_flow_data[int(column_name_full)]["End Station"])
        
dict_df_od_flow_data
# dict_df_od_flow_data[0]["O-D Flow (Initialization)"]
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.5396169,
#   'O-D Flow (Max Entropy)': 612.5396169,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto'},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.0284297,
#   'O-D Flow (Max Entropy)': 80.1904526,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.2110456,
#   'O-D Flow (Max Entropy)': 413.6495858,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217998,
#   'O-D Flow (Max Entropy)': 517.2177493,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.4461263,
#   'O-D Flow (Max Entropy)': 209.3011497,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.3933688,
#   'O-D Flow (Max Entropy)': 348.2467009,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.0136751,
#   'O-D Flow (Max Entropy)': 37.86051453,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.635719,
#   'O-D Flow (Max Entropy)': 229.8646608,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.7820196,
#   'O-D Flow (Max Entropy)': 156.9962517,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436,
#   'O-D Flow (Max Entropy)': 20.52905029,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974,
#   'O-D Flow (Max Entropy)': 198.3714943,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.0084246,
#   'O-D Flow (Max Entropy)': 152.6789188,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.7115899,
#   'O-D Flow (Max Entropy)': 99.72718407,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375,
#   'O-D Flow (Max Entropy)': 142.2577575,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.7292263,
#   'O-D Flow (Max Entropy)': 857.7160572,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490166,
#   'O-D Flow (Max Entropy)': 17.84446726,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto'},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897819,
#   'O-D Flow (Max Entropy)': 92.04654839,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.200536,
#   'O-D Flow (Max Entropy)': 115.0941851,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City'},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.81341751,
#   'O-D Flow (Max Entropy)': 46.57526082,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont'},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624,
#   'O-D Flow (Max Entropy)': 77.4914905,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489043,
#   'O-D Flow (Max Entropy)': 51.14923185,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.74e-05,
#   'O-D Flow (Max Entropy)': 34.93550462,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004379506,
#   'O-D Flow (Max Entropy)': 4.566207665,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo'},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.74189586,
#   'O-D Flow (Max Entropy)': 44.14323907,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame'},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.22169189,
#   'O-D Flow (Max Entropy)': 33.97482145,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122,
#   'O-D Flow (Max Entropy)': 22.19200034,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.11658655,
#   'O-D Flow (Max Entropy)': 31.65589812,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.476219,
#   'O-D Flow (Max Entropy)': 190.8637433,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae'},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581,
#   'O-D Flow (Max Entropy)': 31.42046243,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.88285273,
#   'O-D Flow (Max Entropy)': 39.2880828,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823077,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00111462,
#   'O-D Flow (Max Entropy)': 26.45197974,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.875050911,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000263773,
#   'O-D Flow (Max Entropy)': 17.45973865,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.92512731,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001277735,
#   'O-D Flow (Max Entropy)': 1.558157423,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.06820396,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123545,
#   'O-D Flow (Max Entropy)': 11.59720023,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.77104191,
#   'O-D Flow (Max Entropy)': 7.57510869,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.31151065,
#   'O-D Flow (Max Entropy)': 10.80563614,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.8039813,
#   'O-D Flow (Max Entropy)': 65.15065615,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277859,
#   'O-D Flow (Max Entropy)': 54.91642102,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.0169328,
#   'O-D Flow (Max Entropy)': 68.66669332,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.78688075,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001171756,
#   'O-D Flow (Max Entropy)': 46.23226244,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.02558059,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00032091,
#   'O-D Flow (Max Entropy)': 30.51608653,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001486336,
#   'O-D Flow (Max Entropy)': 2.724047399,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.264585824,
#   'O-D Flow (Max Entropy)': 20.2695037,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.80561589,
#   'O-D Flow (Max Entropy)': 13.23986593,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384,
#   'O-D Flow (Max Entropy)': 18.88601805,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.6440625,
#   'O-D Flow (Max Entropy)': 113.8703381,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.000890278,
#   'O-D Flow (Max Entropy)': 28.39019173,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363559,
#   'O-D Flow (Max Entropy)': 35.4990463,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City'},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.36494385,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont'},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203424,
#   'O-D Flow (Max Entropy)': 23.9008689,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.597651719,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001352577,
#   'O-D Flow (Max Entropy)': 15.775858,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  61: {'Start Index': 10,
#   'End Index': 41,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.7750419,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  62: {'Start Index': 10,
#   'End Index': 44,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002826061,
#   'O-D Flow (Max Entropy)': 1.407803185,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo'},
#  63: {'Start Index': 10,
#   'End Index': 48,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 13.61497387,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame'},
#  64: {'Start Index': 10,
#   'End Index': 55,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.675449695,
#   'O-D Flow (Max Entropy)': 10.47873838,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  65: {'Start Index': 10,
#   'End Index': 59,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 12.42936806,
#   'O-D Flow (Max Entropy)': 6.844509524,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  66: {'Start Index': 10,
#   'End Index': 61,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 12.9698368,
#   'O-D Flow (Max Entropy)': 9.763506318,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  67: {'Start Index': 10,
#   'End Index': 62,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 170.4623075,
#   'O-D Flow (Max Entropy)': 58.86755805,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae'},
#  68: {'Start Index': 15,
#   'End Index': 23,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 145.3009793,
#   'O-D Flow (Max Entropy)': 80.93831702,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  69: {'Start Index': 15,
#   'End Index': 28,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 201.3565436,
#   'O-D Flow (Max Entropy)': 134.666789,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  70: {'Start Index': 15,
#   'End Index': 36,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.63950537,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  71: {'Start Index': 15,
#   'End Index': 38,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.4407734,
#   'O-D Flow (Max Entropy)': 88.88796492,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  72: {'Start Index': 15,
#   'End Index': 41,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 75.50701145,
#   'O-D Flow (Max Entropy)': 60.71162037,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  73: {'Start Index': 15,
#   'End Index': 44,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003201457,
#   'O-D Flow (Max Entropy)': 7.935526161,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  74: {'Start Index': 15,
#   'End Index': 48,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 88.84960774,
#   'O-D Flow (Max Entropy)': 76.71286041,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  75: {'Start Index': 15,
#   'End Index': 55,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 25.79216309,
#   'O-D Flow (Max Entropy)': 59.04220665,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  76: {'Start Index': 15,
#   'End Index': 59,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 19.24237989,
#   'O-D Flow (Max Entropy)': 38.56617712,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  77: {'Start Index': 15,
#   'End Index': 61,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.36980949,
#   'O-D Flow (Max Entropy)': 55.01284193,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  78: {'Start Index': 15,
#   'End Index': 62,
#   'Start Station': '033___410095_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 248.948762,
#   'O-D Flow (Max Entropy)': 331.6930843,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  79: {'Start Index': 17,
#   'End Index': 23,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.005169024,
#   'O-D Flow (Max Entropy)': 4.868485418,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  80: {'Start Index': 17,
#   'End Index': 28,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.007681158,
#   'O-D Flow (Max Entropy)': 8.1003881,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  81: {'Start Index': 17,
#   'End Index': 36,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 0.88003636,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  82: {'Start Index': 17,
#   'End Index': 38,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.006830133,
#   'O-D Flow (Max Entropy)': 5.346710543,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  83: {'Start Index': 17,
#   'End Index': 41,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004418504,
#   'O-D Flow (Max Entropy)': 3.65172221,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  84: {'Start Index': 17,
#   'End Index': 44,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00821024,
#   'O-D Flow (Max Entropy)': 0.477269432,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  85: {'Start Index': 17,
#   'End Index': 48,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.004688282,
#   'O-D Flow (Max Entropy)': 4.614312976,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  86: {'Start Index': 17,
#   'End Index': 55,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005032937,
#   'O-D Flow (Max Entropy)': 3.55129115,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  87: {'Start Index': 17,
#   'End Index': 59,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005396483,
#   'O-D Flow (Max Entropy)': 2.31938056,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  88: {'Start Index': 17,
#   'End Index': 61,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.005799984,
#   'O-D Flow (Max Entropy)': 3.308855917,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  89: {'Start Index': 17,
#   'End Index': 62,
#   'Start Station': '036___410093_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 57.02601787,
#   'O-D Flow (Max Entropy)': 19.95643779,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  90: {'Start Index': 19,
#   'End Index': 23,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.001447419,
#   'O-D Flow (Max Entropy)': 14.98443242,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  91: {'Start Index': 19,
#   'End Index': 28,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 12.25195884,
#   'O-D Flow (Max Entropy)': 24.93163964,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  92: {'Start Index': 19,
#   'End Index': 36,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.709758085,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  93: {'Start Index': 19,
#   'End Index': 38,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00310871,
#   'O-D Flow (Max Entropy)': 16.45620889,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  94: {'Start Index': 19,
#   'End Index': 41,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000697056,
#   'O-D Flow (Max Entropy)': 11.2397004,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  95: {'Start Index': 19,
#   'End Index': 44,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004873121,
#   'O-D Flow (Max Entropy)': 1.468561972,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  96: {'Start Index': 19,
#   'End Index': 48,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.000967103,
#   'O-D Flow (Max Entropy)': 14.20212111,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  97: {'Start Index': 19,
#   'End Index': 55,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.001317689,
#   'O-D Flow (Max Entropy)': 10.93062196,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  98: {'Start Index': 19,
#   'End Index': 59,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.001681722,
#   'O-D Flow (Max Entropy)': 7.139725904,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  99: {'Start Index': 19,
#   'End Index': 61,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.00208488,
#   'O-D Flow (Max Entropy)': 10.18455454,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  100: {'Start Index': 19,
#   'End Index': 62,
#   'Start Station': '040___412787_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 163.4014021,
#   'O-D Flow (Max Entropy)': 61.40546039,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  101: {'Start Index': 21,
#   'End Index': 23,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 76.87666351,
#   'O-D Flow (Max Entropy)': 45.72305581,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont'},
#  102: {'Start Index': 21,
#   'End Index': 28,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 132.6396184,
#   'O-D Flow (Max Entropy)': 76.07437041,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  103: {'Start Index': 21,
#   'End Index': 36,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.269844373,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  104: {'Start Index': 21,
#   'End Index': 38,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 55.65686563,
#   'O-D Flow (Max Entropy)': 50.21377267,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  105: {'Start Index': 21,
#   'End Index': 41,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 6.723103641,
#   'O-D Flow (Max Entropy)': 34.29664803,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  106: {'Start Index': 21,
#   'End Index': 44,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003356329,
#   'O-D Flow (Max Entropy)': 4.482698715,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo'},
#  107: {'Start Index': 21,
#   'End Index': 48,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 20.06569994,
#   'O-D Flow (Max Entropy)': 43.33630934,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame'},
#  108: {'Start Index': 21,
#   'End Index': 55,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 7.582406254,
#   'O-D Flow (Max Entropy)': 33.35353515,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  109: {'Start Index': 21,
#   'End Index': 59,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.62283478,
#   'O-D Flow (Max Entropy)': 21.78622207,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  110: {'Start Index': 21,
#   'End Index': 61,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 9.590880272,
#   'O-D Flow (Max Entropy)': 31.07702696,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  111: {'Start Index': 21,
#   'End Index': 62,
#   'Start Station': '042___412788_Redwood_City___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 215.2448831,
#   'O-D Flow (Max Entropy)': 187.3739503,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae'},
#  112: {'Start Index': 24,
#   'End Index': 28,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 130.6453891,
#   'O-D Flow (Max Entropy)': 65.8275888,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  113: {'Start Index': 24,
#   'End Index': 36,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 7.155922109,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  114: {'Start Index': 24,
#   'End Index': 38,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.51188424,
#   'O-D Flow (Max Entropy)': 43.45029925,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  115: {'Start Index': 24,
#   'End Index': 41,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 4.578122249,
#   'O-D Flow (Max Entropy)': 29.67696219,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  116: {'Start Index': 24,
#   'End Index': 44,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.878867545,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  117: {'Start Index': 24,
#   'End Index': 48,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 17.92071855,
#   'O-D Flow (Max Entropy)': 37.49879341,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  118: {'Start Index': 24,
#   'End Index': 55,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 28.86088574,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  119: {'Start Index': 24,
#   'End Index': 59,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 2.547068615,
#   'O-D Flow (Max Entropy)': 18.85166076,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  120: {'Start Index': 24,
#   'End Index': 61,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 2.085974582,
#   'O-D Flow (Max Entropy)': 26.891004,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  121: {'Start Index': 24,
#   'End Index': 62,
#   'Start Station': '046___410110_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 212.945654,
#   'O-D Flow (Max Entropy)': 162.1353088,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  122: {'Start Index': 26,
#   'End Index': 28,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 52.89757833,
#   'O-D Flow (Max Entropy)': 35.15183487,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  123: {'Start Index': 26,
#   'End Index': 36,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.82088485,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  124: {'Start Index': 26,
#   'End Index': 38,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 23.2021402,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  125: {'Start Index': 26,
#   'End Index': 41,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.8471628,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  126: {'Start Index': 26,
#   'End Index': 44,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.070942282,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo'},
#  127: {'Start Index': 26,
#   'End Index': 48,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.02402142,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame'},
#  128: {'Start Index': 26,
#   'End Index': 55,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.41139793,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  129: {'Start Index': 26,
#   'End Index': 59,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.06657408,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  130: {'Start Index': 26,
#   'End Index': 61,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.3595043,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  131: {'Start Index': 26,
#   'End Index': 62,
#   'Start Station': '049___414212_Belmont___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 173.6789019,
#   'O-D Flow (Max Entropy)': 86.57833995,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae'},
#  132: {'Start Index': 30,
#   'End Index': 36,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.179981053,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  133: {'Start Index': 30,
#   'End Index': 38,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 89.79826359,
#   'O-D Flow (Max Entropy)': 49.66810915,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  134: {'Start Index': 30,
#   'End Index': 41,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 40.82688658,
#   'O-D Flow (Max Entropy)': 33.92392929,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  135: {'Start Index': 30,
#   'End Index': 44,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001760009,
#   'O-D Flow (Max Entropy)': 4.433993222,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  136: {'Start Index': 30,
#   'End Index': 48,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 54.16948288,
#   'O-D Flow (Max Entropy)': 42.86504919,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  137: {'Start Index': 30,
#   'End Index': 55,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 32.99106779,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  138: {'Start Index': 30,
#   'End Index': 59,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 21.5494761,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  139: {'Start Index': 30,
#   'End Index': 61,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 30.73932006,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  140: {'Start Index': 30,
#   'End Index': 62,
#   'Start Station': '053___409676_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 224.9068856,
#   'O-D Flow (Max Entropy)': 185.3377572,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  141: {'Start Index': 32,
#   'End Index': 36,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 17.56552983,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  142: {'Start Index': 32,
#   'End Index': 38,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 169.0094512,
#   'O-D Flow (Max Entropy)': 106.6534925,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  143: {'Start Index': 32,
#   'End Index': 41,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 120.0756892,
#   'O-D Flow (Max Entropy)': 72.84552443,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  144: {'Start Index': 32,
#   'End Index': 44,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002707576,
#   'O-D Flow (Max Entropy)': 9.521692036,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  145: {'Start Index': 32,
#   'End Index': 48,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 133.4182855,
#   'O-D Flow (Max Entropy)': 92.04486517,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  146: {'Start Index': 32,
#   'End Index': 55,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 70.36084088,
#   'O-D Flow (Max Entropy)': 70.84238144,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  147: {'Start Index': 32,
#   'End Index': 59,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 41.00911841,
#   'O-D Flow (Max Entropy)': 46.2743968,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  148: {'Start Index': 32,
#   'End Index': 61,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 42.86374542,
#   'O-D Flow (Max Entropy)': 66.0070944,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  149: {'Start Index': 32,
#   'End Index': 62,
#   'Start Station': '060___405852_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 303.0116319,
#   'O-D Flow (Max Entropy)': 397.9815893,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  150: {'Start Index': 34,
#   'End Index': 36,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 3.891408996,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  151: {'Start Index': 34,
#   'End Index': 38,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 9.209414382,
#   'O-D Flow (Max Entropy)': 23.63028183,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  152: {'Start Index': 34,
#   'End Index': 41,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 16.13957554,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  153: {'Start Index': 34,
#   'End Index': 44,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002552516,
#   'O-D Flow (Max Entropy)': 2.109176032,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  154: {'Start Index': 34,
#   'End Index': 48,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.39350775,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  155: {'Start Index': 34,
#   'End Index': 55,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.69577145,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  156: {'Start Index': 34,
#   'End Index': 59,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 10.25233311,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  157: {'Start Index': 34,
#   'End Index': 61,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.62446777,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  158: {'Start Index': 34,
#   'End Index': 62,
#   'Start Station': '063___405828_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 185.7425891,
#   'O-D Flow (Max Entropy)': 88.17610832,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  159: {'Start Index': 39,
#   'End Index': 41,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 53.21315795,
#   'O-D Flow (Max Entropy)': 32.89241822,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  160: {'Start Index': 39,
#   'End Index': 44,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004291526,
#   'O-D Flow (Max Entropy)': 4.299156372,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  161: {'Start Index': 39,
#   'End Index': 48,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 66.1765064,
#   'O-D Flow (Max Entropy)': 41.56165796,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  162: {'Start Index': 39,
#   'End Index': 55,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.066154823,
#   'O-D Flow (Max Entropy)': 31.98791795,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  163: {'Start Index': 39,
#   'End Index': 59,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.00127593,
#   'O-D Flow (Max Entropy)': 20.8942209,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  164: {'Start Index': 39,
#   'End Index': 61,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.001678017,
#   'O-D Flow (Max Entropy)': 29.80463689,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  165: {'Start Index': 39,
#   'End Index': 62,
#   'Start Station': '070___405849_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 218.6791408,
#   'O-D Flow (Max Entropy)': 179.7021972,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  166: {'Start Index': 42,
#   'End Index': 44,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.003291253,
#   'O-D Flow (Max Entropy)': 6.131364061,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo'},
#  167: {'Start Index': 42,
#   'End Index': 48,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 110.6297733,
#   'O-D Flow (Max Entropy)': 59.27310001,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  168: {'Start Index': 42,
#   'End Index': 55,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 47.48616521,
#   'O-D Flow (Max Entropy)': 45.62007885,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  169: {'Start Index': 42,
#   'End Index': 59,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.000669575,
#   'O-D Flow (Max Entropy)': 29.79857708,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  170: {'Start Index': 42,
#   'End Index': 61,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 19.98906975,
#   'O-D Flow (Max Entropy)': 42.50610845,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  171: {'Start Index': 42,
#   'End Index': 62,
#   'Start Station': '077___403288_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 261.5057144,
#   'O-D Flow (Max Entropy)': 256.285455,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773965,
#   'O-D Flow (Max Entropy)': 12.33551819,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame'},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014125523,
#   'O-D Flow (Max Entropy)': 9.494008346,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406,
#   'O-D Flow (Max Entropy)': 6.201257219,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909371,
#   'O-D Flow (Max Entropy)': 8.845980375,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534588,
#   'O-D Flow (Max Entropy)': 53.33588101,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae'},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.1078921,
#   'O-D Flow (Max Entropy)': 74.20246282,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037,
#   'O-D Flow (Max Entropy)': 48.46926737,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151,
#   'O-D Flow (Max Entropy)': 69.13785987,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934662,
#   'O-D Flow (Max Entropy)': 416.8579301,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278,
#   'O-D Flow (Max Entropy)': 55.98621571,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377,
#   'O-D Flow (Max Entropy)': 36.57007664,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.16673155,
#   'O-D Flow (Max Entropy)': 52.16505486,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.6833762,
#   'O-D Flow (Max Entropy)': 314.5237677,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae'},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.2839857,
#   'O-D Flow (Max Entropy)': 72.76486228,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.95368728,
#   'O-D Flow (Max Entropy)': 47.53017263,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745,
#   'O-D Flow (Max Entropy)': 67.79837653,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.0770121,
#   'O-D Flow (Max Entropy)': 408.7816411,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031222,
#   'O-D Flow (Max Entropy)': 57.61476844,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.490271,
#   'O-D Flow (Max Entropy)': 82.18252039,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.884062,
#   'O-D Flow (Max Entropy)': 495.5073564,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae'}}

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_income_data = pd.read_csv(directory_path + 'data_income_raw___year_2023.csv')

dict_df_income_data = {}

for column_name_full in list(df_income_data.columns):
    if column_name_full == "Income":
        categories_list = df_income_data[column_name_full].tolist()
    else:
        dict_df_income_data[column_name_full] = {}
        for category_index, category in enumerate(categories_list):
            dict_df_income_data[column_name_full][category] \
                = float(df_income_data[column_name_full].tolist()[category_index])
                
dict_df_income_data
# Out:
# {'Palo Alto': {'< $10,000': 4.7,
#   '$10,000 to $14,999': 3.1,
#   '$15,000 to $24,999': 2.0,
#   '$25,000 to $34,999': 2.5,
#   '$35,000 to $49,999': 3.5,
#   '$50,000 to $74,999': 7.8,
#   '$75,000 to $99,999': 7.5,
#   '$100,000 to $149,999': 13.2,
#   '$150,000 to $199,999': 8.8,
#   '>= $200,000': 46.9,
#   'Median': 184068.0,
#   'Mean': 264292.0},
#  'East Palo Alto': {'< $10,000': 3.6,
#   '$10,000 to $14,999': 2.3,
#   '$15,000 to $24,999': 3.9,
#   '$25,000 to $34,999': 4.9,
#   '$35,000 to $49,999': 8.8,
#   '$50,000 to $74,999': 14.9,
#   '$75,000 to $99,999': 9.5,
#   '$100,000 to $149,999': 19.3,
#   '$150,000 to $199,999': 9.7,
#   '>= $200,000': 23.1,
#   'Median': 104832.0,
#   'Mean': 138379.0},
#  'Menlo Park': {'< $10,000': 1.9,
#   '$10,000 to $14,999': 0.3,
#   '$15,000 to $24,999': 2.2,
#   '$25,000 to $34,999': 2.7,
#   '$35,000 to $49,999': 5.0,
#   '$50,000 to $74,999': 6.2,
#   '$75,000 to $99,999': 5.6,
#   '$100,000 to $149,999': 13.4,
#   '$150,000 to $199,999': 9.0,
#   '>= $200,000': 53.6,
#   'Median': 206588.0,
#   'Mean': 339415.0},
#  'Redwood City': {'< $10,000': 3.6,
#   '$10,000 to $14,999': 1.6,
#   '$15,000 to $24,999': 1.9,
#   '$25,000 to $34,999': 4.4,
#   '$35,000 to $49,999': 5.1,
#   '$50,000 to $74,999': 9.8,
#   '$75,000 to $99,999': 6.3,
#   '$100,000 to $149,999': 16.7,
#   '$150,000 to $199,999': 8.8,
#   '>= $200,000': 41.8,
#   'Median': 151234.0,
#   'Mean': 226931.0},
#  'Belmont': {'< $10,000': 2.8,
#   '$10,000 to $14,999': 1.9,
#   '$15,000 to $24,999': 4.7,
#   '$25,000 to $34,999': 2.3,
#   '$35,000 to $49,999': 3.4,
#   '$50,000 to $74,999': 6.2,
#   '$75,000 to $99,999': 4.8,
#   '$100,000 to $149,999': 12.2,
#   '$150,000 to $199,999': 10.1,
#   '>= $200,000': 51.5,
#   'Median': 207609.0,
#   'Mean': 258184.0},
#  'San Mateo': {'< $10,000': 3.1,
#   '$10,000 to $14,999': 1.9,
#   '$15,000 to $24,999': 3.4,
#   '$25,000 to $34,999': 2.8,
#   '$35,000 to $49,999': 6.1,
#   '$50,000 to $74,999': 8.8,
#   '$75,000 to $99,999': 7.9,
#   '$100,000 to $149,999': 15.5,
#   '$150,000 to $199,999': 12.3,
#   '>= $200,000': 38.3,
#   'Median': 151485.0,
#   'Mean': 219670.0},
#  'Burlingame': {'< $10,000': 3.5,
#   '$10,000 to $14,999': 1.5,
#   '$15,000 to $24,999': 1.7,
#   '$25,000 to $34,999': 2.7,
#   '$35,000 to $49,999': 5.2,
#   '$50,000 to $74,999': 8.0,
#   '$75,000 to $99,999': 8.7,
#   '$100,000 to $149,999': 14.8,
#   '$150,000 to $199,999': 13.0,
#   '>= $200,000': 40.9,
#   'Median': 168832.0,
#   'Mean': 237106.0},
#  'Millbrae': {'< $10,000': 2.3,
#   '$10,000 to $14,999': 2.3,
#   '$15,000 to $24,999': 4.6,
#   '$25,000 to $34,999': 2.4,
#   '$35,000 to $49,999': 5.8,
#   '$50,000 to $74,999': 7.8,
#   '$75,000 to $99,999': 7.8,
#   '$100,000 to $149,999': 14.4,
#   '$150,000 to $199,999': 13.5,
#   '>= $200,000': 39.0,
#   'Median': 157567.0,
#   'Mean': 210044.0}}

# %% [markdown]
# # <font color='blue'>To change income bracket ranges, start editing here</font>

# %%
# Need to change:
## 1. Mean Incomes, VoTs, Population Percentages
## 2. Demands per od
## 3. Demands per city

# %% [markdown]
# # Mean Incomes, VoTs, Population Percentages

# %% [markdown]
# ## Case 1: (3 eligible groups, 2 ineligible groups)

# %%
cities_list = list(dict_df_income_data.keys())

dict_income_groups_1 = {}
income_range_list_1 = ["< $15,000", "$15,000 to $35,000", "$35,000 to $100,000", \
                       "$100,000 to $200,000", ">= $200,000"]

for city_name in cities_list:
    dict_income_groups_1[city_name] = {}
    
    for income_range in income_range_list_1:
        
        if income_range == "< $15,000":
            percent_of_population = dict_df_income_data[city_name]["< $10,000"] \
                + dict_df_income_data[city_name]["$10,000 to $14,999"]
            mean_income = (income_range_avg("< $10,000") * dict_df_income_data[city_name]["< $10,000"] \
                + income_range_avg("$10,000 to $14,999") * dict_df_income_data[city_name]["$10,000 to $14,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$15,000 to $35,000":
            percent_of_population = dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + dict_df_income_data[city_name]["$25,000 to $34,999"]
            mean_income = (income_range_avg("$15,000 to $24,999") * dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + income_range_avg("$25,000 to $34,999") * dict_df_income_data[city_name]["$25,000 to $34,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$35,000 to $100,000":
            percent_of_population = dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + dict_df_income_data[city_name]["$75,000 to $99,999"]
            mean_income = (income_range_avg("$35,000 to $49,999") * dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + income_range_avg("$50,000 to $74,999") * dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + income_range_avg("$75,000 to $99,999") * dict_df_income_data[city_name]["$75,000 to $99,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$100,000 to $200,000":
            percent_of_population = dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + dict_df_income_data[city_name]["$150,000 to $199,999"]
            mean_income = (income_range_avg("$100,000 to $149,999") * dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + income_range_avg("$150,000 to $199,999") * dict_df_income_data[city_name]["$150,000 to $199,999"]) \
                / percent_of_population
            dict_income_groups_1[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == ">= $200,000":
            percent_of_population = dict_df_income_data[city_name][">= $200,000"]          
            dict_income_groups_1[city_name][income_range] = [0, percent_of_population, 0]
        
        else:
            assert 1 == 0, "This case should not occur."
    
    if income_range == ">= $200,000":
        sum_of_income_mean_percent_products \
            = sum([dict_income_groups_1[city_name][income_range][0] * dict_income_groups_1[city_name][income_range][1] \
                   for income_range in income_range_list_1 if income_range != ">= 200,000"])
        mean_income = (dict_df_income_data[city_name]["Mean"] * 100 - sum_of_income_mean_percent_products) \
            / dict_income_groups_1[city_name][">= $200,000"][1]
        dict_income_groups_1[city_name][income_range][0] = mean_income

dict_income_groups_1

# %%
dict_mean_income_estimate_1 = {}
dict_population_percentage_1 = {}
dict_VoT_1 = {}

dict_mean_income_estimate_1["Income Range"] = income_range_list_1
dict_population_percentage_1["Income Range"] = income_range_list_1
dict_VoT_1["Income Range"] = income_range_list_1

for city_name in cities_list:
    dict_mean_income_estimate_1[city_name] = []
    dict_population_percentage_1[city_name] = []
    dict_VoT_1[city_name] = []
    
    for income_range in income_range_list_1:
        dict_mean_income_estimate_1[city_name] += [dict_income_groups_1[city_name][income_range][0]]
        dict_population_percentage_1[city_name] += [dict_income_groups_1[city_name][income_range][1]]
        # *2: Household size = 2.
        dict_VoT_1[city_name] += [dict_income_groups_1[city_name][income_range][0] / (40*52*60*2)]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_mean_income_estimate_1 = pd.DataFrame(dict_mean_income_estimate_1)
df_mean_income_estimate_1.to_csv(directory_path + 'data_mean_income_estimate_1.csv', index = False)

df_population_percentage_1 = pd.DataFrame(dict_population_percentage_1)
df_population_percentage_1.to_csv(directory_path + 'data_population_percentage_1.csv', index = False)

df_VoT_1 = pd.DataFrame(dict_VoT_1)
df_VoT_1.to_csv(directory_path + 'data_VoT_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
cities_list = list(dict_df_income_data.keys())

dict_income_groups_2 = {}
income_range_list_2 = ["< $35,000", "$35,000 to $200,000", ">= $200,000"]

for city_name in cities_list:
    dict_income_groups_2[city_name] = {}
    
    for income_range in income_range_list_2:
        dict_income_groups_2[city_name][income_range] = np.zeros(2)
        
        if income_range == "< $35,000":
            percent_of_population = dict_df_income_data[city_name]["< $10,000"] \
                + dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + dict_df_income_data[city_name]["$25,000 to $34,999"]
            mean_income = (income_range_avg("< $10,000") * dict_df_income_data[city_name]["< $10,000"] \
                + income_range_avg("$10,000 to $14,999") * dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + income_range_avg("$15,000 to $24,999") * dict_df_income_data[city_name]["$15,000 to $24,999"] \
                + income_range_avg("$25,000 to $34,999") * dict_df_income_data[city_name]["$25,000 to $34,999"]) \
                / percent_of_population
            dict_income_groups_2[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$35,000 to $200,000":
            percent_of_population = dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + dict_df_income_data[city_name]["$75,000 to $99,999"] \
                + dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + dict_df_income_data[city_name]["$150,000 to $199,999"]
            mean_income = (income_range_avg("$35,000 to $49,999") * dict_df_income_data[city_name]["$35,000 to $49,999"] \
                + income_range_avg("$50,000 to $74,999") * dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + income_range_avg("$75,000 to $99,999") * dict_df_income_data[city_name]["$75,000 to $99,999"] \
                + income_range_avg("$100,000 to $149,999") * dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + income_range_avg("$150,000 to $199,999") * dict_df_income_data[city_name]["$150,000 to $199,999"]) \
                / percent_of_population
            dict_income_groups_2[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == ">= $200,000":
            percent_of_population = dict_df_income_data[city_name][">= $200,000"]          
            dict_income_groups_2[city_name][income_range] = [0, percent_of_population]
        
        else:
            assert 1 == 0, "This case should not occur."
    
    if income_range == ">= $200,000":
        sum_of_income_mean_percent_products \
            = sum([dict_income_groups_2[city_name][income_range][0] * dict_income_groups_2[city_name][income_range][1] \
                   for income_range in income_range_list_2 if income_range != ">= 200,000"])
        mean_income = (dict_df_income_data[city_name]["Mean"] * 100 - sum_of_income_mean_percent_products) \
            / dict_income_groups_2[city_name][">= $200,000"][1]
        dict_income_groups_2[city_name][income_range][0] = mean_income

dict_income_groups_2

# %%
dict_mean_income_estimate_2 = {}
dict_population_percentage_2 = {}
dict_VoT_2 = {}

dict_mean_income_estimate_2["Income Range"] = income_range_list_2
dict_population_percentage_2["Income Range"] = income_range_list_2
dict_VoT_2["Income Range"] = income_range_list_2

for city_name in cities_list:
    dict_mean_income_estimate_2[city_name] = []
    dict_population_percentage_2[city_name] = []
    dict_VoT_2[city_name] = []
    
    for income_range in income_range_list_2:
        dict_mean_income_estimate_2[city_name] += [dict_income_groups_2[city_name][income_range][0]]
        dict_population_percentage_2[city_name] += [dict_income_groups_2[city_name][income_range][1]]
        dict_VoT_2[city_name] += [dict_income_groups_2[city_name][income_range][0] / (40*52*60*2)]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_mean_income_estimate_2 = pd.DataFrame(dict_mean_income_estimate_2)
df_mean_income_estimate_2.to_csv(directory_path + 'data_mean_income_estimate_2.csv', index = False)

df_population_percentage_2 = pd.DataFrame(dict_population_percentage_2)
df_population_percentage_2.to_csv(directory_path + 'data_population_percentage_2.csv', index = False)

df_VoT_2 = pd.DataFrame(dict_VoT_2)
df_VoT_2.to_csv(directory_path + 'data_VoT_2.csv', index = False)

# %% [markdown]
# ## Case 3: (2 eligible groups, 3 ineligible groups)

# %% [markdown]
# ## <font color='red'>Done (Monday, October 13).</font>

# %%
cities_list = list(dict_df_income_data.keys())

dict_income_groups_3 = {}
income_range_list_3 = ["< $25,000", "$25,000 to $50,000", "$50,000 to $100,000", \
                       "$100,000 to $200,000", ">= $200,000"]

for city_name in cities_list:
    dict_income_groups_3[city_name] = {}
    
    for income_range in income_range_list_3:
#         print()
        
        if income_range == "< $25,000":
            percent_of_population = dict_df_income_data[city_name]["< $10,000"] \
                + dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + dict_df_income_data[city_name]["$15,000 to $24,999"]
            mean_income = (income_range_avg("< $10,000") * dict_df_income_data[city_name]["< $10,000"] \
                + income_range_avg("$10,000 to $14,999") * dict_df_income_data[city_name]["$10,000 to $14,999"] \
                + income_range_avg("$15,000 to $24,999") * dict_df_income_data[city_name]["$15,000 to $24,999"]) \
                / percent_of_population
            dict_income_groups_3[city_name][income_range] = [mean_income, percent_of_population]
        
        elif income_range == "$25,000 to $50,000":
            percent_of_population = dict_df_income_data[city_name]["$25,000 to $34,999"] \
                + dict_df_income_data[city_name]["$35,000 to $49,999"]
            mean_income = (income_range_avg("$25,000 to $34,999") * dict_df_income_data[city_name]["$25,000 to $34,999"] \
                + income_range_avg("$35,000 to $49,999") * dict_df_income_data[city_name]["$35,000 to $49,999"]) \
                / percent_of_population
            dict_income_groups_3[city_name][income_range] = [mean_income, percent_of_population]
        
        elif income_range == "$50,000 to $100,000":
            percent_of_population = dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + dict_df_income_data[city_name]["$75,000 to $99,999"]
            mean_income = (income_range_avg("$50,000 to $74,999") * dict_df_income_data[city_name]["$50,000 to $74,999"] \
                + income_range_avg("$75,000 to $99,999") * dict_df_income_data[city_name]["$75,000 to $99,999"]) \
                / percent_of_population
            dict_income_groups_3[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == "$100,000 to $200,000":
            percent_of_population = dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + dict_df_income_data[city_name]["$150,000 to $199,999"]
            mean_income = (income_range_avg("$100,000 to $149,999") * dict_df_income_data[city_name]["$100,000 to $149,999"] \
                + income_range_avg("$150,000 to $199,999") * dict_df_income_data[city_name]["$150,000 to $199,999"]) \
                / percent_of_population
            dict_income_groups_3[city_name][income_range] = [mean_income, percent_of_population]
            
        elif income_range == ">= $200,000":
            percent_of_population = dict_df_income_data[city_name][">= $200,000"]          
            dict_income_groups_3[city_name][income_range] = [0, percent_of_population, 0]
        
        else:
            assert 1 == 0, "This case should not occur."
    
    if income_range == ">= $200,000":
        sum_of_income_mean_percent_products \
            = sum([dict_income_groups_3[city_name][income_range][0] * dict_income_groups_3[city_name][income_range][1] \
                   for income_range in income_range_list_3 if income_range != ">= 200,000"])
        mean_income = (dict_df_income_data[city_name]["Mean"] * 100 - sum_of_income_mean_percent_products) \
            / dict_income_groups_3[city_name][">= $200,000"][1]
        dict_income_groups_3[city_name][income_range][0] = mean_income

dict_income_groups_3
# Out:
# {'Palo Alto': {'< $25,000': [10433.673469387755, 9.8],
#   '$25,000 to $50,000': [37291.666666666664, 6.0],
#   '$50,000 to $100,000': [74754.90196078431, 15.3],
#   '$100,000 to $200,000': [145000.0, 22.0],
#   '>= $200,000': [464167.3773987207, 46.9, 0]},
#  'East Palo Alto': {'< $25,000': [12729.591836734693, 9.8],
#   '$25,000 to $50,000': [38029.197080291975, 13.700000000000001],
#   '$50,000 to $100,000': [72233.60655737705, 24.4],
#   '$100,000 to $200,000': [141724.1379310345, 29.0],
#   '>= $200,000': [316867.96536796534, 23.1, 0]},
#  'Menlo Park': {'< $25,000': [13011.363636363636, 4.4],
#   '$25,000 to $50,000': [38116.88311688312, 7.7],
#   '$50,000 to $100,000': [74364.40677966102, 11.8],
#   '$100,000 to $200,000': [145089.2857142857, 22.4],
#   '>= $200,000': [549687.5, 53.6, 0]},
#  'Redwood City': {'< $25,000': [10704.225352112677, 7.1],
#   '$25,000 to $50,000': [36710.52631578947, 9.5],
#   '$50,000 to $100,000': [72282.60869565216, 16.1],
#   '$100,000 to $200,000': [142254.9019607843, 25.5],
#   '>= $200,000': [418112.4401913876, 41.8, 0]},
#  'Belmont': {'< $25,000': [14015.957446808512, 9.399999999999999],
#   '$25,000 to $50,000': [37456.1403508772, 5.699999999999999],
#   '$50,000 to $100,000': [73409.09090909091, 11.0],
#   '$100,000 to $200,000': [147645.73991031392, 22.299999999999997],
#   '>= $200,000': [415012.6213592233, 51.5, 0]},
#  'San Mateo': {'< $25,000': [12767.857142857143, 8.4],
#   '$25,000 to $50,000': [38567.41573033708, 8.899999999999999],
#   '$50,000 to $100,000': [74326.34730538921, 16.700000000000003],
#   '$100,000 to $200,000': [147122.30215827338, 27.8],
#   '>= $200,000': [422591.38381201046, 38.3, 0]},
#  'Burlingame': {'< $25,000': [10485.074626865671, 6.7],
#   '$25,000 to $50,000': [38227.84810126582, 7.9],
#   '$50,000 to $100,000': [75523.95209580839, 16.7],
#   '$100,000 to $200,000': [148381.29496402878, 27.8],
#   '>= $200,000': [438926.65036674816, 40.9, 0]},
#  'Millbrae': {'< $25,000': [14375.000000000002, 9.2],
#   '$25,000 to $50,000': [38841.46341463415, 8.2],
#   '$50,000 to $100,000': [75000.0, 15.6],
#   '$100,000 to $200,000': [149193.5483870968, 27.9],
#   '>= $200,000': [390285.89743589744, 39.0, 0]}}

# %%
dict_mean_income_estimate_3 = {}
dict_population_percentage_3 = {}
dict_VoT_3 = {}

dict_mean_income_estimate_3["Income Range"] = income_range_list_3
dict_population_percentage_3["Income Range"] = income_range_list_3
dict_VoT_3["Income Range"] = income_range_list_3

for city_name in cities_list:
    dict_mean_income_estimate_3[city_name] = []
    dict_population_percentage_3[city_name] = []
    dict_VoT_3[city_name] = []
    
    for income_range in income_range_list_3:
        dict_mean_income_estimate_3[city_name] += [dict_income_groups_3[city_name][income_range][0]]
        dict_population_percentage_3[city_name] += [dict_income_groups_3[city_name][income_range][1]]
        # *2: Household size = 2.
        dict_VoT_3[city_name] += [dict_income_groups_3[city_name][income_range][0] / (40*52*60*2)]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_mean_income_estimate_3 = pd.DataFrame(dict_mean_income_estimate_3)
df_mean_income_estimate_3.to_csv(directory_path + 'data_mean_income_estimate_3.csv', index = False)

df_population_percentage_3 = pd.DataFrame(dict_population_percentage_3)
df_population_percentage_3.to_csv(directory_path + 'data_population_percentage_3.csv', index = False)

df_VoT_3 = pd.DataFrame(dict_VoT_3)
df_VoT_3.to_csv(directory_path + 'data_VoT_3.csv', index = False)

# %% [markdown]
# # Demands (per od)

# %% [markdown]
# ## Case 1: (3 eligible groups, 2 ineligible groups)

# %%
# dict_df_od_flow_data

# %%
dict_df_od_flow_data_augmented_1 = copy.deepcopy(dict_df_od_flow_data)

# %%
for od_index in list(dict_df_od_flow_data.keys()):
    start_city_name = dict_df_od_flow_data[od_index]["Start City"]
    demand_total_od = dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]
    
    dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][0] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 1)"] = dict_VoT_1[start_city_name][0]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][1] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 2)"] = dict_VoT_1[start_city_name][1]
    
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][2] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 1)"] = dict_VoT_1[start_city_name][2]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][3] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 2)"] = dict_VoT_1[start_city_name][3]
    dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][4] / 100
    dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 3)"] = dict_VoT_1[start_city_name][4]


dict_df_od_flow_data_augmented_1

# %%
# dict_df_od_flow_data

# %%
dict_od_data_to_save_1 = {}
dict_od_data_to_save_1["Data Category"] \
    = ["Start Index", "End Index", "Start Station", "End Station", "Start City", "End City", \
       "O-D Flow (Initialization)", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for od_index in list(dict_df_od_flow_data.keys()):
    dict_od_data_to_save_1[od_index] = []
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start Index"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End Index"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start Station"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End Station"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["Start City"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["End City"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Initialization)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (eligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (eligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 1)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 2)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["Demand (ineligible group, 3)"]]
    dict_od_data_to_save_1[od_index] += [dict_df_od_flow_data_augmented_1[od_index]["VoT (ineligible group, 3)"]]

# %%
# dict_od_data_to_save_1

directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_data_to_save_1 = pd.DataFrame(dict_od_data_to_save_1)
df_od_data_to_save_1.to_csv(directory_path + 'data_od_VoTs_demands_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
# dict_df_od_flow_data

# %%
dict_df_od_flow_data_augmented_2 = copy.deepcopy(dict_df_od_flow_data)

# %%
for od_index in list(dict_df_od_flow_data.keys()):
    start_city_name = dict_df_od_flow_data[od_index]["Start City"]
    demand_total_od = dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]
    
    dict_df_od_flow_data_augmented_2[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][0] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (eligible group, 1)"] = dict_VoT_2[start_city_name][0]
    
    dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][1] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 1)"] = dict_VoT_2[start_city_name][1]
    dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][2] / 100
    dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 2)"] = dict_VoT_2[start_city_name][2]

dict_df_od_flow_data_augmented_2

# %%
dict_df_od_flow_data

# %%
dict_od_data_to_save_2 = {}
dict_od_data_to_save_2["Data Category"] \
    = ["Start Index", "End Index", "Start Station", "End Station", "Start City", "End City", \
       "O-D Flow (Initialization)", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)"]

for od_index in list(dict_df_od_flow_data.keys()):
    dict_od_data_to_save_2[od_index] = []
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start Index"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End Index"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start Station"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End Station"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["Start City"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["End City"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Initialization)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (eligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (eligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 1)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["Demand (ineligible group, 2)"]]
    dict_od_data_to_save_2[od_index] += [dict_df_od_flow_data_augmented_2[od_index]["VoT (ineligible group, 2)"]]

# %%
# dict_od_data_to_save_2

directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_data_to_save_2 = pd.DataFrame(dict_od_data_to_save_2)
df_od_data_to_save_2.to_csv(directory_path + 'data_od_VoTs_demands_2.csv', index = False)

# %% [markdown]
# ## Case 3: (2 eligible groups, 3 ineligible groups)

# %% [markdown]
# ## <font color='red'>Todo (Monday, October 13)</font>

# %%
dict_df_od_flow_data_augmented_3 = copy.deepcopy(dict_df_od_flow_data)

for od_index in list(dict_df_od_flow_data.keys()):
    start_city_name = dict_df_od_flow_data[od_index]["Start City"]
    demand_total_od = dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]
    
    dict_df_od_flow_data_augmented_3[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][0] / 100
    dict_df_od_flow_data_augmented_3[od_index]["VoT (eligible group, 1)"] = dict_VoT_3[start_city_name][0]
    dict_df_od_flow_data_augmented_3[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][1] / 100
    dict_df_od_flow_data_augmented_3[od_index]["VoT (eligible group, 2)"] = dict_VoT_3[start_city_name][1]
    
    dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][2] / 100
    dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 1)"] = dict_VoT_3[start_city_name][2]
    dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][3] / 100
    dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 2)"] = dict_VoT_3[start_city_name][3]
    dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][4] / 100
    dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 3)"] = dict_VoT_3[start_city_name][4]


dict_df_od_flow_data_augmented_3
# Out:
# {0: {'Start Index': 0,
#   'End Index': 1,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '004___425696_Palo_Alto___off',
#   'O-D Flow (Initialization)': 612.5396169,
#   'O-D Flow (Max Entropy)': 612.5396169,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto',
#   'Demand (eligible group, 1)': 60.02888245620001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 36.752377014000004,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 93.71856138570001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 134.75871571800002,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 287.28108032610004,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  1: {'Start Index': 0,
#   'End Index': 5,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 98.0284297,
#   'O-D Flow (Max Entropy)': 80.1904526,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 7.858664354800001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 4.811427156,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 12.269139247800002,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 17.641899572,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 37.609322269399996,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  2: {'Start Index': 0,
#   'End Index': 12,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 309.2110456,
#   'O-D Flow (Max Entropy)': 413.6495858,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 40.5376594084,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 24.818975148,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 63.2883866274,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 91.002908876,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 194.0016557402,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  3: {'Start Index': 0,
#   'End Index': 14,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 340.9217998,
#   'O-D Flow (Max Entropy)': 517.2177493,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 50.687339431400005,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 31.033064958000004,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 79.1343156429,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 113.787904846,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 242.57512442170002,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  4: {'Start Index': 0,
#   'End Index': 23,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 225.4461263,
#   'O-D Flow (Max Entropy)': 209.3011497,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 20.5115126706,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 12.558068982,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 32.023075904100004,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 46.046252934,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 98.16223920929998,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  5: {'Start Index': 0,
#   'End Index': 28,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 268.3933688,
#   'O-D Flow (Max Entropy)': 348.2467009,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 34.1281766882,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 20.894802054000003,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 53.28174523770001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 76.614274198,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 163.3277027221,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  6: {'Start Index': 0,
#   'End Index': 36,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 124.0136751,
#   'O-D Flow (Max Entropy)': 37.86051453,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.710330423940001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 2.2716308718000002,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 5.792658723090001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 8.329313196600001,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 17.75658131457,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  7: {'Start Index': 0,
#   'End Index': 38,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 250.635719,
#   'O-D Flow (Max Entropy)': 229.8646608,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 22.526736758400002,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 13.791879647999998,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 35.169293102400005,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 50.570225375999996,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 107.8065259152,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  8: {'Start Index': 0,
#   'End Index': 41,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 245.7820196,
#   'O-D Flow (Max Entropy)': 156.9962517,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 15.3856326666,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 9.419775102,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 24.020426510100002,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 34.539175373999996,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 73.63124204729999,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  9: {'Start Index': 0,
#   'End Index': 44,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 77.55218436,
#   'O-D Flow (Max Entropy)': 20.52905029,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.0118469284200002,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 1.2317430174000001,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 3.1409446943700003,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 4.5163910638,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 9.62812458601,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  10: {'Start Index': 0,
#   'End Index': 48,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 260.4147974,
#   'O-D Flow (Max Entropy)': 198.3714943,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 19.4404064414,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 11.902289657999999,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 30.350838627900004,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 43.641728746,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 93.03623082669999,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  11: {'Start Index': 0,
#   'End Index': 55,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 264.0084246,
#   'O-D Flow (Max Entropy)': 152.6789188,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 14.9625340424,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 9.160735127999999,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 23.3598745764,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 33.589362136,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 71.60641291719999,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  12: {'Start Index': 0,
#   'End Index': 59,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 251.7115899,
#   'O-D Flow (Max Entropy)': 99.72718407,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 9.77326403886,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 5.9836310442,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 15.25825916271,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 21.9399804954,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 46.77204932883,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  13: {'Start Index': 0,
#   'End Index': 61,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 264.7591375,
#   'O-D Flow (Max Entropy)': 142.2577575,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 13.941260235,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 8.535465449999998,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 21.7654368975,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 31.29670665,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 66.71888826749999,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  14: {'Start Index': 0,
#   'End Index': 62,
#   'Start Station': '001___402376_Palo_Alto___main',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 483.7292263,
#   'O-D Flow (Max Entropy)': 857.7160572,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 84.05617360560001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 51.462963431999995,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 131.2305567516,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 188.697532584,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 402.26883082679996,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  15: {'Start Index': 3,
#   'End Index': 5,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '010___403059_East_Palo_Alto___off',
#   'O-D Flow (Initialization)': 0.006490166,
#   'O-D Flow (Max Entropy)': 17.84446726,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'Demand (eligible group, 1)': 1.7487577914799999,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 1.0706680355999998,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 2.7302034907799997,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 3.9257827971999997,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 8.369055144939999,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  16: {'Start Index': 3,
#   'End Index': 12,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 187.4897819,
#   'O-D Flow (Max Entropy)': 92.04654839,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 9.020561742220002,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 5.5227929034,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 14.083121903670001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 20.250240645799998,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 43.169831194909996,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  17: {'Start Index': 3,
#   'End Index': 14,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 219.200536,
#   'O-D Flow (Max Entropy)': 115.0941851,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 11.279230139800001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 6.9056511060000005,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 17.6094103203,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 25.320720722,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 53.9791728119,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  18: {'Start Index': 3,
#   'End Index': 23,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 12.81341751,
#   'O-D Flow (Max Entropy)': 46.57526082,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 4.56437556036,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 2.7945156492,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 7.12601490546,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 10.246557380399999,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 21.843797324579995,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  19: {'Start Index': 3,
#   'End Index': 28,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 68.87928624,
#   'O-D Flow (Max Entropy)': 77.4914905,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 7.594166069,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 4.64948943,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 11.856198046500001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 17.048127909999998,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 36.343509044499996,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  20: {'Start Index': 3,
#   'End Index': 36,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 8.423889571,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.8255411779580001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 0.50543337426,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 1.2888551043629999,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 1.8532557056199999,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 3.9508042087989996,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  21: {'Start Index': 3,
#   'End Index': 38,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002489043,
#   'O-D Flow (Max Entropy)': 51.14923185,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 5.012624721300001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 3.068953911,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 7.82583247305,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 11.252831007,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 23.988989737649998,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  22: {'Start Index': 3,
#   'End Index': 41,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 7.74e-05,
#   'O-D Flow (Max Entropy)': 34.93550462,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 3.4236794527600005,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 2.0961302772000003,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 5.345132206860001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 7.685811016400001,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 16.38475166678,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  23: {'Start Index': 3,
#   'End Index': 44,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.004379506,
#   'O-D Flow (Max Entropy)': 4.566207665,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.4474883511700001,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 0.2739724599,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 0.6986297727450002,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 1.0045656863,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 2.141551394885,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  24: {'Start Index': 3,
#   'End Index': 48,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 10.74189586,
#   'O-D Flow (Max Entropy)': 44.14323907,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 4.32603742886,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 2.6485943442,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 6.753915577710001,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 9.7115125954,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 20.70317912383,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  25: {'Start Index': 3,
#   'End Index': 55,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 16.22169189,
#   'O-D Flow (Max Entropy)': 33.97482145,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.3295325021,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 2.038489287,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 5.19814768185,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 7.474460719,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 15.93419126005,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  26: {'Start Index': 3,
#   'End Index': 59,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 26.00786122,
#   'O-D Flow (Max Entropy)': 22.19200034,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.1748160333200004,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 1.3315200204000002,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 3.39537605202,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 4.8822400748,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 10.40804815946,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  27: {'Start Index': 3,
#   'End Index': 61,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 22.11658655,
#   'O-D Flow (Max Entropy)': 31.65589812,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.1022780157600005,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 1.8993538872,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 4.84335241236,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 6.964297586400001,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 14.846616218279998,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  28: {'Start Index': 3,
#   'End Index': 62,
#   'Start Station': '006___425897_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 207.476219,
#   'O-D Flow (Max Entropy)': 190.8637433,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 18.704646843400003,
#   'VoT (eligible group, 1)': 0.04180157639979069,
#   'Demand (eligible group, 2)': 11.451824598,
#   'VoT (eligible group, 2)': 0.1494057158119658,
#   'Demand (ineligible group, 1)': 29.202152724900003,
#   'VoT (ineligible group, 1)': 0.29949880593262945,
#   'Demand (ineligible group, 2)': 41.990023526,
#   'VoT (ineligible group, 2)': 0.5809294871794872,
#   'Demand (ineligible group, 3)': 89.5150956077,
#   'VoT (ineligible group, 3)': 1.8596449415012848},
#  29: {'Start Index': 6,
#   'End Index': 12,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 14.29370581,
#   'O-D Flow (Max Entropy)': 31.42046243,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 3.07920531814,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 4.30460335291,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 7.666592832919999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 9.1119341047,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 7.25812682133,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  30: {'Start Index': 6,
#   'End Index': 14,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 45.88285273,
#   'O-D Flow (Max Entropy)': 39.2880828,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 3.8502321144000002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 5.3824673436,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 9.5862922032,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 11.393544012,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 9.0755471268,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  31: {'Start Index': 6,
#   'End Index': 23,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.89823077,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 1.55802661546,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.17805761549,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 3.8791683078799997,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 4.6104869233,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.67249130787,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  32: {'Start Index': 6,
#   'End Index': 28,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00111462,
#   'O-D Flow (Max Entropy)': 26.45197974,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.5922940145199997,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 3.62392122438,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 6.454283056559999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 7.6710741246,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.11040731994,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  33: {'Start Index': 6,
#   'End Index': 36,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.875050911,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.281754989278,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 0.3938819748070001,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 0.7015124222839999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 0.83376476419,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.6641367604410001,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  34: {'Start Index': 6,
#   'End Index': 38,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.000263773,
#   'O-D Flow (Max Entropy)': 17.45973865,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.7110543877,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.39198419505,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 4.260176230599999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 5.063324208499999,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.03319962815,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  35: {'Start Index': 6,
#   'End Index': 41,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 11.92512731,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 1.1686624763800002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.6337424414700001,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 2.90973106364,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 3.4582869199000004,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.7547044086100003,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  36: {'Start Index': 6,
#   'End Index': 44,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001277735,
#   'O-D Flow (Max Entropy)': 1.558157423,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.152699427454,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 0.21346756695100003,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 0.380190411212,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 0.45186565267,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.359934364713,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  37: {'Start Index': 6,
#   'End Index': 48,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 15.06820396,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 1.47668398808,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.06434394252,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 3.67664176624,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 4.3697791484,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.4807551147600004,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  38: {'Start Index': 6,
#   'End Index': 55,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 6.017123545,
#   'O-D Flow (Max Entropy)': 11.59720023,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.1365256225400002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.5888164315100002,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 2.8297168561199997,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 3.3631880667000003,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.67895325313,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  39: {'Start Index': 6,
#   'End Index': 59,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 10.77104191,
#   'O-D Flow (Max Entropy)': 7.57510869,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.74236065162,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.0377898905300003,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 1.8483265203600001,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 2.1967815201,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 1.7498501073900001,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  40: {'Start Index': 6,
#   'End Index': 61,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 11.31151065,
#   'O-D Flow (Max Entropy)': 10.80563614,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.0589523417200002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.4803721511800003,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 2.63657521816,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 3.1336344806,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 2.49610194834,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  41: {'Start Index': 6,
#   'End Index': 62,
#   'Start Station': '011___403060_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 168.8039813,
#   'O-D Flow (Max Entropy)': 65.15065615,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.384764302700001,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 8.925639892550002,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 15.8967601006,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 18.8936902835,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 15.049801570650002,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  42: {'Start Index': 8,
#   'End Index': 12,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 109.4277859,
#   'O-D Flow (Max Entropy)': 54.91642102,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 5.381809259960001,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 7.52354967974,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 13.399606728879998,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 15.925762095800001,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 12.685693255620002,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  43: {'Start Index': 8,
#   'End Index': 14,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 141.0169328,
#   'O-D Flow (Max Entropy)': 68.66669332,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 6.72933594536,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 9.40733698484,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 16.754673170079997,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 19.913341062799997,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 15.86200615692,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  44: {'Start Index': 8,
#   'End Index': 23,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 27.78688075,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 2.7231143135,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 3.8068026627500005,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 6.779998902999999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 8.0581954175,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.41876945325,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  45: {'Start Index': 8,
#   'End Index': 28,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001171756,
#   'O-D Flow (Max Entropy)': 46.23226244,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 4.53076171912,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 6.333819954280001,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 11.280672035359999,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 13.407356107599998,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 10.67965262364,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  46: {'Start Index': 8,
#   'End Index': 36,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 5.02558059,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.49250689782,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 0.68850454083,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 1.2262416639599998,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 1.4574183710999997,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 1.16090911629,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  47: {'Start Index': 8,
#   'End Index': 38,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.00032091,
#   'O-D Flow (Max Entropy)': 30.51608653,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.9905764799400005,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 4.18070385461,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 7.4459251133199995,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 8.849665093699999,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 7.049215988429999,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  48: {'Start Index': 8,
#   'End Index': 41,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '076___403287_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 20.84264243,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.04257895814,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.85544201291,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 5.08560475292,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 6.0443663047000005,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.814650401330001,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  49: {'Start Index': 8,
#   'End Index': 44,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '081___403086_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001486336,
#   'O-D Flow (Max Entropy)': 2.724047399,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.266956645102,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 0.373194493663,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 0.664667565356,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 0.7899737457099999,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.629254949169,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  50: {'Start Index': 8,
#   'End Index': 48,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 26.33616449,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 2.5809441200200003,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 3.6080545351300004,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 6.42602413556,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 7.6374877021000005,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.083653997190001,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  51: {'Start Index': 8,
#   'End Index': 55,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 3.264585824,
#   'O-D Flow (Max Entropy)': 20.2695037,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.9864113626000002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.7769220069000005,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 4.9457589028,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 5.878156073,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.6822553547000005,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  52: {'Start Index': 8,
#   'End Index': 59,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 11.80561589,
#   'O-D Flow (Max Entropy)': 13.23986593,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.2975068611400002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.81386163241,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 3.23052728692,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 3.8395611197,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.0584090298300004,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  53: {'Start Index': 8,
#   'End Index': 61,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 8.159608384,
#   'O-D Flow (Max Entropy)': 18.88601805,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 1.8508297689000002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 2.58738447285,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 4.6081884042,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 5.4769452345000005,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 4.36267016955,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  54: {'Start Index': 8,
#   'End Index': 62,
#   'Start Station': '013___403061_East_Palo_Alto___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 175.6440625,
#   'O-D Flow (Max Entropy)': 113.8703381,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 11.159293133800002,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 15.6002363197,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 27.7843624964,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 33.022398048999996,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 26.3040481011,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  55: {'Start Index': 10,
#   'End Index': 12,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '027___403206_Redwood_City___off',
#   'O-D Flow (Initialization)': 0.000890278,
#   'O-D Flow (Max Entropy)': 28.39019173,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 2.7822387895400005,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 3.8894562670100004,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 6.927206782120001,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 8.2331556017,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 6.558134289630001,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  56: {'Start Index': 10,
#   'End Index': 14,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '032___410094_Redwood_City___off',
#   'O-D Flow (Initialization)': 28.74363559,
#   'O-D Flow (Max Entropy)': 35.4990463,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'Demand (eligible group, 1)': 3.4789065374000008,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 4.8633693431000005,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 8.6617672972,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 10.294723427000001,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 8.200279695300003,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  57: {'Start Index': 10,
#   'End Index': 23,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '045___410111_Belmont___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 14.36494385,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'Demand (eligible group, 1)': 1.4077644972999999,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 1.9679973074500001,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 3.5050462993999996,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 4.1658337165,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 3.31830202935,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  58: {'Start Index': 10,
#   'End Index': 28,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '051___409888_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.002203424,
#   'O-D Flow (Max Entropy)': 23.9008689,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 2.3422851522,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 3.2744190393,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 5.8318120115999985,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 6.931251980999999,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 5.521100715899999,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  59: {'Start Index': 10,
#   'End Index': 36,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '067___405847_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.0,
#   'O-D Flow (Max Entropy)': 2.597651719,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'Demand (eligible group, 1)': 0.25456986846199997,
#   'VoT (eligible group, 1)': 0.05099996729461015,
#   'Demand (eligible group, 2)': 0.35587828550300005,
#   'VoT (eligible group, 2)': 0.15236056522552874,
#   'Demand (ineligible group, 1)': 0.633827019436,
#   'VoT (ineligible group, 1)': 0.28939746216897855,
#   'Demand (ineligible group, 2)': 0.7533189985100001,
#   'VoT (ineligible group, 2)': 0.5678050397877984,
#   'Demand (ineligible group, 3)': 0.6000575470889999,
#   'VoT (ineligible group, 3)': 1.2695030663780662},
#  60: {'Start Index': 10,
#   'End Index': 38,
#   'Start Station': '015___408267_East_Palo_Alto___on',
#   'End Station': '069___405845_San_Mateo___off',
#   'O-D Flow (Initialization)': 0.001352577,
#   'O-D Flow (Max Entropy)': 15.775858,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
# ...
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 98.15732926499999,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  172: {'Start Index': 46,
#   'End Index': 48,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '085___422114_Burlingame___off',
#   'O-D Flow (Initialization)': 0.013773965,
#   'O-D Flow (Max Entropy)': 12.33551819,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame',
#   'Demand (eligible group, 1)': 1.03618352796,
#   'VoT (eligible group, 1)': 0.05115327380952381,
#   'Demand (eligible group, 2)': 1.0978611189099998,
#   'VoT (eligible group, 2)': 0.15451688994526075,
#   'Demand (ineligible group, 1)': 2.0600315377300005,
#   'VoT (ineligible group, 1)': 0.29778184016582215,
#   'Demand (ineligible group, 2)': 3.42927405682,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 4.72450346677,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  173: {'Start Index': 46,
#   'End Index': 55,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014125523,
#   'O-D Flow (Max Entropy)': 9.494008346,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.7974967010640001,
#   'VoT (eligible group, 1)': 0.05115327380952381,
#   'Demand (eligible group, 2)': 0.8449667427939999,
#   'VoT (eligible group, 2)': 0.15451688994526075,
#   'Demand (ineligible group, 1)': 1.585499393782,
#   'VoT (ineligible group, 1)': 0.29778184016582215,
#   'Demand (ineligible group, 2)': 2.639334320188,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 3.6362051965179996,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  174: {'Start Index': 46,
#   'End Index': 59,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014490406,
#   'O-D Flow (Max Entropy)': 6.201257219,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.520905606396,
#   'VoT (eligible group, 1)': 0.05115327380952381,
#   'Demand (eligible group, 2)': 0.5519118924909999,
#   'VoT (eligible group, 2)': 0.15451688994526075,
#   'Demand (ineligible group, 1)': 1.0356099555730003,
#   'VoT (ineligible group, 1)': 0.29778184016582215,
#   'Demand (ineligible group, 2)': 1.7239495068820003,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 2.375081514877,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  175: {'Start Index': 46,
#   'End Index': 61,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 0.014909371,
#   'O-D Flow (Max Entropy)': 8.845980375,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 0.7430623515000001,
#   'VoT (eligible group, 1)': 0.05115327380952381,
#   'Demand (eligible group, 2)': 0.7872922533749999,
#   'VoT (eligible group, 2)': 0.15451688994526075,
#   'Demand (ineligible group, 1)': 1.4772787226250004,
#   'VoT (ineligible group, 1)': 0.29778184016582215,
#   'Demand (ineligible group, 2)': 2.45918254425,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 3.3880104836249996,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  176: {'Start Index': 46,
#   'End Index': 62,
#   'Start Station': '083___403087_San_Mateo___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 90.15534588,
#   'O-D Flow (Max Entropy)': 53.33588101,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.4802140048400005,
#   'VoT (eligible group, 1)': 0.05115327380952381,
#   'Demand (eligible group, 2)': 4.746893409889999,
#   'VoT (eligible group, 2)': 0.15451688994526075,
#   'Demand (ineligible group, 1)': 8.907092128670001,
#   'VoT (ineligible group, 1)': 0.29778184016582215,
#   'Demand (ineligible group, 2)': 14.82737492078,
#   'VoT (ineligible group, 2)': 0.5894323003135953,
#   'Demand (ineligible group, 3)': 20.427642426829998,
#   'VoT (ineligible group, 3)': 1.693074454375042},
#  177: {'Start Index': 49,
#   'End Index': 55,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 126.1078921,
#   'O-D Flow (Max Entropy)': 74.20246282,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.97156500894,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 5.86199456278,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 12.391811290939998,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 20.62828466396,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 30.348807293379995,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  178: {'Start Index': 49,
#   'End Index': 59,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 43.88934037,
#   'O-D Flow (Max Entropy)': 48.46926737,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.2474409137899998,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 3.82907212223,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 8.094367650789998,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 13.474456328859999,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 19.82393035433,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  179: {'Start Index': 49,
#   'End Index': 61,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 98.57682151,
#   'O-D Flow (Max Entropy)': 69.13785987,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.63223661129,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 5.46189092973,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 11.54602259829,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 19.22032504386,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 28.27738468683,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  180: {'Start Index': 49,
#   'End Index': 62,
#   'Start Station': '086___403295_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 340.0934662,
#   'O-D Flow (Max Entropy)': 416.8579301,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 27.9294813167,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 32.9317764779,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 69.61527432669999,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 115.8865045678,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 170.49489341089998,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  181: {'Start Index': 51,
#   'End Index': 55,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 88.86265278,
#   'O-D Flow (Max Entropy)': 55.98621571,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.7510764525700004,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 4.422911041090001,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 9.349698023570001,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 15.564167967380001,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 22.898362225390002,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  182: {'Start Index': 51,
#   'End Index': 59,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 6.532354377,
#   'O-D Flow (Max Entropy)': 36.57007664,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 2.4501951348800004,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 2.8890360545600005,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 6.10720279888,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 10.166481305920001,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 14.957161345760001,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  183: {'Start Index': 51,
#   'End Index': 61,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 61.16673155,
#   'O-D Flow (Max Entropy)': 52.16505486,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 3.4950586756199997,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 4.121039333940001,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 8.711564161619998,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 14.501885251080001,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 21.33550743774,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  184: {'Start Index': 51,
#   'End Index': 62,
#   'Start Station': '090___412782_Burlingame___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 302.6833762,
#   'O-D Flow (Max Entropy)': 314.5237677,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 21.0730924359,
#   'VoT (eligible group, 1)': 0.042007510524301565,
#   'Demand (eligible group, 2)': 24.847377648300004,
#   'VoT (eligible group, 2)': 0.15315644271340473,
#   'Demand (ineligible group, 1)': 52.5254692059,
#   'VoT (ineligible group, 1)': 0.3025799362812836,
#   'Demand (ineligible group, 2)': 87.4376074206,
#   'VoT (ineligible group, 2)': 0.5944763420033204,
#   'Demand (ineligible group, 3)': 128.6402209893,
#   'VoT (ineligible group, 3)': 1.7585202338411385},
#  185: {'Start Index': 53,
#   'End Index': 55,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '099___413209_Millbrae___off',
#   'O-D Flow (Initialization)': 123.2839857,
#   'O-D Flow (Max Entropy)': 72.76486228,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.6943673297599995,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 5.966718706959999,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 11.35131851568,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 20.301396576120002,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 28.3782962892,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  186: {'Start Index': 53,
#   'End Index': 59,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 40.95368728,
#   'O-D Flow (Max Entropy)': 47.53017263,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 4.37277588196,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 3.89747415566,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 7.41470693028,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 13.26091816377,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 18.5367673257,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  187: {'Start Index': 53,
#   'End Index': 61,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 95.56036745,
#   'O-D Flow (Max Entropy)': 67.79837653,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 6.23745064076,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 5.559466875459999,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 10.57654673868,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 18.91574705187,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 26.4413668467,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  188: {'Start Index': 53,
#   'End Index': 62,
#   'Start Station': '094___405863_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 337.0770121,
#   'O-D Flow (Max Entropy)': 408.7816411,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 37.6079109812,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 33.5200945702,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 63.7699360116,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 114.0500778669,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 159.424840029,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  189: {'Start Index': 57,
#   'End Index': 59,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '105___405837_Millbrae___off',
#   'O-D Flow (Initialization)': 94.93031222,
#   'O-D Flow (Max Entropy)': 57.61476844,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 5.3005586964799996,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 4.72441101208,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 8.987903876639999,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 16.07452039476,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 22.469759691599997,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  190: {'Start Index': 57,
#   'End Index': 61,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '110___405862_Millbrae___off',
#   'O-D Flow (Initialization)': 149.490271,
#   'O-D Flow (Max Entropy)': 82.18252039,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 7.560791875879999,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 6.738966671979999,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 12.820473180839999,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 22.928923188809996,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 32.0511829521,
#   'VoT (ineligible group, 3)': 1.563645422419461},
#  191: {'Start Index': 57,
#   'End Index': 62,
#   'Start Station': '101___413212_Millbrae___on',
#   'End Station': '112___400039_Millbrae___main',
#   'O-D Flow (Initialization)': 390.884062,
#   'O-D Flow (Max Entropy)': 495.5073564,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'Demand (eligible group, 1)': 45.5866767888,
#   'VoT (eligible group, 1)': 0.057592147435897446,
#   'Demand (eligible group, 2)': 40.631603224799996,
#   'VoT (eligible group, 2)': 0.155614837398374,
#   'Demand (ineligible group, 1)': 77.2991475984,
#   'VoT (ineligible group, 1)': 0.3004807692307692,
#   'Demand (ineligible group, 2)': 138.2465524356,
#   'VoT (ineligible group, 2)': 0.5977305624483045,
#   'Demand (ineligible group, 3)': 193.247868996,
#   'VoT (ineligible group, 3)': 1.563645422419461}}

# %%
dict_od_data_to_save_3 = {}
dict_od_data_to_save_3["Data Category"] \
    = ["Start Index", "End Index", "Start Station", "End Station", "Start City", "End City", \
       "O-D Flow (Initialization)", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for od_index in list(dict_df_od_flow_data.keys()):
    dict_od_data_to_save_3[od_index] = []
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["Start Index"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["End Index"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["Start Station"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["End Station"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["Start City"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["End City"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Initialization)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data[od_index]["O-D Flow (Max Entropy)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["Demand (eligible group, 1)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["VoT (eligible group, 1)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["Demand (eligible group, 2)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["VoT (eligible group, 2)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 1)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 1)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 2)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 2)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["Demand (ineligible group, 3)"]]
    dict_od_data_to_save_3[od_index] += [dict_df_od_flow_data_augmented_3[od_index]["VoT (ineligible group, 3)"]]

# %%
# dict_od_data_to_save_3

directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_data_to_save_3 = pd.DataFrame(dict_od_data_to_save_3)
df_od_data_to_save_3.to_csv(directory_path + 'data_od_VoTs_demands_3.csv', index = False)

# %% [markdown]
# # Demands (per city)

# %%
od_cities_list = []
for key, od_info in dict_df_od_flow_data.items():
    if [od_info["Start City"], od_info["End City"]] not in od_cities_list:
        od_cities_list += [[od_info["Start City"], od_info["End City"]]]

od_flow_cities_max_entr = np.zeros(len(od_cities_list))
for key, od_info in dict_df_od_flow_data.items():
    od_cities_index = od_cities_list.index([od_info["Start City"], od_info["End City"]])
    od_flow_cities_max_entr[od_cities_index] += od_info["O-D Flow (Max Entropy)"]
    

print("od_cities_list:", od_cities_list)
print()
print("od_flow_cities_max_entr:", od_flow_cities_max_entr)
# Out:
# od_cities_list: [['Palo Alto', 'Palo Alto'], ['Palo Alto', 'East Palo Alto'], ['Palo Alto', 'Redwood City'], ['Palo Alto', 'Belmont'], ['Palo Alto', 'San Mateo'], ['Palo Alto', 'Burlingame'], ['Palo Alto', 'Millbrae'], ['East Palo Alto', 'Redwood City'], ['East Palo Alto', 'Belmont'], ['East Palo Alto', 'San Mateo'], ['East Palo Alto', 'Burlingame'], ['East Palo Alto', 'Millbrae'], ['Redwood City', 'Belmont'], ['Redwood City', 'San Mateo'], ['Redwood City', 'Burlingame'], ['Redwood City', 'Millbrae'], ['Belmont', 'San Mateo'], ['Belmont', 'Burlingame'], ['Belmont', 'Millbrae'], ['San Mateo', 'San Mateo'], ['San Mateo', 'Burlingame'], ['San Mateo', 'Millbrae'], ['Burlingame', 'Millbrae'], ['Millbrae', 'Millbrae']]
#
# od_flow_cities_max_entr: [ 612.5396169    98.03491986 1138.00806859  255.87641052  970.06350243
#   242.51473337 1531.06638078  258.1808976    58.05005537  220.06789713
#    55.01934232  347.34863926  146.51429067  555.44073565  138.86560384
#   876.70137269  230.0826049    57.52281483  363.15467556  391.88563256
#   268.47369827 1694.94808301 1067.91263507 1232.17969777]

# %%
od_cities_dict = {}

for index, od_cities in enumerate(od_cities_list):
    od_cities_dict[index] = {}
    od_cities_dict[index]["Start City Index"] = cities_list.index(od_cities[0])
    od_cities_dict[index]["End City Index"] = cities_list.index(od_cities[1])
    od_cities_dict[index]["Start City"] = od_cities_list[index][0]
    od_cities_dict[index]["End City"] = od_cities_list[index][1]
    od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"] = od_flow_cities_max_entr[index]

od_cities_dict
# Out:
# {0: {'Start City Index': 0,
#   'End City Index': 0,
#   'Start City': 'Palo Alto',
#   'End City': 'Palo Alto',
#   'O-D Flow (Max Entropy, Sum)': np.float64(612.5396169)},
#  1: {'Start City Index': 0,
#   'End City Index': 1,
#   'Start City': 'Palo Alto',
#   'End City': 'East Palo Alto',
#   'O-D Flow (Max Entropy, Sum)': np.float64(98.03491986)},
#  2: {'Start City Index': 0,
#   'End City Index': 3,
#   'Start City': 'Palo Alto',
#   'End City': 'Redwood City',
#   'O-D Flow (Max Entropy, Sum)': np.float64(1138.00806859)},
#  3: {'Start City Index': 0,
#   'End City Index': 4,
#   'Start City': 'Palo Alto',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': np.float64(255.87641051999998)},
#  4: {'Start City Index': 0,
#   'End City Index': 5,
#   'Start City': 'Palo Alto',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': np.float64(970.063502426)},
#  5: {'Start City Index': 0,
#   'End City Index': 6,
#   'Start City': 'Palo Alto',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': np.float64(242.51473337)},
#  6: {'Start City Index': 0,
#   'End City Index': 7,
#   'Start City': 'Palo Alto',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(1531.0663807800001)},
#  7: {'Start City Index': 1,
#   'End City Index': 3,
#   'Start City': 'East Palo Alto',
#   'End City': 'Redwood City',
#   'O-D Flow (Max Entropy, Sum)': np.float64(258.1808976)},
#  8: {'Start City Index': 1,
#   'End City Index': 4,
#   'Start City': 'East Palo Alto',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': np.float64(58.050055369999995)},
#  9: {'Start City Index': 1,
#   'End City Index': 5,
#   'Start City': 'East Palo Alto',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': np.float64(220.067897127)},
#  10: {'Start City Index': 1,
#   'End City Index': 6,
#   'Start City': 'East Palo Alto',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': np.float64(55.01934232)},
#  11: {'Start City Index': 1,
#   'End City Index': 7,
#   'Start City': 'East Palo Alto',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(347.34863926199995)},
#  12: {'Start City Index': 3,
#   'End City Index': 4,
#   'Start City': 'Redwood City',
#   'End City': 'Belmont',
#   'O-D Flow (Max Entropy, Sum)': np.float64(146.514290668)},
#  13: {'Start City Index': 3,
#   'End City Index': 5,
#   'Start City': 'Redwood City',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': np.float64(555.4407356509998)},
#  14: {'Start City Index': 3,
#   'End City Index': 6,
#   'Start City': 'Redwood City',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': np.float64(138.865603836)},
#  15: {'Start City Index': 3,
#   'End City Index': 7,
#   'Start City': 'Redwood City',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(876.7013726910002)},
#  16: {'Start City Index': 4,
#   'End City Index': 5,
#   'Start City': 'Belmont',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': np.float64(230.08260489600002)},
#  17: {'Start City Index': 4,
#   'End City Index': 6,
#   'Start City': 'Belmont',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': np.float64(57.52281483)},
#  18: {'Start City Index': 4,
#   'End City Index': 7,
#   'Start City': 'Belmont',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(363.15467556)},
#  19: {'Start City Index': 5,
#   'End City Index': 5,
#   'Start City': 'San Mateo',
#   'End City': 'San Mateo',
#   'O-D Flow (Max Entropy, Sum)': np.float64(391.885632562)},
#  20: {'Start City Index': 5,
#   'End City Index': 6,
#   'Start City': 'San Mateo',
#   'End City': 'Burlingame',
#   'O-D Flow (Max Entropy, Sum)': np.float64(268.47369827)},
#  21: {'Start City Index': 5,
#   'End City Index': 7,
#   'Start City': 'San Mateo',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(1694.9480830100001)},
#  22: {'Start City Index': 6,
#   'End City Index': 7,
#   'Start City': 'Burlingame',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(1067.91263507)},
#  23: {'Start City Index': 7,
#   'End City Index': 7,
#   'Start City': 'Millbrae',
#   'End City': 'Millbrae',
#   'O-D Flow (Max Entropy, Sum)': np.float64(1232.17969777)}}

# %% [markdown]
# ## Case 1: (2 eligible groups, 3 ineligible groups)

# %%
od_cities_dict_augmented_1 = copy.deepcopy(od_cities_dict)

# %%
for od_index in list(od_cities_dict.keys()):
#     od_cities_dict_augmented_1[]

    start_city_name = od_cities_dict[od_index]["Start City"]
    demand_total_od = od_cities_dict[od_index]["O-D Flow (Max Entropy, Sum)"]
    
    od_cities_dict_augmented_1[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][0] / 100
    od_cities_dict_augmented_1[od_index]["VoT (eligible group, 1)"] = dict_VoT_1[start_city_name][0]
    od_cities_dict_augmented_1[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][1] / 100
    od_cities_dict_augmented_1[od_index]["VoT (eligible group, 2)"] = dict_VoT_1[start_city_name][1]
    
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][2] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 1)"] = dict_VoT_1[start_city_name][2]
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][3] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 2)"] = dict_VoT_1[start_city_name][3]
    od_cities_dict_augmented_1[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_1[start_city_name][4] / 100
    od_cities_dict_augmented_1[od_index]["VoT (ineligible group, 3)"] = dict_VoT_1[start_city_name][4]

# %%
dict_od_cities_data_to_save_1 = {}
dict_od_cities_data_to_save_1["Data Category"] \
    = ["Start City Index", "End City Index", "Start City", "End City", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for index, od_cities in enumerate(od_cities_list):
    dict_od_cities_data_to_save_1[index] = []
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["Start City Index"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["End City Index"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["Start City"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["End City"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (eligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (eligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (eligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (eligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 1)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 2)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["Demand (ineligible group, 3)"]]
    dict_od_cities_data_to_save_1[index] += [od_cities_dict_augmented_1[index]["VoT (ineligible group, 3)"]]

# %%
# for value in dict_od_cities_data_to_save_1.values():
#     print(len(value))

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_cities_data_to_save_1 = pd.DataFrame(dict_od_cities_data_to_save_1)
df_od_cities_data_to_save_1.to_csv(directory_path + 'data_cities_od_VoTs_demands_1.csv', index = False)

# %% [markdown]
# ## Case 2: (1 eligible group, 2 ineligible groups)

# %%
od_cities_dict_augmented_2 = copy.deepcopy(od_cities_dict)

# %%
for od_index in list(od_cities_dict.keys()):
#     od_cities_dict_augmented_2[]

    start_city_name = od_cities_dict[od_index]["Start City"]
    demand_total_od = od_cities_dict[od_index]["O-D Flow (Max Entropy, Sum)"]
    
    od_cities_dict_augmented_2[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][0] / 100
    od_cities_dict_augmented_2[od_index]["VoT (eligible group, 1)"] = dict_VoT_2[start_city_name][0]
    
    od_cities_dict_augmented_2[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][1] / 100
    od_cities_dict_augmented_2[od_index]["VoT (ineligible group, 1)"] = dict_VoT_2[start_city_name][1]
    od_cities_dict_augmented_2[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_2[start_city_name][2] / 100
    od_cities_dict_augmented_2[od_index]["VoT (ineligible group, 2)"] = dict_VoT_2[start_city_name][2]

# %%
dict_od_cities_data_to_save_2 = {}
dict_od_cities_data_to_save_2["Data Category"] \
    = ["Start City Index", "End City Index", "Start City", "End City", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)"]

for index, od_cities in enumerate(od_cities_list):
    dict_od_cities_data_to_save_2[index] = []
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["Start City Index"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["End City Index"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["Start City"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["End City"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (eligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (eligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (ineligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (ineligible group, 1)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["Demand (ineligible group, 2)"]]
    dict_od_cities_data_to_save_2[index] += [od_cities_dict_augmented_2[index]["VoT (ineligible group, 2)"]]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_cities_data_to_save_2 = pd.DataFrame(dict_od_cities_data_to_save_2)
df_od_cities_data_to_save_2.to_csv(directory_path + 'data_cities_od_VoTs_demands_2.csv', index = False)

# %% [markdown]
# ## Case 3: (2 eligible group, 3 ineligible groups)

# %% [markdown]
# ## <font color='red'>Todo (Monday, October 13)</font>

# %%
od_cities_dict_augmented_3 = copy.deepcopy(od_cities_dict)

# %%
for od_index in list(od_cities_dict.keys()):
#     od_cities_dict_augmented_3[]

    start_city_name = od_cities_dict[od_index]["Start City"]
    demand_total_od = od_cities_dict[od_index]["O-D Flow (Max Entropy, Sum)"]
    
    od_cities_dict_augmented_3[od_index]["Demand (eligible group, 1)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][0] / 100
    od_cities_dict_augmented_3[od_index]["VoT (eligible group, 1)"] = dict_VoT_3[start_city_name][0]
    od_cities_dict_augmented_3[od_index]["Demand (eligible group, 2)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][1] / 100
    od_cities_dict_augmented_3[od_index]["VoT (eligible group, 2)"] = dict_VoT_3[start_city_name][1]
    
    od_cities_dict_augmented_3[od_index]["Demand (ineligible group, 1)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][2] / 100
    od_cities_dict_augmented_3[od_index]["VoT (ineligible group, 1)"] = dict_VoT_3[start_city_name][2]
    od_cities_dict_augmented_3[od_index]["Demand (ineligible group, 2)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][3] / 100
    od_cities_dict_augmented_3[od_index]["VoT (ineligible group, 2)"] = dict_VoT_3[start_city_name][3]
    od_cities_dict_augmented_3[od_index]["Demand (ineligible group, 3)"] \
        = demand_total_od * dict_population_percentage_3[start_city_name][4] / 100
    od_cities_dict_augmented_3[od_index]["VoT (ineligible group, 3)"] = dict_VoT_3[start_city_name][4]

# %%
dict_od_cities_data_to_save_3 = {}
dict_od_cities_data_to_save_3["Data Category"] \
    = ["Start City Index", "End City Index", "Start City", "End City", "O-D Flow (Max Entropy)", \
       "Demand (eligible group, 1)", "VoT (eligible group, 1)", \
       "Demand (eligible group, 2)", "VoT (eligible group, 2)", \
       "Demand (ineligible group, 1)", "VoT (ineligible group, 1)", \
       "Demand (ineligible group, 2)", "VoT (ineligible group, 2)", \
       "Demand (ineligible group, 3)", "VoT (ineligible group, 3)"]

for index, od_cities in enumerate(od_cities_list):
    dict_od_cities_data_to_save_3[index] = []
    dict_od_cities_data_to_save_3[index] += [od_cities_dict[index]["Start City Index"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict[index]["End City Index"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict[index]["Start City"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict[index]["End City"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict[index]["O-D Flow (Max Entropy, Sum)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["Demand (eligible group, 1)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["VoT (eligible group, 1)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["Demand (eligible group, 2)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["VoT (eligible group, 2)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["Demand (ineligible group, 1)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["VoT (ineligible group, 1)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["Demand (ineligible group, 2)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["VoT (ineligible group, 2)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["Demand (ineligible group, 3)"]]
    dict_od_cities_data_to_save_3[index] += [od_cities_dict_augmented_3[index]["VoT (ineligible group, 3)"]]

# %%
directory_path = '../data/data_income_percentage_VoT___101_N_Sep_to_Nov_2024/'
df_od_cities_data_to_save_3 = pd.DataFrame(dict_od_cities_data_to_save_3)
df_od_cities_data_to_save_3.to_csv(directory_path + 'data_cities_od_VoTs_demands_3.csv', index = False)

# %% [markdown]
# # Scratch Work

# %%
ell = [1, 2, 3, 4, 5]
# ell[1:-1]
ell += [6]
ell
